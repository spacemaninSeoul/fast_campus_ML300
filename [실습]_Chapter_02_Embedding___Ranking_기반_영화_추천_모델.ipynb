# %% [markdown]
# <a href="https://colab.research.google.com/github/spacemaninSeoul/fast_campus_ML300/blob/main/%5B%E1%84%89%E1%85%B5%E1%86%AF%E1%84%89%E1%85%B3%E1%86%B8%5D_Chapter_02_Embedding___Ranking_%E1%84%80%E1%85%B5%E1%84%87%E1%85%A1%E1%86%AB_%E1%84%8B%E1%85%A7%E1%86%BC%E1%84%92%E1%85%AA_%E1%84%8E%E1%85%AE%E1%84%8E%E1%85%A5%E1%86%AB_%E1%84%86%E1%85%A9%E1%84%83%E1%85%A6%E1%86%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주제 : 추천 시스템 - 영화 데이터셋과 Embedding & Ranking 알고리즘으로 추천시스템 만들기
# ----------
#
# ## 실습 가이드
#     1. 데이터를 다운로드하여 Colab에 불러옵니다.
#     2. 필요한 라이브러리는 모두 코드로 작성되어 있습니다.
#     3. 코드는 위에서부터 아래로 순서대로 실행합니다.
#     4. 전체 문제 구성은 좌측 첫 번째 아이콘을 통해 확인할 수 있습니다.
#
#
# ## 데이터 소개
#     - 이번 주제도 마찬가지로 MovieLens Dataset을 사용합니다.
#     - 같은 데이터라도 상황과 데이터의 크기에 따라 다양한 추천 방법을 활용할 수 있어야 합니다.
#     - 파일은 세 개 이며, 각각의 컬럼은 아래와 같습니다.
#
#     1. ratings.dat
#     user_id : 영화를 시청한 사용자 아이디
#     movie_id : 영화의 아이디
#     rating : 사용자가 영화를 평가한 점수
#     time : 사용자가 영화를 시청한 시간
#
#     2. movies.dat
#     movie_id : 영화의 아이디
#     title : 영화 제목
#     genre : 영화 장르
#
#     3. users.dat
#     user_id : 사용자 아이디
#     gender : 사용자 성별
#     age : 사용자 나이
#     occupation : 사용자 직업코드
#     zipcode : 사용자 거주코드
#
#
# - 데이터 출처: https://grouplens.org/datasets/movielens/
#
#
# ## 최종 목표
#     - Large-Scale 에서 적용 가능한 추천시스템 구조 이해
#     - Word2Vec 기반의 임베딩 모델 이해
#     - EDA로 수행할 수 있는 다양한 인사이트 활용
#     - Point-wise 모델링에 대한 이해
#     - Factorization Machine 알고리즘에 대한 이해
#     - ML에 활용할 수 있는 데이터 변환 능력 습득
#     - 모델의 추천 결과를 평가하는 방법에 대한 연습
#
# - 출제자 : 윤기태 강사
# ---

# %% [markdown]
# ## Step 1. Word2Vec 알고리즘 기반 추천 후보군 생성

# %% [markdown]
# #### Rating Matrix 기반 추천시스템의 한계
#
#     [Memory Based Recommendations]
#     1. 만약 유저, 영화의 수가 3000이 아니라 3천만 개 라면?
#     2. Matrix의 크기는 30,000,000 X 30,000,000
#     3. 연산량 자체도 문제가 되지만, Extreme Sparse 벡터가 되면서 정확도 역시 현저하게 떨어지게 됨
#     4. 차원축소, ALS 등의 방법으로 어느정도 극복할 수 있지만, 근본적인 해결책이 되지는 못함
#
# - Recommendation in Large Scale System
#   - Architecture
#   ![recsys_architecture](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2F30pCp%2Fbtqv7PV6365%2FCkl5dwvSoQF3RdneCIzGr1%2Fimg.png)
#   - 데이터 수집과 처리 단계를 제외하면, 추천시스템은 다음과 같은 레이어로 구분되는 추세
#     - `Generate Candidates` : 수백, 수천만개의 Item 중, 후보가 될 만한 Item을 추출. 여기에 CF 등의 방법을 사용할 수도 있지만, 일반적으로는 연산량이 작은 여러 개의 전략(시나리오)들을 합쳐서 coverage 자체를 확보하는 역할을 함. 예를 들면 인기도가 높은 Item, 연관성이 높은 Item 등을 별개의 전략으로 추출하는 것.
#     - `Intention Predict` : User의 Context에 기반하여 Candidates를 한 번 더 좁혀주는 역할. 반드시 필요한 단계는 아니며, Candidates를 추렸음에도 여전히 Large Scale 문제를 가지고 있는 경우에 필터링의 역할로 사용할 수 있음.
#     - `Personalized Ranking` : 일반적으로 추천시스템에서 추천이 잘 되었는지를 평가하는 지표는 CTR, CVR 같은 지표. 이 지표들을 Maximize 할 수 있는 방법으로 개인화 모델을 학습. 일반적인 Classifier를 생각해도 무방하며, 학습 데이터셋을 잘 구축하는 것이 좋은 추천 랭킹모델을 만드는 것.
#
# ![recsys_architecture2](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FUsbKo%2Fbtqv7PBN46z%2Fd4m5pf7lrKs1CqxzkROY81%2Fimg.png)
#
#
# -----

# %% [markdown]
# #### Word2Vec 기반의 Movie2Vec 만들기
#
#     [Word2Vec]
#     1. 임베딩(Embedding) 방법론 중 가장 대중적이고 성능이 좋은 방법
#     2. 같은 문장 내, 혹은 비슷한 위치에 등장하는 단어들은 유사한 의미를 가지고 있을 것이라는 가정.
#     3. 원래는 단어를 벡터로 표현하는 방법으로 고안되었지만, word2vec의 메커니즘을 다양하게 활용할 수 있음
#     4. Word2Vec은 중심 단어와 주변 단어와의 연관성을 학습하여 벡터로 표현함.
#       - 예시 문장 : "역시 성공은 고난을 동반 말없이 등산을 등반하는 것처럼"
#       - 만약 "성공"이라는 단어를 중심 단어로 활용한다면, [역시, _, 고난을, 동반] 이러한 주변 단어를 가지고 중심에 있는 단어의 벡터를 학습할 수 있게 됨. (Skip-gram 방식. CBOW는 반대)
#
# ![skipgram](http://i.imgur.com/TupGxMl.png)
#
#     [학습 원리]
#     1. 단어셋의 크기를 dim으로 하는 input/output 벡터를 활용하여 softmax classification
#     2. 따라서 아래 함수를 최소화 하는 것을 목표로 하는 network를 학습하게 됨
#
# ![function](https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/images/function.png)
#
#     [벡터 표현]
#     1. 학습된 네트워크의 hidden layer (projection layer)에 단어의 벡터가 표현됨
#     2. 이를 lookup 이라고 함
#
# ![lookup](https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/images/lookup.png)
#
# -----
#
#     [영화의 벡터 표현]
#     1. word2vec 방법에서 word를 item으로 치환하면, item2vec으로 활용할 수 있음 (많은 추천시스템에서 활용하는 방법)
#     2. 단, 이 방법은 데이터의 meta-data가 하나의 축으로 이루어진 단어에서와 달리, 영화처럼 multi-axis meta-data를 가진 데이터에서는 완전한 표현이라고 볼 수 없음 (ex. 장르, 감독 등등의 정보)
#     3. 또한 item2vec 메커니즘을 추천시스템에 활용하면 필연적으로 cold-start 문제가 발생할 수 있음
#     4. `Cold-start Problem` : 새로운 유저나 새로운 아이템을 대상으로 추천하게 될 때, 기존 학습모델에서는 등장한 적 없는 데이터이기 때문에 추천 대상으로 포함되기 어려운 현상
#     5. 임베딩 기반 추천에서 cold-start를 극복하는 방법은 여러가지가 있지만, 그 중에서 가장 적용하기 간단하면서도 중요한 개념을 담고 있는 meta-prod2vec을 활용
#     6. 자세한 내용 : https://arxiv.org/pdf/1607.07326.pdf
#
# ![meta-prod2vec](https://image.slidesharecdn.com/metaprod2vec-161007133531/95/metaprod2vec-simple-product-embeddings-with-sideinformation-36-638.jpg?cb=1475847427)

# %% [markdown]
# ### 문제 1. 데이터 불러오기

# %%
import pandas as pd

rating_url = 'https://raw.githubusercontent.com/yoonkt200/python-data-analysis/master/data/ml-1m/ratings.dat'
rating_df = pd.io.parsers.read_csv(rating_url, names=['user_id', 'movie_id', 'rating', 'time'], delimiter='::', engine ='python')

movie_url = 'https://raw.githubusercontent.com/yoonkt200/python-data-analysis/master/data/ml-1m/movies.dat'
movie_df = pd.io.parsers.read_csv(movie_url, names=['movie_id', 'title', 'genre'], delimiter='::', engine ='python', encoding='ISO-8859-1')

user_url = 'https://raw.githubusercontent.com/yoonkt200/python-data-analysis/master/data/ml-1m/users.dat'
user_df = pd.io.parsers.read_csv(user_url, names=['user_id', 'gender', 'age', 'occupation', 'zipcode'], delimiter='::', engine ='python')

# %% [markdown]
# ### 문제 2. EDA & 전처리 - 사용자별 시청 목록 추출

# %%
# groupby, apply 함수로 사용자별 시청 목록 추출
def get_movie_list_sort_by_time(x):
  return x.sort_values(['time'])['movie_id'].tolist()

user_watch_list = rating_df.groupby('user_id')[['movie_id', 'time']].apply(lambda x: get_movie_list_sort_by_time(x))

# %%
user_watch_list
# Out:
# user_id
# 1       [3186, 1721, 1022, 1270, 2340, 1836, 3408, 120...
# 2       [1198, 1217, 1210, 2717, 1293, 2943, 1225, 119...
# 3       [593, 2858, 3534, 1968, 1961, 1431, 1266, 1378...
# 4       [1210, 1097, 3468, 3527, 480, 260, 1196, 1198,...
# 5       [2717, 919, 908, 356, 1250, 2188, 2858, 1127, ...
#                               ...
# 6036    [1721, 2376, 3438, 2428, 1883, 2492, 2827, 268...
# 6037    [1882, 2028, 1267, 702, 3508, 562, 3148, 858, ...
# 6038    [920, 3396, 1210, 2146, 356, 1387, 1079, 1148,...
# 6039    [111, 282, 2067, 930, 1230, 3133, 3022, 947, 3...
# 6040    [858, 2384, 593, 1961, 2019, 573, 3111, 3505, ...
# Length: 6040, dtype: object

# %%
rating_df['movie_id'].value_counts()
# Out:
# 2858    3428
# 260     2991
# 1196    2990
# 1210    2883
# 480     2672
#         ...
# 3458       1
# 2226       1
# 1815       1
# 398        1
# 2909       1
# Name: movie_id, Length: 3706, dtype: int64

# %%
rating_df['movie_id'].value_counts().hist(bins=100)

# %% [markdown]
# ### 문제 3. EDA & 전처리 - 영화 개봉년도 피쳐 생성

# %%
movie_df.head()
# Out:
#    movie_id                               title                         genre
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
# title 피처에서 개봉 년도 (ex. 1990, 2000...) 분리
movie_df['released_year_area'] = movie_df['title'].apply(lambda x: x[-5:-2]+'0')
movie_df.head()
# Out:
#    movie_id  ... released_year_area
# 0         1  ...               1990
# 1         2  ...               1990
# 2         3  ...               1990
# 3         4  ...               1990
# 4         5  ...               1990
#
# [5 rows x 4 columns]

# %%
import seaborn as sns

# %%
# sns.barplot으로 개봉 년도별 영화 갯수 시각화
released_year_area = movie_df['released_year_area'].value_counts().sort_index()
sns.barplot(released_year_area.index, released_year_area.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### 문제 4. EDA & 전처리 - 영화 장르 피쳐 생성

# %%
movie_df['genre'].value_counts()
# Out:
# Drama                                  843
# Comedy                                 521
# Horror                                 178
# Comedy|Drama                           162
# Comedy|Romance                         142
#                                       ...
# Action|Comedy|Crime|Horror|Thriller      1
# Action|Drama|Thriller|War                1
# Action|Adventure|Children's              1
# Action|Adventure|Children's|Fantasy      1
# Adventure|Crime|Sci-Fi|Thriller          1
# Name: genre, Length: 301, dtype: int64

# %%
movie_df['genre'].value_counts().hist()

# %%
# genre 피처에서 영화의 대표 장르 추출
movie_df['main_genre'] = movie_df['genre'].apply(lambda x: x.split('|')[0])

# %%
movie_df['main_genre'].value_counts()
# Out:
# Drama          1176
# Comedy         1024
# Action          503
# Horror          262
# Adventure       155
# Crime           131
# Documentary     123
# Thriller        101
# Animation        90
# Children's       89
# Romance          50
# Sci-Fi           46
# Mystery          36
# Western          33
# Film-Noir        25
# Musical          25
# War              12
# Fantasy           2
# Name: main_genre, dtype: int64

# %% [markdown]
# ### 문제 5. Embedding - EDA 결과를 활용하여 Movie2Vec 학습

# %%
movie_df.head()
# Out:
#    movie_id                               title  ... released_year_area main_genre
# 0         1                    Toy Story (1995)  ...               1990  Animation
# 1         2                      Jumanji (1995)  ...               1990  Adventure
# 2         3             Grumpier Old Men (1995)  ...               1990     Comedy
# 3         4            Waiting to Exhale (1995)  ...               1990     Comedy
# 4         5  Father of the Bride Part II (1995)  ...               1990     Comedy
#
# [5 rows x 5 columns]

# %%
# movie_meta_dict 생성

# ex.
# {'main_genre': {1: 'Animation',
#   2: 'Adventure',
#   3: 'Comedy',
#   4: 'Comedy',
#   5: 'Comedy',
#   ...
#   'released_year_area': {...},
#   ...
# }
movie_meta_dict = movie_df.set_index('movie_id')[['released_year_area', 'main_genre']].to_dict()

# %%
movie_meta_dict
# Out:
# {'main_genre': {1: 'Animation',
#   2: 'Adventure',
#   3: 'Comedy',
#   4: 'Comedy',
#   5: 'Comedy',
#   6: 'Action',
#   7: 'Comedy',
#   8: 'Adventure',
#   9: 'Action',
#   10: 'Action',
#   11: 'Comedy',
#   12: 'Comedy',
#   13: 'Animation',
#   14: 'Drama',
#   15: 'Action',
#   16: 'Drama',
#   17: 'Drama',
#   18: 'Thriller',
#   19: 'Comedy',
#   20: 'Action',
#   21: 'Action',
#   22: 'Crime',
#   23: 'Thriller',
#   24: 'Drama',
#   25: 'Drama',
#   26: 'Drama',
#   27: 'Drama',
#   28: 'Romance',
#   29: 'Adventure',
#   30: 'Drama',
#   31: 'Drama',
#   32: 'Drama',
#   33: 'Adventure',
#   34: "Children's",
#   35: 'Drama',
#   36: 'Drama',
#   37: 'Documentary',
#   38: 'Comedy',
#   39: 'Comedy',
#   40: 'Drama',
#   41: 'Drama',
#   42: 'Action',
#   43: 'Drama',
#   44: 'Action',
#   45: 'Comedy',
#   46: 'Drama',
#   47: 'Crime',
#   48: 'Animation',
#   49: 'Drama',
#   50: 'Crime',
#   51: 'Action',
#   52: 'Comedy',
#   53: 'Drama',
#   54: "Children's",
#   55: 'Drama',
#   56: 'Adventure',
#   57: 'Drama',
#   58: 'Drama',
#   59: 'Drama',
#   60: 'Adventure',
#   61: 'Drama',
#   62: 'Drama',
#   63: 'Comedy',
#   64: 'Comedy',
#   65: 'Comedy',
#   66: 'Sci-Fi',
#   67: 'Drama',
#   68: 'Comedy',
#   69: 'Comedy',
#   70: 'Action',
#   71: 'Action',
#   72: 'Comedy',
#   73: 'Drama',
#   74: 'Drama',
#   75: 'Comedy',
#   76: 'Sci-Fi',
#   77: 'Documentary',
#   78: 'Drama',
#   79: 'Drama',
#   80: 'Drama',
#   81: 'Crime',
#   82: 'Drama',
#   83: 'Drama',
#   84: 'Comedy',
#   85: 'Drama',
#   86: 'Adventure',
#   87: "Children's",
#   88: 'Comedy',
#   89: 'Action',
#   90: 'Drama',
#   92: 'Drama',
#   93: 'Comedy',
#   94: 'Drama',
#   95: 'Action',
#   96: 'Comedy',
#   97: 'Drama',
#   98: 'Action',
#   99: 'Documentary',
#   100: 'Drama',
#   101: 'Comedy',
#   102: 'Comedy',
#   103: 'Thriller',
#   104: 'Comedy',
#   105: 'Drama',
#   106: 'Comedy',
#   107: 'Adventure',
#   108: 'Documentary',
#   109: 'Comedy',
#   110: 'Action',
#   111: 'Drama',
#   112: 'Action',
#   113: 'Drama',
#   114: 'Drama',
#   115: 'Comedy',
#   116: 'Documentary',
#   117: 'Crime',
#   118: 'Comedy',
#   119: 'Comedy',
#   120: 'Drama',
#   121: 'Drama',
#   122: 'Comedy',
#   123: 'Drama',
#   124: 'Drama',
#   125: 'Comedy',
#   126: 'Adventure',
#   127: 'Drama',
#   128: 'Documentary',
#   129: 'Comedy',
#   130: 'Drama',
#   131: 'Drama',
#   132: 'Thriller',
#   133: 'Comedy',
#   134: 'Documentary',
#   135: 'Comedy',
#   136: 'Documentary',
#   137: 'Documentary',
#   138: 'Drama',
#   139: 'Action',
#   140: 'Drama',
#   141: 'Comedy',
#   142: 'Drama',
#   143: 'Drama',
#   144: 'Comedy',
#   145: 'Action',
#   146: 'Adventure',
#   147: 'Drama',
#   148: 'Drama',
#   149: 'Crime',
#   150: 'Drama',
#   151: 'Drama',
#   152: 'Horror',
#   153: 'Action',
#   154: 'Drama',
#   155: 'Drama',
#   156: 'Comedy',
#   157: 'Comedy',
#   158: 'Adventure',
#   159: 'Drama',
#   160: 'Action',
#   161: 'Drama',
#   162: 'Documentary',
#   163: 'Action',
#   164: 'Crime',
#   165: 'Action',
#   166: 'Comedy',
#   167: 'Drama',
#   168: 'Action',
#   169: 'Adventure',
#   170: 'Action',
#   171: 'Comedy',
#   172: 'Action',
#   173: 'Action',
#   174: 'Comedy',
#   175: 'Drama',
#   176: 'Comedy',
#   177: 'Horror',
#   178: 'Comedy',
#   179: 'Drama',
#   180: 'Comedy',
#   181: 'Action',
#   182: 'Drama',
#   183: 'Thriller',
#   184: 'Drama',
#   185: 'Sci-Fi',
#   186: 'Comedy',
#   187: 'Comedy',
#   188: 'Horror',
#   189: 'Comedy',
#   190: 'Thriller',
#   191: 'Drama',
#   192: 'Documentary',
#   193: 'Drama',
#   194: 'Drama',
#   195: 'Comedy',
#   196: 'Horror',
#   197: 'Drama',
#   198: 'Action',
#   199: 'Drama',
#   200: 'Thriller',
#   201: 'Drama',
#   202: 'Drama',
#   203: 'Comedy',
#   204: 'Action',
#   205: 'Comedy',
#   206: 'Documentary',
#   207: 'Drama',
#   208: 'Action',
#   209: 'Drama',
#   210: 'Western',
#   211: 'Drama',
#   212: 'Comedy',
#   213: 'Drama',
#   214: 'Drama',
#   215: 'Drama',
#   216: 'Comedy',
#   217: 'Drama',
#   218: 'Comedy',
#   219: 'Drama',
#   220: 'Horror',
#   222: 'Drama',
#   223: 'Comedy',
#   224: 'Comedy',
#   225: 'Drama',
#   226: 'Thriller',
#   227: 'Action',
#   228: 'Comedy',
#   229: 'Drama',
#   230: 'Drama',
#   231: 'Comedy',
#   232: 'Comedy',
#   233: 'Drama',
#   234: 'Comedy',
#   235: 'Comedy',
#   236: 'Comedy',
#   237: 'Comedy',
#   238: 'Adventure',
#   239: 'Animation',
#   240: 'Thriller',
#   241: "Children's",
#   242: 'Drama',
#   243: 'Comedy',
#   244: 'Animation',
#   245: 'Crime',
#   246: 'Documentary',
#   247: 'Drama',
#   248: 'Comedy',
#   249: 'Drama',
#   250: "Children's",
#   251: 'Action',
#   252: 'Comedy',
#   253: 'Drama',
#   254: 'Drama',
#   255: 'Comedy',
#   256: 'Comedy',
#   257: 'Mystery',
#   258: 'Adventure',
#   259: 'Crime',
#   260: 'Action',
#   261: 'Drama',
#   262: "Children's",
#   263: 'Drama',
#   264: 'Drama',
#   265: 'Drama',
#   266: 'Drama',
#   267: 'Comedy',
#   268: 'Drama',
#   269: 'Drama',
#   270: 'Drama',
#   271: 'Drama',
#   272: 'Drama',
#   273: 'Drama',
#   274: 'Comedy',
#   275: 'Comedy',
#   276: 'Comedy',
#   277: 'Drama',
#   278: 'Comedy',
#   279: 'Drama',
#   280: 'Drama',
#   281: 'Drama',
#   282: 'Drama',
#   283: 'Crime',
#   284: 'Action',
#   285: 'Drama',
#   286: 'Action',
#   287: 'Comedy',
#   288: 'Action',
#   289: 'Comedy',
#   290: 'Crime',
#   291: 'Thriller',
#   292: 'Action',
#   293: 'Crime',
#   294: 'Comedy',
#   295: 'Comedy',
#   296: 'Crime',
#   297: 'Drama',
#   298: 'Comedy',
#   299: 'Drama',
#   300: 'Drama',
#   301: 'Drama',
#   302: 'Drama',
#   303: 'Action',
#   304: 'Comedy',
#   305: 'Comedy',
#   306: 'Drama',
#   307: 'Drama',
#   308: 'Drama',
#   309: 'Drama',
#   310: 'Comedy',
#   311: 'Horror',
#   312: 'Comedy',
#   313: 'Animation',
#   314: 'Drama',
#   315: 'Action',
#   316: 'Action',
#   317: "Children's",
#   318: 'Drama',
#   319: 'Thriller',
#   320: 'Film-Noir',
#   321: 'Drama',
#   322: 'Comedy',
#   324: 'Comedy',
#   325: 'Comedy',
#   326: 'Drama',
#   327: 'Action',
#   328: 'Horror',
#   329: 'Action',
#   330: 'Comedy',
#   331: 'Drama',
#   332: 'Horror',
#   333: 'Comedy',
#   334: 'Drama',
#   335: 'Mystery',
#   336: 'Drama',
#   337: 'Drama',
#   338: 'Sci-Fi',
#   339: 'Comedy',
#   340: 'Adventure',
#   341: 'Drama',
#   342: 'Comedy',
#   343: "Children's",
#   344: 'Comedy',
#   345: 'Comedy',
#   346: 'Drama',
#   347: 'Drama',
#   348: 'Comedy',
#   349: 'Action',
#   350: 'Drama',
#   351: 'Comedy',
#   352: 'Comedy',
#   353: 'Action',
#   354: 'Drama',
#   355: "Children's",
#   356: 'Comedy',
#   357: 'Comedy',
#   358: 'Drama',
#   359: 'Comedy',
#   360: 'Action',
#   361: 'Drama',
#   362: 'Adventure',
#   363: 'Documentary',
#   364: 'Animation',
#   365: 'Drama',
#   366: 'Horror',
#   367: 'Comedy',
#   368: 'Action',
#   369: 'Drama',
#   370: 'Comedy',
#   371: 'Comedy',
#   372: 'Comedy',
#   373: 'Thriller',
#   374: "Children's",
#   375: 'Drama',
#   376: 'Action',
#   377: 'Action',
#   378: 'Comedy',
#   379: 'Action',
#   380: 'Action',
#   381: 'Drama',
#   382: 'Drama',
#   383: 'Western',
#   384: 'Action',
#   385: 'Drama',
#   386: 'Drama',
#   387: 'Action',
#   388: 'Drama',
#   389: 'Drama',
#   390: 'Action',
#   391: 'Crime',
#   392: 'Adventure',
#   393: 'Action',
#   394: 'Action',
#   395: 'Drama',
#   396: 'Drama',
#   397: 'Horror',
#   398: 'Documentary',
#   399: 'Drama',
#   400: 'Drama',
#   401: 'Action',
#   402: 'Comedy',
#   403: 'Comedy',
#   404: 'Documentary',
#   405: 'Action',
#   406: 'Drama',
#   407: 'Horror',
#   408: 'Drama',
#   409: 'Drama',
#   410: 'Comedy',
#   411: 'Comedy',
#   412: 'Drama',
#   413: 'Comedy',
#   414: 'Comedy',
#   415: 'Comedy',
#   416: 'Western',
#   417: 'Comedy',
#   418: 'Drama',
#   419: 'Comedy',
#   420: 'Action',
#   421: 'Adventure',
#   422: 'Thriller',
#   423: 'Action',
#   424: 'Drama',
#   425: 'Drama',
#   426: 'Horror',
#   427: 'Mystery',
#   428: 'Drama',
#   429: 'Comedy',
#   430: 'Drama',
#   431: 'Crime',
#   432: 'Comedy',
#   433: 'Comedy',
#   434: 'Action',
#   435: 'Comedy',
#   436: 'Drama',
#   437: 'Comedy',
#   438: 'Action',
#   439: 'Drama',
#   440: 'Comedy',
#   441: 'Comedy',
#   442: 'Action',
#   443: 'Documentary',
#   444: 'Comedy',
#   445: 'Comedy',
#   446: 'Drama',
#   447: 'Comedy',
#   448: 'Drama',
#   449: 'Comedy',
#   450: 'Comedy',
#   451: 'Drama',
#   452: 'Drama',
#   453: 'Comedy',
#   454: 'Drama',
#   455: 'Adventure',
#   456: 'Drama',
#   457: 'Action',
#   458: 'Drama',
#   459: 'Action',
#   460: 'Comedy',
#   461: 'Drama',
#   462: 'Action',
#   463: 'Crime',
#   464: 'Action',
#   465: 'Action',
#   466: 'Action',
#   467: 'Comedy',
#   468: 'Comedy',
#   469: 'Drama',
#   470: 'Comedy',
#   471: 'Comedy',
#   472: 'Comedy',
#   473: 'Comedy',
#   474: 'Action',
#   475: 'Drama',
#   476: 'Comedy',
#   477: 'Drama',
#   478: 'Comedy',
#   479: 'Action',
#   480: 'Action',
#   481: 'Drama',
#   482: 'Thriller',
#   483: 'Drama',
#   484: 'Adventure',
#   485: 'Action',
#   486: 'Comedy',
#   487: 'Comedy',
#   488: 'Drama',
#   489: 'Comedy',
#   490: 'Thriller',
#   491: 'Drama',
#   492: 'Comedy',
#   493: 'Action',
#   494: 'Action',
#   495: 'Drama',
#   496: 'Comedy',
#   497: 'Comedy',
#   498: 'Drama',
#   499: 'Comedy',
#   500: 'Comedy',
#   501: 'Drama',
#   502: 'Action',
#   503: 'Drama',
#   504: 'Action',
#   505: 'Comedy',
#   506: 'Drama',
#   507: 'Action',
#   508: 'Drama',
#   509: 'Drama',
#   510: 'Drama',
#   511: 'Action',
#   512: 'Horror',
#   513: 'Comedy',
#   514: 'Comedy',
#   515: 'Drama',
#   516: 'Comedy',
#   517: 'Action',
#   518: 'Comedy',
#   519: 'Sci-Fi',
#   520: 'Comedy',
#   521: 'Crime',
#   522: 'Action',
#   523: 'Drama',
#   524: 'Drama',
#   525: 'Drama',
#   526: 'Drama',
#   527: 'Drama',
#   528: 'Drama',
#   529: 'Drama',
#   530: 'Drama',
#   531: "Children's",
#   532: 'Comedy',
#   533: 'Action',
#   534: 'Drama',
#   535: 'Drama',
#   536: 'Drama',
#   537: 'Comedy',
#   538: 'Drama',
#   539: 'Comedy',
#   540: 'Thriller',
#   541: 'Film-Noir',
#   542: 'Comedy',
#   543: 'Comedy',
#   544: 'Action',
#   545: 'Drama',
#   546: 'Action',
#   547: 'Action',
#   548: 'Action',
#   549: 'Documentary',
#   550: 'Comedy',
#   551: "Children's",
#   552: 'Action',
#   553: 'Western',
#   554: 'Thriller',
#   555: 'Action',
#   556: 'Documentary',
#   557: 'Drama',
#   558: 'Action',
#   559: 'Comedy',
#   560: 'Drama',
#   561: 'Thriller',
#   562: 'Comedy',
#   563: 'Drama',
#   564: 'Comedy',
#   565: 'Horror',
#   566: 'Comedy',
#   567: 'Drama',
#   568: 'Comedy',
#   569: "Children's",
#   570: 'Comedy',
#   571: 'Drama',
#   572: 'Drama',
#   573: 'Drama',
#   574: 'Comedy',
#   575: "Children's",
#   576: 'Comedy',
#   577: 'Adventure',
#   578: 'Drama',
#   579: 'Thriller',
#   580: 'Drama',
#   581: 'Documentary',
#   582: 'Comedy',
#   583: 'Comedy',
#   584: 'Drama',
#   585: 'Comedy',
#   586: "Children's",
#   587: 'Comedy',
#   588: 'Animation',
#   589: 'Action',
#   590: 'Adventure',
#   591: 'Action',
#   592: 'Action',
#   593: 'Drama',
#   594: 'Animation',
#   595: 'Animation',
#   596: 'Animation',
#   597: 'Comedy',
#   598: 'Comedy',
#   599: 'Western',
#   600: 'Thriller',
#   601: 'Drama',
#   602: 'Documentary',
#   603: 'Comedy',
#   604: 'Documentary',
#   605: 'Drama',
#   606: 'Horror',
#   607: 'Drama',
#   608: 'Crime',
#   609: 'Adventure',
#   610: 'Action',
#   611: 'Action',
#   612: 'Comedy',
#   613: 'Drama',
#   614: 'Drama',
#   615: 'Drama',
#   616: 'Animation',
#   617: 'Drama',
#   618: 'Comedy',
#   619: 'Comedy',
#   620: 'Drama',
#   621: 'Drama',
#   623: 'Romance',
#   624: 'Action',
#   625: 'Drama',
#   626: 'Comedy',
#   627: 'Drama',
#   628: 'Drama',
#   629: 'Drama',
#   630: 'Drama',
#   631: 'Animation',
#   632: 'War',
#   633: 'Comedy',
#   634: 'Comedy',
#   635: 'Comedy',
#   636: 'Drama',
#   637: 'Comedy',
#   638: 'Romance',
#   639: 'Comedy',
#   640: 'Drama',
#   641: 'Comedy',
#   642: 'Drama',
#   643: 'Comedy',
#   644: 'Comedy',
#   645: 'Drama',
#   647: 'Drama',
#   648: 'Action',
#   649: 'Comedy',
#   650: 'Drama',
#   651: 'Comedy',
#   652: 'Mystery',
#   653: 'Action',
#   654: 'Drama',
#   655: 'Comedy',
#   656: 'Comedy',
#   657: 'Comedy',
#   658: 'Drama',
#   659: 'Crime',
#   660: 'Drama',
#   661: 'Animation',
#   662: 'Thriller',
#   663: 'Comedy',
#   664: 'Comedy',
#   665: 'War',
#   666: 'Drama',
#   667: 'Action',
#   668: 'Drama',
#   669: 'Drama',
#   670: 'Drama',
#   671: 'Comedy',
#   672: 'Drama',
#   673: 'Adventure',
#   674: 'Adventure',
#   675: 'Action',
#   676: 'Drama',
#   678: 'Drama',
#   679: 'Drama',
#   680: 'Sci-Fi',
#   681: 'Crime',
#   682: 'Documentary',
#   683: 'Documentary',
#   684: 'Drama',
#   685: 'Drama',
#   687: 'Drama',
#   688: 'Action',
#   690: 'Romance',
#   691: 'Comedy',
#   692: 'Action',
#   693: 'Drama',
#   694: 'Action',
#   695: 'Mystery',
#   696: 'Thriller',
#   697: 'Drama',
#   698: 'Drama',
#   699: 'Drama',
#   700: 'Comedy',
#   701: 'Drama',
#   702: 'Drama',
#   703: 'Drama',
#   704: 'Action',
#   705: 'Comedy',
#   706: 'Drama',
#   707: 'Crime',
#   708: 'Comedy',
#   709: 'Animation',
#   710: 'Comedy',
#   711: 'Adventure',
#   712: 'Drama',
#   713: 'Drama',
#   714: 'Western',
#   715: 'Drama',
#   716: 'Crime',
#   717: 'Comedy',
#   718: 'Comedy',
#   719: 'Comedy',
#   720: 'Animation',
#   721: 'Drama',
#   722: 'Documentary',
#   723: 'Drama',
#   724: 'Drama',
#   725: 'Comedy',
#   726: 'Drama',
#   727: 'Documentary',
#   728: 'Comedy',
#   729: 'Drama',
#   730: 'Drama',
#   731: 'Mystery',
#   732: 'Crime',
#   733: 'Action',
#   734: 'Comedy',
#   735: 'Comedy',
#   736: 'Action',
#   737: 'Action',
#   738: 'Drama',
#   739: 'Comedy',
#   741: 'Animation',
#   742: 'Horror',
#   743: 'Comedy',
#   744: 'Drama',
#   745: 'Animation',
#   746: 'Film-Noir',
#   747: 'Comedy',
#   748: 'Action',
#   749: 'Drama',
#   750: 'Sci-Fi',
#   751: 'Comedy',
#   752: 'Comedy',
#   753: 'Comedy',
#   754: 'Adventure',
#   755: "Children's",
#   756: 'Documentary',
#   757: 'Drama',
#   758: 'Drama',
#   759: 'Documentary',
#   760: 'War',
#   761: 'Adventure',
#   762: 'Comedy',
#   763: 'Drama',
#   764: 'Drama',
#   765: 'Comedy',
#   766: 'Drama',
#   767: 'Drama',
#   768: 'Drama',
#   769: 'Documentary',
#   770: 'Drama',
#   771: 'Comedy',
#   772: 'Comedy',
#   773: 'Drama',
#   774: 'Drama',
#   775: 'Horror',
#   776: 'Comedy',
#   777: 'War',
#   778: 'Drama',
#   779: 'Drama',
#   780: 'Action',
#   781: 'Drama',
#   782: 'Thriller',
#   783: 'Animation',
#   784: 'Comedy',
#   785: 'Comedy',
#   786: 'Action',
#   787: 'Documentary',
#   788: 'Comedy',
#   789: 'Drama',
#   790: 'Drama',
#   791: 'Documentary',
#   792: 'Fantasy',
#   793: 'Drama',
#   794: 'Comedy',
#   795: 'Drama',
#   796: 'Drama',
#   797: 'Comedy',
#   798: 'Action',
#   799: 'Comedy',
#   800: 'Drama',
#   801: "Children's",
#   802: 'Drama',
#   803: 'Romance',
#   804: 'Comedy',
#   805: 'Drama',
#   806: 'Drama',
#   807: 'Comedy',
#   808: 'Adventure',
#   809: 'Action',
#   810: "Children's",
#   811: 'Comedy',
#   812: 'Drama',
#   813: 'Comedy',
#   814: 'Drama',
#   815: 'Action',
#   816: 'Drama',
#   818: 'Comedy',
#   819: 'Comedy',
#   820: 'Drama',
#   821: 'Romance',
#   822: 'Drama',
#   823: 'Drama',
#   824: 'Drama',
#   825: 'Comedy',
#   826: 'Drama',
#   827: 'Drama',
#   828: 'Adventure',
#   829: 'Comedy',
#   830: 'Comedy',
#   831: 'Drama',
#   832: 'Drama',
#   833: 'Comedy',
#   834: 'Comedy',
#   835: 'Drama',
#   836: 'Action',
#   837: "Children's",
#   838: 'Comedy',
#   839: 'Action',
#   840: 'Comedy',
#   841: 'Horror',
#   842: 'Horror',
#   843: 'Drama',
#   844: 'Drama',
#   845: 'Drama',
#   846: 'Drama',
#   847: 'Comedy',
#   848: 'Drama',
#   849: 'Action',
#   850: 'Crime',
#   851: 'Drama',
#   852: 'Comedy',
#   853: 'Drama',
#   854: 'Drama',
#   855: 'Drama',
#   856: 'Comedy',
#   857: 'Drama',
#   858: 'Action',
#   859: 'Documentary',
#   860: 'Comedy',
#   861: 'Action',
#   862: 'Drama',
#   863: 'Comedy',
#   864: 'Comedy',
#   865: 'Drama',
#   866: 'Crime',
#   867: 'Comedy',
#   868: 'Comedy',
#   869: 'Crime',
#   870: 'Comedy',
#   871: 'Comedy',
#   872: 'Drama',
#   873: 'Drama',
#   874: 'Crime',
#   875: 'Drama',
#   876: 'Action',
#   877: 'Drama',
#   878: 'Drama',
#   879: 'Horror',
#   880: 'Sci-Fi',
#   881: "Children's",
#   882: 'Drama',
#   884: 'Drama',
#   885: "Children's",
#   886: 'Action',
#   887: 'Drama',
#   888: 'Animation',
#   889: 'Romance',
#   890: 'Thriller',
#   891: 'Horror',
#   892: 'Comedy',
#   893: 'Drama',
#   894: 'Romance',
#   895: 'Drama',
#   896: 'Drama',
#   897: 'Adventure',
#   898: 'Comedy',
#   899: 'Musical',
#   900: 'Musical',
#   901: 'Comedy',
#   902: 'Drama',
#   903: 'Mystery',
#   904: 'Mystery',
#   905: 'Comedy',
#   906: 'Mystery',
#   907: 'Comedy',
#   908: 'Drama',
#   909: 'Comedy',
#   910: 'Comedy',
#   911: 'Comedy',
#   912: 'Drama',
#   913: 'Film-Noir',
#   914: 'Musical',
#   915: 'Comedy',
#   916: 'Comedy',
#   917: "Children's",
#   918: 'Musical',
#   919: 'Adventure',
#   920: 'Drama',
#   921: 'Comedy',
#   922: 'Film-Noir',
#   923: 'Drama',
#   924: 'Drama',
#   925: 'Adventure',
#   926: 'Drama',
#   927: 'Comedy',
#   928: 'Romance',
#   929: 'Thriller',
#   930: 'Film-Noir',
#   931: 'Mystery',
#   932: 'Romance',
#   933: 'Comedy',
#   934: 'Comedy',
#   935: 'Comedy',
#   936: 'Comedy',
#   937: 'Comedy',
#   938: 'Musical',
#   939: 'Comedy',
#   940: 'Action',
#   941: 'Adventure',
#   942: 'Crime',
#   943: 'Drama',
#   944: 'Drama',
#   945: 'Comedy',
#   946: 'Comedy',
#   947: 'Comedy',
#   948: 'Drama',
#   949: 'Drama',
#   950: 'Mystery',
#   951: 'Comedy',
#   952: 'Adventure',
#   953: 'Drama',
#   954: 'Drama',
#   955: 'Comedy',
#   956: 'Drama',
#   957: 'Drama',
#   958: 'Comedy',
#   959: 'Drama',
#   960: 'Crime',
#   961: 'Drama',
#   962: 'Crime',
#   963: 'Musical',
#   964: 'Western',
#   965: 'Thriller',
#   966: 'Drama',
#   967: 'Western',
#   968: 'Horror',
#   969: 'Action',
#   970: 'Comedy',
#   971: 'Drama',
#   972: 'Drama',
#   973: 'Drama',
#   974: 'Drama',
#   975: 'Comedy',
#   976: 'Romance',
#   977: 'Mystery',
#   978: 'Drama',
#   979: 'Drama',
#   980: 'Action',
#   981: 'Drama',
#   982: 'Drama',
#   983: 'Romance',
#   984: 'Comedy',
#   985: 'Documentary',
#   986: 'Adventure',
#   987: 'Drama',
#   988: 'Comedy',
#   989: 'Drama',
#   990: 'Action',
#   991: 'Drama',
#   992: 'Thriller',
#   993: 'Drama',
#   994: 'Drama',
#   996: 'Action',
#   997: 'Drama',
#   998: 'Action',
#   999: 'Crime',
#   1000: 'Crime',
#   1001: 'Comedy',
#   1002: 'Comedy',
#   1003: 'Drama',
#   1004: 'Action',
#   1005: "Children's",
#   1006: 'Drama',
#   1007: "Children's",
#   1008: 'Western',
#   1009: 'Adventure',
#   1010: "Children's",
#   1011: 'Adventure',
#   1012: "Children's",
#   ...},
#  'released_year_area': {1: '1990',
#   2: '1990',
#   3: '1990',
#   4: '1990',
#   5: '1990',
#   6: '1990',
#   7: '1990',
#   8: '1990',
#   9: '1990',
#   10: '1990',
#   11: '1990',
#   12: '1990',
#   13: '1990',
#   14: '1990',
#   15: '1990',
#   16: '1990',
#   17: '1990',
#   18: '1990',
#   19: '1990',
#   20: '1990',
#   21: '1990',
#   22: '1990',
#   23: '1990',
#   24: '1990',
#   25: '1990',
#   26: '1990',
#   27: '1990',
#   28: '1990',
#   29: '1990',
#   30: '1990',
#   31: '1990',
#   32: '1990',
#   33: '1990',
#   34: '1990',
#   35: '1990',
#   36: '1990',
#   37: '1990',
#   38: '1990',
#   39: '1990',
#   40: '1990',
#   41: '1990',
#   42: '1990',
#   43: '1990',
#   44: '1990',
#   45: '1990',
#   46: '1990',
#   47: '1990',
#   48: '1990',
#   49: '1990',
#   50: '1990',
#   51: '1990',
#   52: '1990',
#   53: '1990',
#   54: '1990',
#   55: '1990',
#   56: '1990',
#   57: '1990',
#   58: '1990',
#   59: '1990',
#   60: '1990',
#   61: '1990',
#   62: '1990',
#   63: '1990',
#   64: '1990',
#   65: '1990',
#   66: '1990',
#   67: '1990',
#   68: '1990',
#   69: '1990',
#   70: '1990',
#   71: '1990',
#   72: '1990',
#   73: '1990',
#   74: '1990',
#   75: '1990',
#   76: '1990',
#   77: '1990',
#   78: '1990',
#   79: '1990',
#   80: '1990',
#   81: '1990',
#   82: '1990',
#   83: '1990',
#   84: '1990',
#   85: '1990',
#   86: '1990',
#   87: '1990',
#   88: '1990',
#   89: '1990',
#   90: '1990',
#   92: '1990',
#   93: '1990',
#   94: '1990',
#   95: '1990',
#   96: '1990',
#   97: '1990',
#   98: '1990',
#   99: '1990',
#   100: '1990',
#   101: '1990',
#   102: '1990',
#   103: '1990',
#   104: '1990',
#   105: '1990',
#   106: '1990',
#   107: '1990',
#   108: '1990',
#   109: '1990',
#   110: '1990',
#   111: '1970',
#   112: '1990',
#   113: '1990',
#   114: '1990',
#   115: '1990',
#   116: '1990',
#   117: '1990',
#   118: '1990',
#   119: '1990',
#   120: '1990',
#   121: '1990',
#   122: '1990',
#   123: '1990',
#   124: '1990',
#   125: '1990',
#   126: '1990',
#   127: '1990',
#   128: '1990',
#   129: '1990',
#   130: '1990',
#   131: '1990',
#   132: '1990',
#   133: '1990',
#   134: '1990',
#   135: '1990',
#   136: '1990',
#   137: '1990',
#   138: '1990',
#   139: '1990',
#   140: '1990',
#   141: '1990',
#   142: '1980',
#   143: '1990',
#   144: '1990',
#   145: '1990',
#   146: '1990',
#   147: '1990',
#   148: '1990',
#   149: '1990',
#   150: '1990',
#   151: '1990',
#   152: '1990',
#   153: '1990',
#   154: '1960',
#   155: '1990',
#   156: '1990',
#   157: '1990',
#   158: '1990',
#   159: '1990',
#   160: '1990',
#   161: '1990',
#   162: '1990',
#   163: '1990',
#   164: '1990',
#   165: '1990',
#   166: '1990',
#   167: '1990',
#   168: '1990',
#   169: '1990',
#   170: '1990',
#   171: '1990',
#   172: '1990',
#   173: '1990',
#   174: '1990',
#   175: '1990',
#   176: '1990',
#   177: '1990',
#   178: '1990',
#   179: '1990',
#   180: '1990',
#   181: '1990',
#   182: '1990',
#   183: '1990',
#   184: '1990',
#   185: '1990',
#   186: '1990',
#   187: '1990',
#   188: '1990',
#   189: '1990',
#   190: '1990',
#   191: '1990',
#   192: '1990',
#   193: '1990',
#   194: '1990',
#   195: '1990',
#   196: '1990',
#   197: '1990',
#   198: '1990',
#   199: '1960',
#   200: '1990',
#   201: '1990',
#   202: '1990',
#   203: '1990',
#   204: '1990',
#   205: '1990',
#   206: '1990',
#   207: '1990',
#   208: '1990',
#   209: '1990',
#   210: '1990',
#   211: '1990',
#   212: '1990',
#   213: '1990',
#   214: '1990',
#   215: '1990',
#   216: '1990',
#   217: '1990',
#   218: '1990',
#   219: '1990',
#   220: '1990',
#   222: '1990',
#   223: '1990',
#   224: '1990',
#   225: '1990',
#   226: '1990',
#   227: '1990',
#   228: '1990',
#   229: '1990',
#   230: '1990',
#   231: '1990',
#   232: '1990',
#   233: '1990',
#   234: '1990',
#   235: '1990',
#   236: '1990',
#   237: '1990',
#   238: '1990',
#   239: '1990',
#   240: '1990',
#   241: '1990',
#   242: '1990',
#   243: '1990',
#   244: '1990',
#   245: '1990',
#   246: '1990',
#   247: '1990',
#   248: '1990',
#   249: '1990',
#   250: '1990',
#   251: '1990',
#   252: '1990',
#   253: '1990',
#   254: '1990',
#   255: '1990',
#   256: '1990',
#   257: '1990',
#   258: '1990',
#   259: '1990',
#   260: '1970',
#   261: '1990',
#   262: '1990',
#   263: '1990',
#   264: '1990',
#   265: '1990',
#   266: '1990',
#   267: '1990',
#   268: '1990',
#   269: '1990',
#   270: '1990',
#   271: '1990',
#   272: '1990',
#   273: '1990',
#   274: '1990',
#   275: '1990',
#   276: '1990',
#   277: '1990',
#   278: '1990',
#   279: '1990',
#   280: '1990',
#   281: '1990',
#   282: '1990',
#   283: '1990',
#   284: '1990',
#   285: '1990',
#   286: '1990',
#   287: '1990',
#   288: '1990',
#   289: '1990',
#   290: '1990',
#   291: '1990',
#   292: '1990',
#   293: '1990',
#   294: '1990',
#   295: '1990',
#   296: '1990',
#   297: '1990',
#   298: '1990',
#   299: '1990',
#   300: '1990',
#   301: '1990',
#   302: '1990',
#   303: '1990',
#   304: '1990',
#   305: '1990',
#   306: '1990',
#   307: '1990',
#   308: '1990',
#   309: '1990',
#   310: '1990',
#   311: '1990',
#   312: '1990',
#   313: '1990',
#   314: '1990',
#   315: '1990',
#   316: '1990',
#   317: '1990',
#   318: '1990',
#   319: '1990',
#   320: '1990',
#   321: '1990',
#   322: '1990',
#   324: '1990',
#   325: '1990',
#   326: '1990',
#   327: '1990',
#   328: '1990',
#   329: '1990',
#   330: '1990',
#   331: '1990',
#   332: '1990',
#   333: '1990',
#   334: '1990',
#   335: '1990',
#   336: '1990',
#   337: '1990',
#   338: '1990',
#   339: '1990',
#   340: '1990',
#   341: '1990',
#   342: '1990',
#   343: '1990',
#   344: '1990',
#   345: '1990',
#   346: '1990',
#   347: '1990',
#   348: '1990',
#   349: '1990',
#   350: '1990',
#   351: '1990',
#   352: '1990',
#   353: '1990',
#   354: '1990',
#   355: '1990',
#   356: '1990',
#   357: '1990',
#   358: '1990',
#   359: '1990',
#   360: '1990',
#   361: '1990',
#   362: '1990',
#   363: '1990',
#   364: '1990',
#   365: '1990',
#   366: '1990',
#   367: '1990',
#   368: '1990',
#   369: '1990',
#   370: '1990',
#   371: '1990',
#   372: '1990',
#   373: '1990',
#   374: '1990',
#   375: '1990',
#   376: '1990',
#   377: '1990',
#   378: '1990',
#   379: '1990',
#   380: '1990',
#   381: '1990',
#   382: '1990',
#   383: '1990',
#   384: '1990',
#   385: '1990',
#   386: '1990',
#   387: '1990',
#   388: '1990',
#   389: '1990',
#   390: '1960',
#   391: '1990',
#   392: '1990',
#   393: '1990',
#   394: '1990',
#   395: '1990',
#   396: '1990',
#   397: '1990',
#   398: '1990',
#   399: '1990',
#   400: '1990',
#   401: '1990',
#   402: '1990',
#   403: '1990',
#   404: '1990',
#   405: '1990',
#   406: '1990',
#   407: '1990',
#   408: '1990',
#   409: '1990',
#   410: '1990',
#   411: '1990',
#   412: '1990',
#   413: '1990',
#   414: '1990',
#   415: '1990',
#   416: '1990',
#   417: '1990',
#   418: '1990',
#   419: '1990',
#   420: '1990',
#   421: '1990',
#   422: '1990',
#   423: '1990',
#   424: '1990',
#   425: '1990',
#   426: '1990',
#   427: '1990',
#   428: '1990',
#   429: '1990',
#   430: '1990',
#   431: '1990',
#   432: '1990',
#   433: '1990',
#   434: '1990',
#   435: '1990',
#   436: '1990',
#   437: '1990',
#   438: '1990',
#   439: '1990',
#   440: '1990',
#   441: '1990',
#   442: '1990',
#   443: '1990',
#   444: '1990',
#   445: '1990',
#   446: '1990',
#   447: '1990',
#   448: '1990',
#   449: '1990',
#   450: '1990',
#   451: '1990',
#   452: '1990',
#   453: '1990',
#   454: '1990',
#   455: '1990',
#   456: '1990',
#   457: '1990',
#   458: '1990',
#   459: '1990',
#   460: '1990',
#   461: '1990',
#   462: '1990',
#   463: '1990',
#   464: '1990',
#   465: '1990',
#   466: '1990',
#   467: '1990',
#   468: '1990',
#   469: '1990',
#   470: '1990',
#   471: '1990',
#   472: '1990',
#   473: '1990',
#   474: '1990',
#   475: '1990',
#   476: '1990',
#   477: '1990',
#   478: '1990',
#   479: '1990',
#   480: '1990',
#   481: '1990',
#   482: '1990',
#   483: '1990',
#   484: '1990',
#   485: '1990',
#   486: '1990',
#   487: '1990',
#   488: '1990',
#   489: '1990',
#   490: '1990',
#   491: '1990',
#   492: '1990',
#   493: '1990',
#   494: '1990',
#   495: '1970',
#   496: '1990',
#   497: '1990',
#   498: '1990',
#   499: '1990',
#   500: '1990',
#   501: '1990',
#   502: '1990',
#   503: '1990',
#   504: '1990',
#   505: '1990',
#   506: '1990',
#   507: '1990',
#   508: '1990',
#   509: '1990',
#   510: '1990',
#   511: '1990',
#   512: '1990',
#   513: '1990',
#   514: '1990',
#   515: '1990',
#   516: '1990',
#   517: '1990',
#   518: '1990',
#   519: '1990',
#   520: '1990',
#   521: '1990',
#   522: '1990',
#   523: '1990',
#   524: '1990',
#   525: '1990',
#   526: '1990',
#   527: '1990',
#   528: '1990',
#   529: '1990',
#   530: '1990',
#   531: '1990',
#   532: '1990',
#   533: '1990',
#   534: '1990',
#   535: '1990',
#   536: '1990',
#   537: '1990',
#   538: '1990',
#   539: '1990',
#   540: '1990',
#   541: '1980',
#   542: '1990',
#   543: '1990',
#   544: '1990',
#   545: '1990',
#   546: '1990',
#   547: '1990',
#   548: '1990',
#   549: '1990',
#   550: '1990',
#   551: '1990',
#   552: '1990',
#   553: '1990',
#   554: '1990',
#   555: '1990',
#   556: '1990',
#   557: '1960',
#   558: '1990',
#   559: '1990',
#   560: '1990',
#   561: '1990',
#   562: '1990',
#   563: '1990',
#   564: '1990',
#   565: '1990',
#   566: '1990',
#   567: '1990',
#   568: '1990',
#   569: '1990',
#   570: '1990',
#   571: '1990',
#   572: '1990',
#   573: '1990',
#   574: '1990',
#   575: '1990',
#   576: '1990',
#   577: '1990',
#   578: '1990',
#   579: '1990',
#   580: '1990',
#   581: '1990',
#   582: '1990',
#   583: '1990',
#   584: '1990',
#   585: '1990',
#   586: '1990',
#   587: '1990',
#   588: '1990',
#   589: '1990',
#   590: '1990',
#   591: '1990',
#   592: '1980',
#   593: '1990',
#   594: '1930',
#   595: '1990',
#   596: '1940',
#   597: '1990',
#   598: '1990',
#   599: '1960',
#   600: '1990',
#   601: '1990',
#   602: '1990',
#   603: '1990',
#   604: '1990',
#   605: '1990',
#   606: '1990',
#   607: '1990',
#   608: '1990',
#   609: '1990',
#   610: '1980',
#   611: '1990',
#   612: '1990',
#   613: '1990',
#   614: '1990',
#   615: '1970',
#   616: '1970',
#   617: '1990',
#   618: '1990',
#   619: '1990',
#   620: '1990',
#   621: '1990',
#   623: '1990',
#   624: '1990',
#   625: '1990',
#   626: '1990',
#   627: '1990',
#   628: '1990',
#   629: '1990',
#   630: '1990',
#   631: '1990',
#   632: '1990',
#   633: '1990',
#   634: '1990',
#   635: '1990',
#   636: '1990',
#   637: '1990',
#   638: '1990',
#   639: '1990',
#   640: '1990',
#   641: '1990',
#   642: '1990',
#   643: '1990',
#   644: '1990',
#   645: '1990',
#   647: '1990',
#   648: '1990',
#   649: '1990',
#   650: '1990',
#   651: '1990',
#   652: '1990',
#   653: '1990',
#   654: '1990',
#   655: '1990',
#   656: '1990',
#   657: '1990',
#   658: '1990',
#   659: '1960',
#   660: '1990',
#   661: '1990',
#   662: '1990',
#   663: '1990',
#   664: '1990',
#   665: '1990',
#   666: '1990',
#   667: '1990',
#   668: '1950',
#   669: '1950',
#   670: '1950',
#   671: '1990',
#   672: '1990',
#   673: '1990',
#   674: '1960',
#   675: '1990',
#   676: '1990',
#   678: '1990',
#   679: '1990',
#   680: '1960',
#   681: '1980',
#   682: '1990',
#   683: '1990',
#   684: '1980',
#   685: '1990',
#   687: '1990',
#   688: '1990',
#   690: '1990',
#   691: '1990',
#   692: '1990',
#   693: '1990',
#   694: '1990',
#   695: '1990',
#   696: '1990',
#   697: '1990',
#   698: '1990',
#   699: '1990',
#   700: '1990',
#   701: '1990',
#   702: '1960',
#   703: '1990',
#   704: '1990',
#   705: '1990',
#   706: '1990',
#   707: '1990',
#   708: '1990',
#   709: '1980',
#   710: '1990',
#   711: '1990',
#   712: '1990',
#   713: '1990',
#   714: '1990',
#   715: '1990',
#   716: '1970',
#   717: '1990',
#   718: '1990',
#   719: '1990',
#   720: '1990',
#   721: '1990',
#   722: '1990',
#   723: '1980',
#   724: '1990',
#   725: '1990',
#   726: '1990',
#   727: '1990',
#   728: '1990',
#   729: '1990',
#   730: '1990',
#   731: '1990',
#   732: '1990',
#   733: '1990',
#   734: '1990',
#   735: '1990',
#   736: '1990',
#   737: '1990',
#   738: '1990',
#   739: '1990',
#   741: '1990',
#   742: '1990',
#   743: '1990',
#   744: '1990',
#   745: '1990',
#   746: '1940',
#   747: '1990',
#   748: '1990',
#   749: '1940',
#   750: '1960',
#   751: '1990',
#   752: '1990',
#   753: '1990',
#   754: '1990',
#   755: '1950',
#   756: '1990',
#   757: '1990',
#   758: '1990',
#   759: '1990',
#   760: '1990',
#   761: '1990',
#   762: '1990',
#   763: '1990',
#   764: '1990',
#   765: '1990',
#   766: '1990',
#   767: '1990',
#   768: '1990',
#   769: '1990',
#   770: '1940',
#   771: '1980',
#   772: '1990',
#   773: '1970',
#   774: '1980',
#   775: '1960',
#   776: '1990',
#   777: '1990',
#   778: '1990',
#   779: '1990',
#   780: '1990',
#   781: '1990',
#   782: '1990',
#   783: '1990',
#   784: '1990',
#   785: '1990',
#   786: '1990',
#   787: '1990',
#   788: '1990',
#   789: '1990',
#   790: '1990',
#   791: '1990',
#   792: '1980',
#   793: '1990',
#   794: '1990',
#   795: '1990',
#   796: '1970',
#   797: '1990',
#   798: '1990',
#   799: '1990',
#   800: '1990',
#   801: '1990',
#   802: '1990',
#   803: '1990',
#   804: '1990',
#   805: '1990',
#   806: '1990',
#   807: '1990',
#   808: '1990',
#   809: '1990',
#   810: '1990',
#   811: '1990',
#   812: '1990',
#   813: '1990',
#   814: '1990',
#   815: '1990',
#   816: '1990',
#   818: '1990',
#   819: '1990',
#   820: '1950',
#   821: '1990',
#   822: '1990',
#   823: '1960',
#   824: '1990',
#   825: '1990',
#   826: '1990',
#   827: '1990',
#   828: '1990',
#   829: '1990',
#   830: '1990',
#   831: '1990',
#   832: '1990',
#   833: '1990',
#   834: '1990',
#   835: '1990',
#   836: '1990',
#   837: '1990',
#   838: '1990',
#   839: '1990',
#   840: '1990',
#   841: '1950',
#   842: '1990',
#   843: '1990',
#   844: '1990',
#   845: '1990',
#   846: '1990',
#   847: '1990',
#   848: '1990',
#   849: '1990',
#   850: '1990',
#   851: '1990',
#   852: '1990',
#   853: '1990',
#   854: '1950',
#   855: '1990',
#   856: '1990',
#   857: '1940',
#   858: '1970',
#   859: '1990',
#   860: '1990',
#   861: '1990',
#   862: '1990',
#   863: '1990',
#   864: '1990',
#   865: '1990',
#   866: '1990',
#   867: '1990',
#   868: '1990',
#   869: '1990',
#   870: '1990',
#   871: '1990',
#   872: '1990',
#   873: '1970',
#   874: '1990',
#   875: '1990',
#   876: '1990',
#   877: '1990',
#   878: '1990',
#   879: '1990',
#   880: '1990',
#   881: '1990',
#   882: '1990',
#   884: '1990',
#   885: '1990',
#   886: '1990',
#   887: '1990',
#   888: '1990',
#   889: '1990',
#   890: '1980',
#   891: '1990',
#   892: '1990',
#   893: '1990',
#   894: '1930',
#   895: '1990',
#   896: '1990',
#   897: '1940',
#   898: '1940',
#   899: '1950',
#   900: '1950',
#   901: '1950',
#   902: '1960',
#   903: '1950',
#   904: '1950',
#   905: '1930',
#   906: '1940',
#   907: '1930',
#   908: '1950',
#   909: '1960',
#   910: '1950',
#   911: '1960',
#   912: '1940',
#   913: '1940',
#   914: '1960',
#   915: '1950',
#   916: '1950',
#   917: '1930',
#   918: '1940',
#   919: '1930',
#   920: '1930',
#   921: '1980',
#   922: '1950',
#   923: '1940',
#   924: '1960',
#   925: '1940',
#   926: '1950',
#   927: '1930',
#   928: '1940',
#   929: '1940',
#   930: '1940',
#   931: '1940',
#   932: '1950',
#   933: '1950',
#   934: '1950',
#   935: '1950',
#   936: '1930',
#   937: '1950',
#   938: '1950',
#   939: '1950',
#   940: '1930',
#   941: '1940',
#   942: '1940',
#   943: '1940',
#   944: '1930',
#   945: '1930',
#   946: '1940',
#   947: '1930',
#   948: '1950',
#   949: '1950',
#   950: '1930',
#   951: '1940',
#   952: '1950',
#   953: '1940',
#   954: '1930',
#   955: '1930',
#   956: '1940',
#   957: '1920',
#   958: '1940',
#   959: '1930',
#   960: '1940',
#   961: '1930',
#   962: '1930',
#   963: '1940',
#   964: '1940',
#   965: '1930',
#   966: '1940',
#   967: '1940',
#   968: '1960',
#   969: '1950',
#   970: '1950',
#   971: '1950',
#   972: '1950',
#   973: '1940',
#   974: '1930',
#   975: '1930',
#   976: '1930',
#   977: '1930',
#   978: '1930',
#   979: '1990',
#   980: '1980',
#   981: '1990',
#   982: '1950',
#   983: '1990',
#   984: '1990',
#   985: '1990',
#   986: '1990',
#   987: '1990',
#   988: '1990',
#   989: '1990',
#   990: '1990',
#   991: '1990',
#   992: '1990',
#   993: '1990',
#   994: '1990',
#   996: '1990',
#   997: '1990',
#   998: '1990',
#   999: '1990',
#   1000: '1990',
#   1001: '1980',
#   1002: '1990',
#   1003: '1990',
#   1004: '1990',
#   1005: '1990',
#   1006: '1990',
#   1007: '1970',
#   1008: '1950',
#   1009: '1970',
#   1010: '1960',
#   1011: '1970',
#   1012: '1950',
#   ...}}

# %%
user_watch_list.head()
# Out:
# user_id
# 1    [3186, 1721, 1022, 1270, 2340, 1836, 3408, 120...
# 2    [1198, 1217, 1210, 2717, 1293, 2943, 1225, 119...
# 3    [593, 2858, 3534, 1968, 1961, 1431, 1266, 1378...
# 4    [1210, 1097, 3468, 3527, 480, 260, 1196, 1198,...
# 5    [2717, 919, 908, 356, 1250, 2188, 2858, 1127, ...
# dtype: object

# %%
# Gensim을 활용한 meta-prod2vec을 학습할 수 있는 데이터셋 생성

# ex. [['movie_id:3186', 'year:1990', 'genre:Drama', 'movie_id:1721', 
#       'year:1990', 'genre:Drama', 'movie_id:1022', 'year:1950', 
#       'genre:Animation', 'movie_id:1270', 'year:1980', 'genre:Comedy', 'movie_id:2340'...]]
movie2vec_dataset = []
for movie_list in user_watch_list:
  meta_list = []
  for movie_id in movie_list:
    word_meta_1 = 'movie_id:' + str(movie_id)
    word_meta_2 = 'year:' + movie_meta_dict['released_year_area'][movie_id]
    word_meta_3 = 'gener:' + movie_meta_dict['main_genre'][movie_id]
    meta_list.append(word_meta_1)
    meta_list.append(word_meta_2)
    meta_list.append(word_meta_3)
  movie2vec_dataset.append(meta_list)

# %%
movie2vec_dataset[:10]
# Out:
# [['movie_id:3186',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1721',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1022',
#   'year:1950',
#   'gener:Animation',
#   'movie_id:1270',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2340',
#   'year:1990',
#   'gener:Romance',
#   'movie_id:1836',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3408',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:1207',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:2804',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:720',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1193',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:260',
#   'year:1970',
#   'gener:Action',
#   'movie_id:919',
#   'year:1930',
#   'gener:Adventure',
#   'movie_id:608',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2692',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1961',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3105',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:938',
#   'year:1950',
#   'gener:Musical',
#   'movie_id:1962',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1035',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:150',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2018',
#   'year:1940',
#   'gener:Animation',
#   'movie_id:1028',
#   'year:1960',
#   "gener:Children's",
#   'movie_id:1097',
#   'year:1980',
#   "gener:Children's",
#   'movie_id:914',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:2797',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1287',
#   'year:1950',
#   'gener:Action',
#   'movie_id:2762',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:1246',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:661',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2918',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:531',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:3114',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2791',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1029',
#   'year:1940',
#   'gener:Animation',
#   'movie_id:2321',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1197',
#   'year:1980',
#   'gener:Action',
#   'movie_id:594',
#   'year:1930',
#   'gener:Animation',
#   'movie_id:2398',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:1545',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:527',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:588',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2687',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:745',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:595',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2294',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:783',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2355',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1907',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1566',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:48',
#   'year:1990',
#   'gener:Animation'],
#  ['movie_id:1198',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1217',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2717',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1293',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2943',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1225',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1193',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:318',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3030',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1213',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1945',
#   'year:1950',
#   'gener:Crime',
#   'movie_id:1207',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:593',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3095',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:515',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1873',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3468',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:1090',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2501',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2067',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:110',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3035',
#   'year:1950',
#   'gener:Comedy',
#   'movie_id:3147',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1247',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:3105',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1357',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1196',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1957',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:920',
#   'year:1930',
#   'gener:Drama',
#   'movie_id:1953',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1084',
#   'year:1960',
#   'gener:Crime',
#   'movie_id:1962',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1834',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3735',
#   'year:1970',
#   'gener:Crime',
#   'movie_id:3654',
#   'year:1960',
#   'gener:Action',
#   'movie_id:3471',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:1784',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1259',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1954',
#   'year:1970',
#   'gener:Action',
#   'movie_id:2728',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:1968',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:902',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:1103',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:3451',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:3334',
#   'year:1940',
#   'gener:Crime',
#   'movie_id:2852',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:3578',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3068',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:265',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2312',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:590',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:3071',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1253',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:1244',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:3699',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1245',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1955',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:2236',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3678',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:982',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:1442',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2268',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2194',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3255',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:235',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:647',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1096',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:498',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1246',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1124',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:3893',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:1537',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1188',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2396',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2321',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2359',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:356',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3809',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3108',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1265',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2571',
#   'year:1990',
#   'gener:Action',
#   'movie_id:457',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:589',
#   'year:1990',
#   'gener:Action',
#   'movie_id:380',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3418',
#   'year:1990',
#   'gener:Action',
#   'movie_id:163',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1610',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2916',
#   'year:1990',
#   'gener:Action',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3256',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1527',
#   'year:1990',
#   'gener:Action',
#   'movie_id:349',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1408',
#   'year:1990',
#   'gener:Action',
#   'movie_id:21',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2353',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2006',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2278',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1370',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2427',
#   'year:1990',
#   'gener:Action',
#   'movie_id:648',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1372',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1552',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1792',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2490',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1385',
#   'year:1990',
#   'gener:Action',
#   'movie_id:780',
#   'year:1990',
#   'gener:Action',
#   'movie_id:165',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2881',
#   'year:1990',
#   'gener:Action',
#   'movie_id:368',
#   'year:1990',
#   'gener:Action',
#   'movie_id:459',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1801',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3107',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1597',
#   'year:1990',
#   'gener:Action',
#   'movie_id:442',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1690',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2628',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3257',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2002',
#   'year:1990',
#   'gener:Action',
#   'movie_id:736',
#   'year:1990',
#   'gener:Action',
#   'movie_id:292',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2126',
#   'year:1990',
#   'gener:Action',
#   'movie_id:95',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1687',
#   'year:1990',
#   'gener:Action',
#   'movie_id:434',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1544',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1917',
#   'year:1990',
#   'gener:Action'],
#  ['movie_id:593',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3534',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:1968',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1961',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1431',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1266',
#   'year:1990',
#   'gener:Western',
#   'movie_id:1378',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3671',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1379',
#   'year:1990',
#   'gener:Action',
#   'movie_id:590',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:260',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1196',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2871',
#   'year:1970',
#   'gener:Adventure',
#   'movie_id:1197',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3168',
#   'year:1960',
#   'gener:Adventure',
#   'movie_id:1198',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1291',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2167',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1261',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1580',
#   'year:1990',
#   'gener:Action',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1615',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:653',
#   'year:1990',
#   'gener:Action',
#   'movie_id:733',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2006',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2470',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:2115',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1049',
#   'year:1990',
#   'gener:Action',
#   'movie_id:552',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2617',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2735',
#   'year:1980',
#   'gener:Action',
#   'movie_id:648',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1136',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:3114',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3421',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2997',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1394',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1304',
#   'year:1960',
#   'gener:Action',
#   'movie_id:3619',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1270',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1259',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1079',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1265',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1641',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2355',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3552',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3868',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:104',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2081',
#   'year:1980',
#   'gener:Animation'],
#  ['movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1097',
#   'year:1980',
#   "gener:Children's",
#   'movie_id:3468',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:3527',
#   'year:1980',
#   'gener:Action',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:260',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1196',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1198',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1387',
#   'year:1970',
#   'gener:Action',
#   'movie_id:2692',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1201',
#   'year:1960',
#   'gener:Action',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2947',
#   'year:1960',
#   'gener:Action',
#   'movie_id:2366',
#   'year:1930',
#   'gener:Action',
#   'movie_id:1240',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3418',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1214',
#   'year:1970',
#   'gener:Action',
#   'movie_id:3702',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1036',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2951',
#   'year:1960',
#   'gener:Action',
#   'movie_id:1954',
#   'year:1970',
#   'gener:Action'],
#  ['movie_id:2717',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:919',
#   'year:1930',
#   'gener:Adventure',
#   'movie_id:908',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:356',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1250',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:2188',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1127',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3051',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2683',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2997',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3786',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2355',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2908',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2770',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3016',
#   'year:1980',
#   'gener:Horror',
#   'movie_id:2759',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1093',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3408',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3113',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2599',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2428',
#   'year:1990',
#   'gener:Horror',
#   'movie_id:2959',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3409',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:2716',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2333',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2607',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2580',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2318',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2390',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:913',
#   'year:1940',
#   'gener:Film-Noir',
#   'movie_id:2734',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2723',
#   'year:1990',
#   'gener:Action',
#   'movie_id:968',
#   'year:1960',
#   'gener:Horror',
#   'movie_id:2013',
#   'year:1970',
#   'gener:Action',
#   'movie_id:299',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:24',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1513',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2560',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2692',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2762',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:2395',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3081',
#   'year:1990',
#   'gener:Horror',
#   'movie_id:2700',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3176',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2806',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2337',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2070',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2721',
#   'year:1990',
#   'gener:Romance',
#   'movie_id:2987',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:3793',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3624',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3578',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3514',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3513',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3744',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3799',
#   'year:2000',
#   'gener:Animation',
#   'movie_id:501',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1243',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1617',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1046',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3083',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:593',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:296',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:318',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:608',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1213',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1089',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:50',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1719',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:896',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:714',
#   'year:1990',
#   'gener:Western',
#   'movie_id:1192',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:2571',
#   'year:1990',
#   'gener:Action',
#   'movie_id:860',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1704',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1684',
#   'year:1990',
#   'gener:Romance',
#   'movie_id:994',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1554',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:800',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2289',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3728',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:176',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1788',
#   'year:1990',
#   'gener:Action',
#   'movie_id:34',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:1730',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:562',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:162',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:1912',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2282',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1649',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:41',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2437',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:728',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1175',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2159',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:36',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2291',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:581',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:1449',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1171',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3163',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3267',
#   'year:1990',
#   'gener:Action',
#   'movie_id:461',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:32',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3418',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1509',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3046',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1529',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:39',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:265',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3499',
#   'year:1990',
#   'gener:Horror',
#   'movie_id:3260',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1095',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:29',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:1279',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1923',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1635',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1650',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1500',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1734',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:47',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:866',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:215',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3006',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2323',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:2890',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:272',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1759',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1535',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1594',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1885',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2359',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1517',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:16',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3100',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2916',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1392',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1610',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1747',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:497',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1466',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2384',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:1732',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2058',
#   'year:1990',
#   'gener:Action',
#   'movie_id:150',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1721',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1729',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:733',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2952',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2353',
#   'year:1990',
#   'gener:Action',
#   'movie_id:509',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:224',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:357',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1429',
#   'year:1990',
#   'gener:Action',
#   'movie_id:348',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:321',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1715',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:515',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1653',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:412',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:6',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1643',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3249',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:3020',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3476',
#   'year:1990',
#   'gener:Horror',
#   'movie_id:1966',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1268',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3386',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1794',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:377',
#   'year:1990',
#   'gener:Action',
#   'movie_id:506',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1580',
#   'year:1990',
#   'gener:Action',
#   'movie_id:202',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2268',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1722',
#   'year:1990',
#   'gener:Action',
#   'movie_id:194',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1683',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3079',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1921',
#   'year:1990',
#   'gener:Sci-Fi',
#   'movie_id:2725',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3266',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1897',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1191',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:1733',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2427',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1909',
#   'year:1990',
#   'gener:Mystery',
#   'movie_id:52',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1527',
#   'year:1990',
#   'gener:Action',
#   'movie_id:353',
#   'year:1990',
#   'gener:Action',
#   'movie_id:551',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:229',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2029',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1884',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3105',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1485',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:288',
#   'year:1990',
#   'gener:Action'],
#  ['movie_id:3072',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2006',
#   'year:1990',
#   'gener:Action',
#   'movie_id:912',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3534',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:1043',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1441',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:377',
#   'year:1990',
#   'gener:Action',
#   'movie_id:17',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1296',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:3685',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2100',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3699',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:2081',
#   'year:1980',
#   'gener:Animation',
#   'movie_id:1674',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1959',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2802',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1088',
#   'year:1980',
#   'gener:Musical',
#   'movie_id:2469',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2406',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1101',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3501',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3524',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1188',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2396',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:569',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:1806',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:2506',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2082',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:1',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2321',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:590',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:2966',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:296',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:838',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:34',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:595',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:588',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1688',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:199',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:48',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1566',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:364',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1380',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1030',
#   'year:1970',
#   'gener:Adventure',
#   'movie_id:1035',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:3604',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:1028',
#   'year:1960',
#   "gener:Children's",
#   'movie_id:914',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:1947',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:3600',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:3610',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:2017',
#   'year:1960',
#   "gener:Children's",
#   'movie_id:383',
#   'year:1990',
#   'gener:Western',
#   'movie_id:266',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:368',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3074',
#   'year:1970',
#   'gener:Western',
#   'movie_id:3508',
#   'year:1970',
#   'gener:Western',
#   'movie_id:3682',
#   'year:1970',
#   'gener:Western',
#   'movie_id:1007',
#   'year:1970',
#   "gener:Children's",
#   'movie_id:3578',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3753',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3408',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3536',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:3624',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3565',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:3717',
#   'year:2000',
#   'gener:Action',
#   'movie_id:920',
#   'year:1930',
#   'gener:Drama',
#   'movie_id:1569',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:597',
#   'year:1990',
#   'gener:Comedy'],
#  ['movie_id:1270',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1196',
#   'year:1980',
#   'gener:Action',
#   'movie_id:442',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1221',
#   'year:1970',
#   'gener:Action',
#   'movie_id:648',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3753',
#   'year:2000',
#   'gener:Action',
#   'movie_id:1997',
#   'year:1970',
#   'gener:Horror',
#   'movie_id:3578',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3793',
#   'year:2000',
#   'gener:Action',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:110',
#   'year:1990',
#   'gener:Action',
#   'movie_id:457',
#   'year:1990',
#   'gener:Action',
#   'movie_id:589',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1610',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2571',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3418',
#   'year:1990',
#   'gener:Action',
#   'movie_id:377',
#   'year:1990',
#   'gener:Action',
#   'movie_id:733',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2916',
#   'year:1990',
#   'gener:Action',
#   'movie_id:6',
#   'year:1990',
#   'gener:Action',
#   'movie_id:474',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1580',
#   'year:1990',
#   'gener:Action',
#   'movie_id:861',
#   'year:1990',
#   'gener:Action',
#   'movie_id:380',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1573',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2353',
#   'year:1990',
#   'gener:Action',
#   'movie_id:349',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3256',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1722',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3107',
#   'year:1990',
#   'gener:Action'],
#  ['movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:111',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:908',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:3481',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:1573',
#   'year:1990',
#   'gener:Action',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:589',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3265',
#   'year:1990',
#   'gener:Action',
#   'movie_id:393',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2692',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3418',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2571',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2916',
#   'year:1990',
#   'gener:Action',
#   'movie_id:110',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3267',
#   'year:1990',
#   'gener:Action',
#   'movie_id:377',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2427',
#   'year:1990',
#   'gener:Action',
#   'movie_id:555',
#   'year:1990',
#   'gener:Action',
#   'movie_id:163',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3107',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1580',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2278',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2490',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1916',
#   'year:1990',
#   'gener:Action',
#   'movie_id:733',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3256',
#   'year:1990',
#   'gener:Action',
#   'movie_id:349',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2699',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2006',
#   'year:1990',
#   'gener:Action',
#   'movie_id:288',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2600',
#   'year:1990',
#   'gener:Action',
#   'movie_id:25',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2396',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1265',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:17',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:265',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:39',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1735',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1277',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1059',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1639',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1393',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2291',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1213',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:527',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:608',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:296',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2329',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1704',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3260',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3386',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3252',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:36',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1730',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1466',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2908',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:16',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2336',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2686',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:562',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3250',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3006',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:337',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3148',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:73',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:58',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1673',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:538',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1411',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3246',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1120',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:161',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:508',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:506',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2324',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2442',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3147',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1840',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:524',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1660',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:150',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1678',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3105',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:476',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:14',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1721',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1357',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3186',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2268',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1682',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2712',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1653',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:253',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:650',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2702',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:345',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1589',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1621',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:24',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1810',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2541',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1693',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:269',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:151',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:454',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:465',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2297',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2688',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1476',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3259',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1836',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:266',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:230',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1701',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3528',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2023',
#   'year:1990',
#   'gener:Action',
#   'movie_id:282',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2320',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2429',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:1711',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3425',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1488',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3173',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2314',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1801',
#   'year:1990',
#   'gener:Action',
#   'movie_id:105',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:510',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1027',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:4',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3155',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3500',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:42',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1274',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:3213',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:741',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3257',
#   'year:1990',
#   'gener:Action'],
#  ['movie_id:1961',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:3751',
#   'year:2000',
#   'gener:Animation',
#   'movie_id:912',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3178',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1221',
#   'year:1970',
#   'gener:Action',
#   'movie_id:3916',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3948',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:1233',
#   'year:1980',
#   'gener:Action',
#   'movie_id:527',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1213',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:593',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:50',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1148',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:920',
#   'year:1930',
#   'gener:Drama',
#   'movie_id:1307',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2692',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1552',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3510',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3408',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3793',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3755',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3623',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3298',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3717',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3301',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:3513',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3452',
#   'year:2000',
#   'gener:Action',
#   'movie_id:3826',
#   'year:2000',
#   'gener:Horror',
#   'movie_id:3484',
#   'year:2000',
#   'gener:Thriller',
#   'movie_id:3148',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:318',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:608',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:720',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:745',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2028',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1617',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1704',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2599',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3114',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1089',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1223',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3160',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2571',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2762',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:457',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1310',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:162',
#   'year:1990',
#   'gener:Documentary',
#   'movie_id:3006',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:25',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:150',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2355',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1265',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2324',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3147',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1393',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:47',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1784',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1639',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1500',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2959',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1669',
#   'year:1990',
#   'gener:Romance',
#   'movie_id:1446',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:377',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1923',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3253',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:223',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2166',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1358',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3255',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1584',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:778',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1466',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:1721',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1060',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1343',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:412',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:300',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2890',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1777',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1682',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:508',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:994',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1912',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1921',
#   'year:1990',
#   'gener:Sci-Fi',
#   'movie_id:590',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:3270',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2302',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:597',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2268',
#   'year:1990',
#   'gener:Crime',
#   'movie_id:838',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:529',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:349',
#   'year:1990',
#   'gener:Action',
#   'movie_id:805',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:428',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:524',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:16',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1653',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1356',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2278',
#   'year:1990',
#   'gener:Action',
#   'movie_id:861',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2294',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:367',
#   'year:1990',
#   'gener:Comedy'],
#  ['movie_id:743',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:858',
#   'year:1970',
#   'gener:Action',
#   'movie_id:597',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1948',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:1210',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1282',
#   'year:1940',
#   'gener:Animation',
#   'movie_id:3751',
#   'year:2000',
#   'gener:Animation',
#   'movie_id:551',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:2312',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2858',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2033',
#   'year:1980',
#   'gener:Animation',
#   'movie_id:3155',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2791',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:480',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1544',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3675',
#   'year:1950',
#   'gener:Musical',
#   'movie_id:2657',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2135',
#   'year:1960',
#   'gener:Adventure',
#   'movie_id:2399',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:648',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3189',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3481',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:3408',
#   'year:2000',
#   'gener:Drama',
#   'movie_id:3629',
#   'year:1920',
#   'gener:Comedy',
#   'movie_id:1204',
#   'year:1960',
#   'gener:Adventure',
#   'movie_id:2762',
#   'year:1990',
#   'gener:Thriller',
#   'movie_id:1148',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:919',
#   'year:1930',
#   'gener:Adventure',
#   'movie_id:1927',
#   'year:1930',
#   'gener:War',
#   'movie_id:541',
#   'year:1980',
#   'gener:Film-Noir',
#   'movie_id:1234',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1198',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1293',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:3037',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2300',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:912',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:1270',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1954',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1291',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3114',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1302',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:1214',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1079',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1080',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1215',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1201',
#   'year:1960',
#   'gener:Action',
#   'movie_id:110',
#   'year:1990',
#   'gener:Action',
#   'movie_id:588',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:913',
#   'year:1940',
#   'gener:Film-Noir',
#   'movie_id:223',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1278',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2918',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:954',
#   'year:1930',
#   'gener:Drama',
#   'movie_id:2716',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1294',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1387',
#   'year:1970',
#   'gener:Action',
#   'movie_id:3035',
#   'year:1950',
#   'gener:Comedy',
#   'movie_id:3868',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2997',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1028',
#   'year:1960',
#   "gener:Children's",
#   'movie_id:3296',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:3702',
#   'year:1970',
#   'gener:Action',
#   'movie_id:589',
#   'year:1990',
#   'gener:Action',
#   'movie_id:277',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2336',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2959',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2872',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3198',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:3095',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:926',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:3471',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:1254',
#   'year:1940',
#   'gener:Adventure',
#   'movie_id:2324',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3671',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1411',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1682',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:150',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2000',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1271',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3194',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:3358',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1580',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2501',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:802',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2863',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:953',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:1',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3087',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2355',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:3525',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1269',
#   'year:1940',
#   'gener:Comedy',
#   'movie_id:1307',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1250',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:1084',
#   'year:1960',
#   'gener:Crime',
#   'movie_id:364',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2100',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3451',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:180',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:914',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:3703',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1947',
#   'year:1960',
#   'gener:Musical',
#   'movie_id:356',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3699',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:2080',
#   'year:1950',
#   'gener:Animation',
#   'movie_id:3066',
#   'year:1970',
#   'gener:War',
#   'movie_id:1253',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:2529',
#   'year:1960',
#   'gener:Action',
#   'movie_id:2291',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3723',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:594',
#   'year:1930',
#   'gener:Animation',
#   'movie_id:3097',
#   'year:1940',
#   'gener:Comedy',
#   'movie_id:1230',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2804',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2040',
#   'year:1970',
#   "gener:Children's",
#   'movie_id:368',
#   'year:1990',
#   'gener:Action',
#   'movie_id:587',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:920',
#   'year:1930',
#   'gener:Drama',
#   'movie_id:653',
#   'year:1990',
#   'gener:Action',
#   'movie_id:62',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2496',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3100',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:3359',
#   'year:1970',
#   'gener:Drama',
#   'movie_id:3255',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:943',
#   'year:1940',
#   'gener:Drama',
#   'movie_id:2948',
#   'year:1960',
#   'gener:Action',
#   'movie_id:1408',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2874',
#   'year:1950',
#   'gener:Comedy',
#   'movie_id:915',
#   'year:1950',
#   'gener:Comedy',
#   'movie_id:918',
#   'year:1940',
#   'gener:Musical',
#   'movie_id:539',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1653',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1104',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:592',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1088',
#   'year:1980',
#   'gener:Musical',
#   'movie_id:2041',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1257',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1243',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2302',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2321',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3386',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1287',
#   'year:1950',
#   'gener:Action',
#   'movie_id:1967',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1012',
#   'year:1950',
#   "gener:Children's",
#   'movie_id:3247',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1921',
#   'year:1990',
#   'gener:Sci-Fi',
#   'movie_id:316',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2662',
#   'year:1950',
#   'gener:Action',
#   'movie_id:104',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:971',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:3086',
#   'year:1930',
#   'gener:Comedy',
#   'movie_id:2294',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:1357',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2371',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:590',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:2078',
#   'year:1960',
#   'gener:Animation',
#   'movie_id:2174',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:963',
#   'year:1940',
#   'gener:Musical',
#   'movie_id:2001',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2617',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3363',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1019',
#   'year:1950',
#   'gener:Adventure',
#   'movie_id:7',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2003',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2137',
#   'year:1970',
#   'gener:Animation',
#   'movie_id:2967',
#   'year:1950',
#   'gener:Drama',
#   'movie_id:3701',
#   'year:1980',
#   'gener:Crime',
#   'movie_id:1356',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1220',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2115',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1517',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2018',
#   'year:1940',
#   'gener:Animation',
#   'movie_id:3039',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2081',
#   'year:1980',
#   'gener:Animation',
#   'movie_id:2393',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1025',
#   'year:1960',
#   'gener:Animation',
#   'movie_id:2470',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:2011',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3500',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1101',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2012',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:596',
#   'year:1940',
#   'gener:Animation',
#   'movie_id:1375',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2161',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:2622',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1923',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1372',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3928',
#   'year:1940',
#   'gener:Comedy',
#   'movie_id:2746',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3704',
#   'year:1980',
#   'gener:Action',
#   'movie_id:3174',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:671',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2628',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1032',
#   'year:1950',
#   'gener:Animation',
#   'movie_id:3809',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1441',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3591',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1031',
#   'year:1970',
#   'gener:Adventure',
#   'movie_id:2045',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:2015',
#   'year:1960',
#   "gener:Children's",
#   'movie_id:3608',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1042',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:780',
#   'year:1990',
#   'gener:Action',
#   'movie_id:317',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:3259',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1756',
#   'year:1990',
#   'gener:Horror',
#   'movie_id:1020',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3252',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:586',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:2082',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:292',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2453',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2111',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2090',
#   'year:1970',
#   'gener:Animation',
#   'movie_id:543',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2138',
#   'year:1970',
#   'gener:Animation',
#   'movie_id:253',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:333',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3501',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2423',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:3072',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2046',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:2043',
#   'year:1950',
#   'gener:Adventure',
#   'movie_id:2109',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1676',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1124',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:2094',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2431',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:329',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2133',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1016',
#   'year:1950',
#   "gener:Children's",
#   'movie_id:2124',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2436',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1633',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:938',
#   'year:1950',
#   'gener:Musical',
#   'movie_id:1345',
#   'year:1970',
#   'gener:Horror',
#   'movie_id:1380',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:344',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1573',
#   'year:1990',
#   'gener:Action',
#   'movie_id:370',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2054',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1135',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2047',
#   'year:1960',
#   "gener:Children's",
#   'movie_id:2005',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:435',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1371',
#   'year:1970',
#   'gener:Action',
#   'movie_id:2002',
#   'year:1990',
#   'gener:Action',
#   'movie_id:351',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1125',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2049',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:2093',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:1409',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2316',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2424',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:282',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:830',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1091',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1884',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3153',
#   'year:1950',
#   'gener:Action',
#   'movie_id:248',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1377',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3439',
#   'year:1990',
#   'gener:Action',
#   'movie_id:153',
#   'year:1990',
#   'gener:Action',
#   'movie_id:186',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3812',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:1586',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2497',
#   'year:1990',
#   'gener:Romance',
#   'movie_id:3688',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2136',
#   'year:1960',
#   'gener:Comedy',
#   'movie_id:48',
#   'year:1990',
#   'gener:Animation',
#   'movie_id:2375',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:208',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3099',
#   'year:1970',
#   'gener:Comedy',
#   'movie_id:2378',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:1513',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1918',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1690',
#   'year:1990',
#   'gener:Action',
#   'movie_id:2770',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1959',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:765',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1566',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:542',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:203',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1583',
#   'year:1990',
#   "gener:Children's",
#   'movie_id:2826',
#   'year:1990',
#   'gener:Action',
#   'movie_id:3254',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3869',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:2530',
#   'year:1970',
#   'gener:Action',
#   'movie_id:24',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2091',
#   'year:1970',
#   "gener:Children's",
#   'movie_id:3264',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:3388',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:2405',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1320',
#   'year:1990',
#   'gener:Action',
#   'movie_id:520',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1015',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:2072',
#   'year:1980',
#   'gener:Comedy',
#   'movie_id:784',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1030',
#   'year:1970',
#   'gener:Adventure',
#   'movie_id:3948',
#   'year:2000',
#   'gener:Comedy',
#   'movie_id:2067',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:898',
#   'year:1940',
#   'gener:Comedy',
#   'movie_id:2396',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1265',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1197',
#   'year:1980',
#   'gener:Action',
#   'movie_id:899',
#   'year:1950',
#   'gener:Musical',
#   'movie_id:2125',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1639',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1247',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:3668',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:2006',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1721',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2108',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:969',
#   'year:1950',
#   'gener:Action',
#   'movie_id:357',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:1286',
#   'year:1980',
#   'gener:Drama',
#   'movie_id:902',
#   'year:1960',
#   'gener:Drama',
#   'movie_id:339',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:932',
#   'year:1950',
#   'gener:Romance',
#   'movie_id:1059',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1339',
#   'year:1990',
#   'gener:Horror',
#   'movie_id:3108',
#   'year:1990',
#   'gener:Comedy',
#   'movie_id:260',
#   'year:1970',
#   'gener:Action',
#   'movie_id:1196',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1584',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:1127',
#   'year:1980',
#   'gener:Action',
#   'movie_id:2571',
#   'year:1990',
#   'gener:Action',
#   'movie_id:1097',
#   'year:1980',
#   "gener:Children's",
#   'movie_id:3175',
#   'year:1990',
#   'gener:Adventure',
#   'movie_id:1376',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1200',
#   'year:1980',
#   'gener:Action',
#   'movie_id:1374',
#   'year:1980',
#   'gener:Action',
#   'movie_id:32',
#   'year:1990',
#   'gener:Drama',
#   'movie_id:2968',
#   'year:1980',
#   'gener:Adventure',
#   'movie_id:924',
#   ...]]

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)

# %%
from gensim.models import Word2Vec

model = Word2Vec(movie2vec_dataset,
                 size=100,
                 window=6,  # 주변 word의 윈도우
                 sg=1,  # skip-gram OR cbow
                 hs=0,  # hierarchical softmax OR negative sampling
                 negative=20,  # negative sampling 파라미터
                 min_count=1,  # word의 등장 최소 횟수
                 iter=20)

# %% [markdown]
# ### 문제 6. Embedding - 일부 데이터로 Movie2Vec 학습 결과 확인

# %%
# most_similar 함수로 학습 결과 확인
model.most_similar('movie_id:1', topn=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('movie_id:1223', 0.8379892706871033),
#  ('movie_id:3429', 0.755408525466919),
#  ('movie_id:1537', 0.7091866731643677),
#  ('movie_id:3114', 0.7058719992637634),
#  ('movie_id:2324', 0.696773886680603)]

# %%
movie_df[movie_df['movie_id'].isin([1223, 3429, 2324, 3114, 3429])]
# Out:
#       movie_id  ... main_genre
# 1205      1223  ...  Animation
# 2255      2324  ...     Comedy
# 3045      3114  ...  Animation
# 3360      3429  ...  Animation
#
# [4 rows x 5 columns]

# %% [markdown]
# ### 문제 7. EDA & 전처리 - Movie2Vec 모델로 Item2Item 후보군 생성

# %%
# item to item 후보군 생성할 변수
item2item = {}

# 영화별 연관 영화 k개씩 추출
k = 10
not_in_count = 0
for movie_id in movie_df['movie_id'].values:
  item2item[movie_id] = []
  try:
    sim_list = model.wv.most_similar('movie_id:' + str(movie_id), topn=k+10)
    for movie_tup in sim_list:
      tup_info = movie_tup[0].split(':')
      if (tup_info[0] == 'movie_id') and (len(item2item[movie_id]) < 10):
        item2item[movie_id].append(tup_info[1])
  except:
    not_in_count += 1
    print('word', str(movie_id), 'not in vocabulary')
# Out:
# word 51 not in vocabulary
# word 109 not in vocabulary
# word 115 not in vocabulary
# word 143 not in vocabulary
# word 284 not in vocabulary
# word 285 not in vocabulary
# word 395 not in vocabulary
# word 399 not in vocabulary
# word 400 not in vocabulary
# word 403 not in vocabulary
# word 604 not in vocabulary
# word 620 not in vocabulary
# word 625 not in vocabulary
# word 629 not in vocabulary
# word 636 not in vocabulary
# word 654 not in vocabulary
# word 675 not in vocabulary
# word 676 not in vocabulary
# word 683 not in vocabulary
# word 693 not in vocabulary
# word 699 not in vocabulary
# word 713 not in vocabulary
# word 721 not in vocabulary
# word 723 not in vocabulary
# word 727 not in vocabulary
# word 738 not in vocabulary
# word 739 not in vocabulary
# word 752 not in vocabulary
# word 768 not in vocabulary
# word 770 not in vocabulary
# word 772 not in vocabulary
# word 773 not in vocabulary
# word 777 not in vocabulary
# word 794 not in vocabulary
# word 795 not in vocabulary
# word 797 not in vocabulary
# word 812 not in vocabulary
# word 816 not in vocabulary
# word 819 not in vocabulary
# word 822 not in vocabulary
# word 825 not in vocabulary
# word 845 not in vocabulary
# word 855 not in vocabulary
# word 856 not in vocabulary
# word 857 not in vocabulary
# word 871 not in vocabulary
# word 873 not in vocabulary
# word 890 not in vocabulary
# word 894 not in vocabulary
# word 979 not in vocabulary
# word 983 not in vocabulary
# word 1001 not in vocabulary
# word 1045 not in vocabulary
# word 1052 not in vocabulary
# word 1065 not in vocabulary
# word 1075 not in vocabulary
# word 1106 not in vocabulary
# word 1108 not in vocabulary
# word 1109 not in vocabulary
# word 1110 not in vocabulary
# word 1122 not in vocabulary
# word 1137 not in vocabulary
# word 1140 not in vocabulary
# word 1141 not in vocabulary
# word 1143 not in vocabulary
# word 1146 not in vocabulary
# word 1155 not in vocabulary
# word 1156 not in vocabulary
# word 1157 not in vocabulary
# word 1158 not in vocabulary
# word 1159 not in vocabulary
# word 1166 not in vocabulary
# word 1308 not in vocabulary
# word 1309 not in vocabulary
# word 1314 not in vocabulary
# word 1318 not in vocabulary
# word 1319 not in vocabulary
# word 1368 not in vocabulary
# word 1400 not in vocabulary
# word 1424 not in vocabulary
# word 1443 not in vocabulary
# word 1448 not in vocabulary
# word 1462 not in vocabulary
# word 1467 not in vocabulary
# word 1524 not in vocabulary
# word 1557 not in vocabulary
# word 1559 not in vocabulary
# word 1568 not in vocabulary
# word 1577 not in vocabulary
# word 1578 not in vocabulary
# word 1628 not in vocabulary
# word 1697 not in vocabulary
# word 1698 not in vocabulary
# word 1705 not in vocabulary
# word 1706 not in vocabulary
# word 1708 not in vocabulary
# word 1710 not in vocabulary
# word 1716 not in vocabulary
# word 1723 not in vocabulary
# word 1738 not in vocabulary
# word 1740 not in vocabulary
# word 1742 not in vocabulary
# word 1757 not in vocabulary
# word 1765 not in vocabulary
# word 1768 not in vocabulary
# word 1774 not in vocabulary
# word 1776 not in vocabulary
# word 1781 not in vocabulary
# word 1789 not in vocabulary
# word 1819 not in vocabulary
# word 1847 not in vocabulary
# word 2030 not in vocabulary
# word 2199 not in vocabulary
# word 2216 not in vocabulary
# word 2220 not in vocabulary
# word 2222 not in vocabulary
# word 2224 not in vocabulary
# word 2225 not in vocabulary
# word 2228 not in vocabulary
# word 2229 not in vocabulary
# word 2230 not in vocabulary
# word 2270 not in vocabulary
# word 2274 not in vocabulary
# word 2319 not in vocabulary
# word 2489 not in vocabulary
# word 2508 not in vocabulary
# word 2547 not in vocabulary
# word 2564 not in vocabulary
# word 2588 not in vocabulary
# word 2595 not in vocabulary
# word 2601 not in vocabulary
# word 2603 not in vocabulary
# word 2604 not in vocabulary
# word 2680 not in vocabulary
# word 2684 not in vocabulary
# word 2698 not in vocabulary
# word 2832 not in vocabulary
# word 2838 not in vocabulary
# word 2910 not in vocabulary
# word 2954 not in vocabulary
# word 2957 not in vocabulary
# word 2958 not in vocabulary
# word 2980 not in vocabulary
# word 3009 not in vocabulary
# word 3023 not in vocabulary
# word 3059 not in vocabulary
# word 3080 not in vocabulary
# word 3170 not in vocabulary
# word 3191 not in vocabulary
# word 3193 not in vocabulary
# word 3195 not in vocabulary
# word 3226 not in vocabulary
# word 3227 not in vocabulary
# word 3231 not in vocabulary
# word 3234 not in vocabulary
# word 3278 not in vocabulary
# word 3279 not in vocabulary
# word 3332 not in vocabulary
# word 3348 not in vocabulary
# word 3356 not in vocabulary
# word 3369 not in vocabulary
# word 3383 not in vocabulary
# word 3411 not in vocabulary
# word 3455 not in vocabulary
# word 3541 not in vocabulary
# word 3558 not in vocabulary
# word 3560 not in vocabulary
# word 3561 not in vocabulary
# word 3582 not in vocabulary
# word 3583 not in vocabulary
# word 3589 not in vocabulary
# word 3630 not in vocabulary
# word 3650 not in vocabulary
# word 3750 not in vocabulary
# word 3829 not in vocabulary
# word 3856 not in vocabulary
# word 3907 not in vocabulary

# %%
item2item
# Out:
# {1: ['1223',
#   '3429',
#   '1537',
#   '3114',
#   '2324',
#   '1148',
#   '745',
#   '2289',
#   '235',
#   '2700'],
#  2: ['60',
#   '3489',
#   '653',
#   '1848',
#   '1009',
#   '2143',
#   '1015',
#   '126',
#   '2043',
#   '2005'],
#  3: ['804', '1593', '2558', '237', '1353', '2510', '499', '195', '276', '447'],
#  4: ['2252', '2431', '542', '1410', '186', '518', '765', '520', '719', '472'],
#  5: ['830', '186', '2082', '2431', '174', '203', '135', '1167', '2306', '542'],
#  6: ['2278',
#   '474',
#   '1610',
#   '3267',
#   '555',
#   '493',
#   '2058',
#   '2353',
#   '1912',
#   '457'],
#  7: ['2424', '1409', '597', '252', '339', '1457', '539', '1569', '236', '468'],
#  8: ['1582',
#   '1551',
#   '986',
#   '1015',
#   '238',
#   '362',
#   '2103',
#   '609',
#   '2057',
#   '158'],
#  9: ['315', '227', '694', '459', '1382', '548', '479', '544', '204', '1004'],
#  10: ['349',
#   '733',
#   '1049',
#   '1552',
#   '1370',
#   '2273',
#   '494',
#   '2334',
#   '1047',
#   '3256'],
#  11: ['2539',
#   '2671',
#   '357',
#   '1693',
#   '838',
#   '2108',
#   '342',
#   '1569',
#   '1680',
#   '440'],
#  12: ['1992',
#   '843',
#   '1756',
#   '1993',
#   '2462',
#   '2149',
#   '2798',
#   '397',
#   '1990',
#   '2515'],
#  13: ['2089',
#   '2354',
#   '313',
#   '783',
#   '2876',
#   '3400',
#   '1688',
#   '1907',
#   '48',
#   '2687'],
#  14: ['282',
#   '2271',
#   '175',
#   '1399',
#   '491',
#   '887',
#   '730',
#   '1611',
#   '369',
#   '2250'],
#  15: ['168', '3705', '1556', '704', '20', '990', '360', '1626', '502', '1867'],
#  16: ['628',
#   '1343',
#   '1834',
#   '508',
#   '300',
#   '1682',
#   '281',
#   '454',
#   '230',
#   '1268'],
#  17: ['265', '25', '446', '58', '1094', '1393', '1357', '36', '534', '1277'],
#  18: ['2803',
#   '3063',
#   '662',
#   '3249',
#   '422',
#   '132',
#   '2778',
#   '782',
#   '3686',
#   '1003'],
#  19: ['1503',
#   '2798',
#   '747',
#   '2886',
#   '3248',
#   '325',
#   '2799',
#   '1855',
#   '2152',
#   '93'],
#  20: ['204',
#   '315',
#   '1004',
#   '1752',
#   '544',
#   '694',
#   '485',
#   '1479',
#   '990',
#   '1100'],
#  21: ['1916',
#   '3418',
#   '3178',
#   '474',
#   '1408',
#   '2353',
#   '493',
#   '3255',
#   '3253',
#   '1429'],
#  22: ['1620',
#   '1805',
#   '2112',
#   '1061',
#   '521',
#   '1686',
#   '280',
#   '1589',
#   '832',
#   '259'],
#  23: ['2803',
#   '662',
#   '3249',
#   '2320',
#   '3063',
#   '422',
#   '2446',
#   '132',
#   '415',
#   '103'],
#  24: ['2901',
#   '2672',
#   '2560',
#   '2900',
#   '2906',
#   '2093',
#   '3219',
#   '2598',
#   '43',
#   '2526'],
#  25: ['265', '17', '1393', '58', '3260', '1357', '1094', '36', '778', '1704'],
#  26: ['3252', '3100', '805', '2590', '2437', '62', '175', '508', '282', '766'],
#  27: ['630',
#   '1811',
#   '1726',
#   '510',
#   '672',
#   '2233',
#   '3382',
#   '184',
#   '703',
#   '697'],
#  28: ['2708',
#   '928',
#   '265',
#   '446',
#   '1669',
#   '17',
#   '1277',
#   '1850',
#   '2704',
#   '1554'],
#  29: ['1175',
#   '32',
#   '2968',
#   '741',
#   '1584',
#   '1274',
#   '1206',
#   '1199',
#   '789',
#   '2010'],
#  30: ['398',
#   '2610',
#   '121',
#   '1719',
#   '3295',
#   '1360',
#   '2839',
#   '1041',
#   '326',
#   '1176'],
#  31: ['1027',
#   '491',
#   '282',
#   '1366',
#   '2432',
#   '3502',
#   '430',
#   '1515',
#   '2271',
#   '1807'],
#  32: ['1584',
#   '1253',
#   '1653',
#   '3471',
#   '1396',
#   '29',
#   '1748',
#   '1175',
#   '1301',
#   '2571'],
#  33: ['679',
#   '1514',
#   '2292',
#   '396',
#   '2679',
#   '1666',
#   '530',
#   '1685',
#   '179',
#   '2510'],
#  34: ['2384',
#   '2289',
#   '2324',
#   '1694',
#   '1',
#   '150',
#   '2501',
#   '1446',
#   '232',
#   '1223'],
#  35: ['2062',
#   '1735',
#   '3528',
#   '1549',
#   '1498',
#   '613',
#   '222',
#   '802',
#   '2801',
#   '821'],
#  36: ['2501',
#   '1704',
#   '1358',
#   '1041',
#   '1095',
#   '3260',
#   '778',
#   '1719',
#   '1411',
#   '25'],
#  37: ['3077',
#   '1470',
#   '985',
#   '136',
#   '791',
#   '2538',
#   '1780',
#   '3237',
#   '3609',
#   '108'],
#  38: ['310',
#   '3031',
#   '2296',
#   '1510',
#   '505',
#   '274',
#   '1839',
#   '545',
#   '460',
#   '743'],
#  39: ['357',
#   '2108',
#   '497',
#   '440',
#   '3108',
#   '3358',
#   '342',
#   '3060',
#   '1188',
#   '2321'],
#  40: ['1366',
#   '2277',
#   '2479',
#   '282',
#   '526',
#   '1727',
#   '90',
#   '3502',
#   '1836',
#   '730'],
#  41: ['2890',
#   '3246',
#   '1670',
#   '529',
#   '1094',
#   '1635',
#   '1095',
#   '213',
#   '778',
#   '3260'],
#  42: ['2616',
#   '2540',
#   '1918',
#   '170',
#   '998',
#   '1833',
#   '434',
#   '1382',
#   '3165',
#   '2002'],
#  43: ['299',
#   '2686',
#   '2702',
#   '2560',
#   '314',
#   '3219',
#   '2841',
#   '2443',
#   '2490',
#   '24'],
#  44: ['208', '1606', '809', '798', '533', '836', '464', '547', '434', '168'],
#  45: ['1747',
#   '3255',
#   '52',
#   '1042',
#   '322',
#   '3060',
#   '1279',
#   '342',
#   '1476',
#   '3253'],
#  46: ['3528',
#   '605',
#   '2316',
#   '361',
#   '140',
#   '207',
#   '1735',
#   '3436',
#   '697',
#   '2062'],
#  47: ['2391',
#   '1089',
#   '293',
#   '866',
#   '2542',
#   '2952',
#   '2268',
#   '373',
#   '1358',
#   '50'],
#  48: ['2092',
#   '783',
#   '1489',
#   '239',
#   '1688',
#   '888',
#   '1030',
#   '13',
#   '2354',
#   '3400'],
#  49: ['878',
#   '730',
#   '1664',
#   '2218',
#   '2557',
#   '2833',
#   '2998',
#   '2611',
#   '3295',
#   '398'],
#  50: ['1089',
#   '1213',
#   '296',
#   '608',
#   '1617',
#   '593',
#   '246',
#   '678',
#   '1358',
#   '290'],
#  51: [],
#  52: ['3255',
#   '45',
#   '1883',
#   '1641',
#   '322',
#   '3253',
#   '1747',
#   '348',
#   '2359',
#   '125'],
#  53: ['758',
#   '1384',
#   '2825',
#   '1139',
#   '59',
#   '138',
#   '1423',
#   '730',
#   '878',
#   '1471'],
#  54: ['2036', '419', '2953', '65', '1707', '243', '274', '2886', '575', '87'],
#  55: ['452',
#   '1044',
#   '730',
#   '580',
#   '1038',
#   '1836',
#   '385',
#   '2283',
#   '2619',
#   '2218'],
#  56: ['2162',
#   '126',
#   '3440',
#   '810',
#   '3439',
#   '1849',
#   '1583',
#   '1525',
#   '169',
#   '1848'],
#  57: ['282',
#   '887',
#   '361',
#   '2236',
#   '832',
#   '3252',
#   '1027',
#   '2590',
#   '730',
#   '369'],
#  58: ['265', '25', '1357', '17', '1393', '509', '446', '534', '1643', '249'],
#  59: ['758',
#   '744',
#   '2673',
#   '1908',
#   '1533',
#   '1471',
#   '1423',
#   '2223',
#   '2691',
#   '1058'],
#  60: ['2',
#   '2005',
#   '2161',
#   '1848',
#   '1967',
#   '1009',
#   '653',
#   '1015',
#   '3489',
#   '1654'],
#  61: ['436', '100', '1003', '225', '882', '79', '3063', '1515', '1483', '132'],
#  62: ['3252',
#   '1271',
#   '3271',
#   '3100',
#   '508',
#   '805',
#   '1672',
#   '1678',
#   '1120',
#   '1682'],
#  63: ['542',
#   '2195',
#   '725',
#   '545',
#   '3120',
#   '2845',
#   '2325',
#   '231',
#   '1855',
#   '445'],
#  64: ['3436',
#   '2385',
#   '1353',
#   '444',
#   '1593',
#   '195',
#   '505',
#   '566',
#   '2558',
#   '2510'],
#  65: ['419', '2798', '2036', '88', '325', '255', '93', '870', '2953', '1526'],
#  66: ['519',
#   '880',
#   '3464',
#   '1862',
#   '3664',
#   '737',
#   '1882',
#   '338',
#   '3663',
#   '546'],
#  67: ['3323',
#   '3382',
#   '131',
#   '1139',
#   '3123',
#   '3295',
#   '2218',
#   '2742',
#   '744',
#   '730'],
#  68: ['3108',
#   '96',
#   '2108',
#   '357',
#   '1782',
#   '1966',
#   '298',
#   '2671',
#   '497',
#   '892'],
#  69: ['663',
#   '180',
#   '1753',
#   '441',
#   '2282',
#   '1923',
#   '514',
#   '3253',
#   '104',
#   '101'],
#  70: ['366',
#   '532',
#   '2617',
#   '3274',
#   '1717',
#   '3450',
#   '188',
#   '1785',
#   '3918',
#   '1645'],
#  71: ['1170',
#   '204',
#   '1626',
#   '1004',
#   '315',
#   '544',
#   '20',
#   '1497',
#   '1432',
#   '548'],
#  72: ['1002',
#   '84',
#   '878',
#   '663',
#   '1180',
#   '1914',
#   '562',
#   '1903',
#   '2359',
#   '1392'],
#  73: ['199',
#   '1873',
#   '1487',
#   '2501',
#   '3260',
#   '1678',
#   '242',
#   '2565',
#   '515',
#   '36'],
#  74: ['605',
#   '1735',
#   '613',
#   '3436',
#   '140',
#   '2316',
#   '3528',
#   '1043',
#   '2556',
#   '46'],
#  75: ['1558',
#   '3495',
#   '634',
#   '1622',
#   '664',
#   '981',
#   '660',
#   '618',
#   '3407',
#   '576'],
#  76: ['1603',
#   '2232',
#   '338',
#   '1909',
#   '185',
#   '426',
#   '1876',
#   '2009',
#   '1653',
#   '1573'],
#  77: ['134',
#   '985',
#   '1470',
#   '1039',
#   '2909',
#   '3609',
#   '791',
#   '1315',
#   '2930',
#   '128'],
#  78: ['887',
#   '1051',
#   '2165',
#   '1006',
#   '1563',
#   '2435',
#   '1836',
#   '282',
#   '100',
#   '491'],
#  79: ['1515', '436', '2269', '782', '92', '882', '3063', '61', '463', '3376'],
#  80: ['1719',
#   '1041',
#   '2357',
#   '213',
#   '3260',
#   '2609',
#   '306',
#   '2610',
#   '1095',
#   '1280'],
#  81: ['2561',
#   '874',
#   '1598',
#   '1804',
#   '3272',
#   '2231',
#   '2112',
#   '1501',
#   '1647',
#   '1671'],
#  82: ['85',
#   '730',
#   '2437',
#   '1633',
#   '887',
#   '398',
#   '1354',
#   '452',
#   '2619',
#   '1177'],
#  83: ['398', '2127', '264', '863', '730', '776', '2619', '573', '2711', '617'],
#  84: ['396',
#   '1871',
#   '2999',
#   '630',
#   '1002',
#   '2865',
#   '1384',
#   '1734',
#   '863',
#   '633'],
#  85: ['534',
#   '1357',
#   '2071',
#   '1643',
#   '302',
#   '1680',
#   '2943',
#   '509',
#   '222',
#   '2621'],
#  86: ['2702',
#   '2337',
#   '2714',
#   '2961',
#   '2721',
#   '2491',
#   '2806',
#   '2763',
#   '2485',
#   '2672'],
#  87: ['2953',
#   '374',
#   '174',
#   '2152',
#   '3248',
#   '1707',
#   '1474',
#   '310',
#   '867',
#   '1005'],
#  88: ['216', '637', '135', '1526', '65', '2335', '429', '542', '784', '234'],
#  89: ['786',
#   '288',
#   '2334',
#   '1769',
#   '1792',
#   '494',
#   '3274',
#   '1754',
#   '292',
#   '376'],
#  90: ['1471',
#   '730',
#   '385',
#   '563',
#   '402',
#   '887',
#   '1709',
#   '1510',
#   '878',
#   '1908'],
#  92: ['640', '882', '2269', '1515', '79', '672', '193', '1811', '209', '1798'],
#  93: ['325', '65', '102', '276', '2552', '419', '3248', '2799', '267', '2798'],
#  94: ['147',
#   '875',
#   '851',
#   '1051',
#   '2236',
#   '1810',
#   '2994',
#   '730',
#   '175',
#   '1611'],
#  95: ['1792',
#   '786',
#   '1687',
#   '288',
#   '423',
#   '1518',
#   '1552',
#   '2334',
#   '1769',
#   '494'],
#  96: ['1966',
#   '68',
#   '348',
#   '396',
#   '776',
#   '1871',
#   '2359',
#   '1449',
#   '1002',
#   '176'],
#  97: ['1846',
#   '535',
#   '617',
#   '2127',
#   '1611',
#   '1844',
#   '729',
#   '1594',
#   '730',
#   '1908'],
#  98: ['3380',
#   '990',
#   '2892',
#   '2608',
#   '1626',
#   '591',
#   '2298',
#   '789',
#   '311',
#   '3563'],
#  99: ['1470',
#   '134',
#   '985',
#   '2909',
#   '3237',
#   '791',
#   '1111',
#   '3609',
#   '2198',
#   '2323'],
#  100: ['225', '832', '280', '1841', '61', '230', '436', '1003', '2803', '350'],
#  101: ['441',
#   '1449',
#   '348',
#   '1060',
#   '2359',
#   '1885',
#   '562',
#   '1845',
#   '125',
#   '1923'],
#  102: ['2799',
#   '2798',
#   '437',
#   '1839',
#   '2296',
#   '243',
#   '634',
#   '1731',
#   '1558',
#   '93'],
#  103: ['782',
#   '132',
#   '3063',
#   '540',
#   '1798',
#   '2446',
#   '3249',
#   '2778',
#   '2803',
#   '882'],
#  104: ['3253',
#   '1042',
#   '1476',
#   '1923',
#   '3255',
#   '514',
#   '180',
#   '1883',
#   '1747',
#   '1485'],
#  105: ['1735',
#   '3259',
#   '361',
#   '802',
#   '605',
#   '3528',
#   '509',
#   '222',
#   '1498',
#   '35'],
#  106: ['1236',
#   '2557',
#   '698',
#   '878',
#   '2865',
#   '1734',
#   '1871',
#   '583',
#   '456',
#   '3245'],
#  107: ['1566',
#   '1031',
#   '1030',
#   '2083',
#   '1806',
#   '2135',
#   '1015',
#   '1359',
#   '1894',
#   '2103'],
#  108: ['1039',
#   '985',
#   '3237',
#   '1470',
#   '791',
#   '134',
#   '3609',
#   '2909',
#   '1138',
#   '136'],
#  109: [],
#  110: ['2028',
#   '1233',
#   '589',
#   '2948',
#   '3418',
#   '1242',
#   '1673',
#   '457',
#   '2571',
#   '2944'],
#  111: ['1193',
#   '3359',
#   '3201',
#   '1952',
#   '3152',
#   '3468',
#   '593',
#   '2925',
#   '903',
#   '908'],
#  112: ['733',
#   '2278',
#   '1049',
#   '555',
#   '493',
#   '10',
#   '2006',
#   '380',
#   '1275',
#   '349'],
#  113: ['3262',
#   '2024',
#   '3386',
#   '451',
#   '1589',
#   '350',
#   '2844',
#   '1464',
#   '731',
#   '138'],
#  114: ['730',
#   '2619',
#   '887',
#   '685',
#   '1510',
#   '398',
#   '2994',
#   '396',
#   '878',
#   '2218'],
#  115: [],
#  116: ['2627',
#   '1039',
#   '985',
#   '769',
#   '1149',
#   '791',
#   '136',
#   '2909',
#   '1315',
#   '3237'],
#  117: ['1034',
#   '431',
#   '1061',
#   '1404',
#   '2280',
#   '1799',
#   '2425',
#   '1729',
#   '1466',
#   '1447'],
#  118: ['447',
#   '276',
#   '2510',
#   '499',
#   '64',
#   '2385',
#   '1353',
#   '2558',
#   '237',
#   '378'],
#  119: ['1915',
#   '1857',
#   '305',
#   '2350',
#   '884',
#   '2849',
#   '585',
#   '396',
#   '2589',
#   '1773'],
#  120: ['3382',
#   '2197',
#   '2218',
#   '1814',
#   '1852',
#   '3050',
#   '2269',
#   '2914',
#   '2432',
#   '3323'],
#  121: ['1719',
#   '398',
#   '30',
#   '1412',
#   '994',
#   '1041',
#   '1533',
#   '787',
#   '334',
#   '2610'],
#  122: ['252',
#   '1409',
#   '1593',
#   '550',
#   '236',
#   '237',
#   '2558',
#   '1468',
#   '1457',
#   '1888'],
#  123: ['265',
#   '800',
#   '1594',
#   '17',
#   '25',
#   '3386',
#   '1635',
#   '1719',
#   '286',
#   '1245'],
#  124: ['1841',
#   '264',
#   '878',
#   '2621',
#   '2869',
#   '730',
#   '2931',
#   '3123',
#   '3295',
#   '2432'],
#  125: ['348',
#   '1641',
#   '441',
#   '2359',
#   '1966',
#   '1060',
#   '2321',
#   '1923',
#   '2282',
#   '1449'],
#  126: ['2162', '1525', '56', '1583', '1881', '2', '3489', '2449', '60', '673'],
#  127: ['3376',
#   '1430',
#   '142',
#   '3202',
#   '3290',
#   '3321',
#   '868',
#   '3382',
#   '311',
#   '226'],
#  128: ['134',
#   '1315',
#   '1470',
#   '1039',
#   '2930',
#   '2824',
#   '2198',
#   '985',
#   '2909',
#   '1123'],
#  129: ['2811',
#   '396',
#   '1874',
#   '402',
#   '3377',
#   '576',
#   '744',
#   '807',
#   '1850',
#   '623'],
#  130: ['139',
#   '1316',
#   '2703',
#   '3748',
#   '2569',
#   '2619',
#   '1496',
#   '3485',
#   '396',
#   '2845'],
#  131: ['67',
#   '1139',
#   '1415',
#   '1514',
#   '1384',
#   '630',
#   '730',
#   '3103',
#   '138',
#   '567'],
#  132: ['540',
#   '3063',
#   '782',
#   '103',
#   '1798',
#   '2778',
#   '882',
#   '2446',
#   '1427',
#   '3557'],
#  133: ['3651',
#   '2754',
#   '3460',
#   '977',
#   '311',
#   '3085',
#   '3904',
#   '3229',
#   '3321',
#   '3458'],
#  134: ['985',
#   '1470',
#   '2198',
#   '2909',
#   '791',
#   '1039',
#   '3237',
#   '1315',
#   '3609',
#   '1743'],
#  135: ['637',
#   '3243',
#   '1461',
#   '719',
#   '833',
#   '1167',
#   '743',
#   '88',
#   '2335',
#   '1390'],
#  136: ['1470',
#   '1039',
#   '985',
#   '134',
#   '2984',
#   '2909',
#   '791',
#   '108',
#   '756',
#   '1743'],
#  137: ['1315',
#   '769',
#   '134',
#   '398',
#   '1039',
#   '1050',
#   '1470',
#   '136',
#   '985',
#   '2930'],
#  138: ['396',
#   '630',
#   '679',
#   '1510',
#   '1038',
#   '331',
#   '730',
#   '1384',
#   '3374',
#   '3220'],
#  139: ['130',
#   '2845',
#   '545',
#   '396',
#   '3164',
#   '790',
#   '3904',
#   '868',
#   '226',
#   '1852'],
#  140: ['3528',
#   '2316',
#   '697',
#   '605',
#   '1043',
#   '2154',
#   '207',
#   '46',
#   '3103',
#   '3436'],
#  141: ['500',
#   '1042',
#   '1485',
#   '2496',
#   '1883',
#   '1747',
#   '1777',
#   '3255',
#   '1020',
#   '1476'],
#  142: ['1820',
#   '3904',
#   '127',
#   '3321',
#   '1718',
#   '200',
#   '843',
#   '1430',
#   '1764',
#   '3280'],
#  143: [],
#  144: ['1171',
#   '3450',
#   '524',
#   '268',
#   '1903',
#   '2837',
#   '3263',
#   '1444',
#   '1673',
#   '1580'],
#  145: ['3107',
#   '3633',
#   '1385',
#   '3082',
#   '2001',
#   '2273',
#   '1047',
#   '3635',
#   '1518',
#   '494'],
#  146: ['808',
#   '1795',
#   '1592',
#   '888',
#   '455',
#   '577',
#   '310',
#   '2449',
#   '2142',
#   '169'],
#  147: ['94',
#   '875',
#   '851',
#   '1810',
#   '1051',
#   '1611',
#   '2236',
#   '730',
#   '560',
#   '2190'],
#  148: ['847',
#   '1695',
#   '2445',
#   '2850',
#   '1814',
#   '526',
#   '331',
#   '730',
#   '895',
#   '2960'],
#  149: ['806',
#   '22',
#   '521',
#   '3250',
#   '2425',
#   '1675',
#   '1352',
#   '1447',
#   '1061',
#   '1799'],
#  150: ['1694',
#   '3105',
#   '1784',
#   '2501',
#   '2329',
#   '337',
#   '3271',
#   '1682',
#   '36',
#   '3246'],
#  151: ['1183',
#   '1094',
#   '647',
#   '161',
#   '1619',
#   '991',
#   '534',
#   '2890',
#   '1408',
#   '1670'],
#  152: ['565',
#   '3499',
#   '735',
#   '1255',
#   '2159',
#   '188',
#   '1407',
#   '1130',
#   '1982',
#   '1349'],
#  153: ['1562', '420', '1431', '485', '1377', '44', '762', '886', '836', '208'],
#  154: ['2732',
#   '2285',
#   '3533',
#   '1952',
#   '872',
#   '702',
#   '3011',
#   '1164',
#   '2728',
#   '2132'],
#  155: ['1619',
#   '647',
#   '991',
#   '151',
#   '1183',
#   '1670',
#   '389',
#   '2106',
#   '336',
#   '1507'],
#  156: ['1871',
#   '187',
#   '728',
#   '2331',
#   '1883',
#   '1875',
#   '2999',
#   '322',
#   '601',
#   '1425'],
#  157: ['473', '516', '1184', '1445', '466', '688', '545', '647', '312', '520'],
#  158: ['2429',
#   '1015',
#   '1359',
#   '609',
#   '2103',
#   '455',
#   '362',
#   '1551',
#   '711',
#   '577'],
#  159: ['766',
#   '3252',
#   '805',
#   '730',
#   '1611',
#   '506',
#   '1840',
#   '1120',
#   '832',
#   '1268'],
#  160: ['1590',
#   '1591',
#   '546',
#   '1882',
#   '173',
#   '2808',
#   '172',
#   '737',
#   '405',
#   '2986'],
#  161: ['647',
#   '2890',
#   '151',
#   '1183',
#   '1619',
#   '1670',
#   '991',
#   '1094',
#   '16',
#   '628'],
#  162: ['246',
#   '1147',
#   '2677',
#   '1649',
#   '2909',
#   '134',
#   '581',
#   '549',
#   '556',
#   '1470'],
#  163: ['1722',
#   '1047',
#   '377',
#   '3256',
#   '2058',
#   '1370',
#   '2273',
#   '2353',
#   '353',
#   '861'],
#  164: ['942',
#   '1783',
#   '1179',
#   '1805',
#   '1344',
#   '2066',
#   '707',
#   '3220',
#   '320',
#   '3706'],
#  165: ['494',
#   '292',
#   '2334',
#   '1518',
#   '1792',
#   '1370',
#   '288',
#   '2273',
#   '95',
#   '1769'],
#  166: ['840', '765', '267', '305', '505', '444', '1855', '234', '660', '984'],
#  167: ['385', '730', '729', '844', '184', '878', '993', '197', '375', '1651'],
#  168: ['3257',
#   '1801',
#   '1100',
#   '44',
#   '15',
#   '2822',
#   '1479',
#   '3165',
#   '208',
#   '809'],
#  169: ['455', '1595', '2429', '484', '577', '56', '126', '3166', '609', '754'],
#  170: ['786',
#   '1687',
#   '2616',
#   '1479',
#   '1438',
#   '1752',
#   '1792',
#   '533',
#   '464',
#   '2126'],
#  171: ['1614',
#   '1425',
#   '2155',
#   '1875',
#   '500',
#   '231',
#   '1883',
#   '3255',
#   '1871',
#   '2295'],
#  172: ['1591',
#   '1831',
#   '173',
#   '2808',
#   '849',
#   '1037',
#   '2549',
#   '1590',
#   '2986',
#   '379'],
#  173: ['1591',
#   '849',
#   '172',
#   '1831',
#   '2808',
#   '2549',
#   '1882',
#   '379',
#   '2322',
#   '504'],
#  174: ['1167',
#   '1526',
#   '87',
#   '3248',
#   '274',
#   '637',
#   '545',
#   '1133',
#   '505',
#   '833'],
#  175: ['1611',
#   '14',
#   '781',
#   '2165',
#   '730',
#   '1120',
#   '2271',
#   '1051',
#   '1810',
#   '2236'],
#  176: ['2289',
#   '235',
#   '1537',
#   '1446',
#   '562',
#   '1885',
#   '2324',
#   '1966',
#   '1188',
#   '101'],
#  177: ['879',
#   '328',
#   '1342',
#   '842',
#   '1999',
#   '2328',
#   '2279',
#   '1655',
#   '2327',
#   '2120'],
#  178: ['305',
#   '1614',
#   '203',
#   '2295',
#   '1317',
#   '2543',
#   '1915',
#   '3120',
#   '830',
#   '171'],
#  179: ['3436',
#   '697',
#   '2154',
#   '672',
#   '2292',
#   '630',
#   '2316',
#   '2234',
#   '33',
#   '2742'],
#  180: ['104',
#   '1753',
#   '69',
#   '1042',
#   '1923',
#   '3253',
#   '663',
#   '471',
#   '441',
#   '101'],
#  181: ['502',
#   '1495',
#   '546',
#   '3268',
#   '393',
#   '1681',
#   '1497',
#   '591',
#   '3440',
#   '839'],
#  182: ['1549',
#   '605',
#   '3436',
#   '3528',
#   '140',
#   '2316',
#   '2168',
#   '672',
#   '179',
#   '207'],
#  183: ['422',
#   '1369',
#   '280',
#   '230',
#   '1889',
#   '3249',
#   '286',
#   '662',
#   '985',
#   '2803'],
#  184: ['167',
#   '27',
#   '1529',
#   '672',
#   '730',
#   '2271',
#   '386',
#   '1114',
#   '2742',
#   '1040'],
#  185: ['338',
#   '1603',
#   '880',
#   '1037',
#   '1831',
#   '379',
#   '1779',
#   '2232',
#   '172',
#   '849'],
#  186: ['542', '743', '818', '3243', '203', '5', '2335', '305', '719', '518'],
#  187: ['322',
#   '1883',
#   '2282',
#   '1875',
#   '1425',
#   '2155',
#   '348',
#   '728',
#   '52',
#   '562'],
#  188: ['328',
#   '1342',
#   '1717',
#   '565',
#   '2120',
#   '1355',
#   '2004',
#   '177',
#   '3013',
#   '724'],
#  189: ['664',
#   '1820',
#   '843',
#   '660',
#   '2695',
#   '1118',
#   '545',
#   '1558',
#   '3321',
#   '1622'],
#  190: ['3728',
#   '1889',
#   '373',
#   '1358',
#   '2964',
#   '929',
#   '319',
#   '1631',
#   '448',
#   '561'],
#  191: ['1726',
#   '1363',
#   '2269',
#   '672',
#   '209',
#   '2234',
#   '386',
#   '193',
#   '526',
#   '1880'],
#  192: ['545',
#   '2317',
#   '1133',
#   '1855',
#   '843',
#   '3722',
#   '865',
#   '1311',
#   '274',
#   '660'],
#  193: ['2386',
#   '2269',
#   '1726',
#   '1522',
#   '640',
#   '847',
#   '92',
#   '430',
#   '672',
#   '1811'],
#  194: ['535',
#   '1486',
#   '1120',
#   '428',
#   '300',
#   '3246',
#   '3100',
#   '729',
#   '2127',
#   '1268'],
#  195: ['2558',
#   '1457',
#   '1593',
#   '237',
#   '1888',
#   '236',
#   '1353',
#   '1409',
#   '378',
#   '499'],
#  196: ['332',
#   '512',
#   '2448',
#   '426',
#   '3024',
#   '1924',
#   '2668',
#   '2377',
#   '1762',
#   '3662'],
#  197: ['167',
#   '730',
#   '271',
#   '729',
#   '2742',
#   '672',
#   '1044',
#   '617',
#   '2994',
#   '452'],
#  198: ['1527',
#   '1573',
#   '1372',
#   '2985',
#   '1876',
#   '1356',
#   '316',
#   '1396',
#   '1676',
#   '329'],
#  199: ['73',
#   '1951',
#   '1487',
#   '346',
#   '3549',
#   '715',
#   '1932',
#   '2565',
#   '242',
#   '1416'],
#  200: ['1430',
#   '1718',
#   '142',
#   '291',
#   '1798',
#   '3056',
#   '1427',
#   '651',
#   '2778',
#   '132'],
#  201: ['277', '184', '3457', '209', '1814', '672', '893', '191', '396', '887'],
#  202: ['630',
#   '2679',
#   '270',
#   '2154',
#   '3436',
#   '1043',
#   '672',
#   '2742',
#   '3103',
#   '660'],
#  203: ['305',
#   '719',
#   '1390',
#   '518',
#   '542',
#   '248',
#   '186',
#   '2335',
#   '2249',
#   '3120'],
#  204: ['20',
#   '694',
#   '1004',
#   '1497',
#   '360',
#   '485',
#   '315',
#   '1606',
#   '548',
#   '1382'],
#  205: ['1701',
#   '1279',
#   '1542',
#   '45',
#   '371',
#   '1476',
#   '224',
#   '3255',
#   '3261',
#   '878'],
#  206: ['985',
#   '1470',
#   '134',
#   '1865',
#   '791',
#   '2198',
#   '2909',
#   '3609',
#   '1315',
#   '1039'],
#  207: ['2316', '140', '3528', '46', '3436', '605', '697', '802', '270', '613'],
#  208: ['44', '1606', '533', '798', '809', '836', '849', '552', '459', '547'],
#  209: ['2269',
#   '1726',
#   '672',
#   '1522',
#   '981',
#   '2234',
#   '418',
#   '3382',
#   '679',
#   '3436'],
#  210: ['3236',
#   '383',
#   '967',
#   '416',
#   '458',
#   '996',
#   '553',
#   '3311',
#   '3644',
#   '1843'],
#  211: ['757',
#   '1759',
#   '3530',
#   '398',
#   '1859',
#   '1699',
#   '1719',
#   '1635',
#   '1411',
#   '824'],
#  212: ['430',
#   '843',
#   '2039',
#   '478',
#   '2244',
#   '2556',
#   '310',
#   '1167',
#   '87',
#   '243'],
#  213: ['306',
#   '1280',
#   '1041',
#   '1176',
#   '80',
#   '2610',
#   '1699',
#   '1719',
#   '2357',
#   '36'],
#  214: ['896',
#   '1117',
#   '2544',
#   '878',
#   '263',
#   '1860',
#   '2673',
#   '1893',
#   '2839',
#   '698'],
#  215: ['1535',
#   '1680',
#   '3378',
#   '1643',
#   '1357',
#   '534',
#   '1554',
#   '2570',
#   '302',
#   '1059'],
#  216: ['88', '333', '585', '719', '833', '2249', '784', '2335', '122', '2447'],
#  217: ['3502',
#   '2445',
#   '424',
#   '882',
#   '79',
#   '436',
#   '2778',
#   '1726',
#   '3376',
#   '92'],
#  218: ['3500',
#   '2252',
#   '122',
#   '472',
#   '4',
#   '719',
#   '585',
#   '1468',
#   '1915',
#   '3045'],
#  219: ['981',
#   '375',
#   '1905',
#   '2742',
#   '498',
#   '1366',
#   '386',
#   '209',
#   '672',
#   '2960'],
#  220: ['1324',
#   '1756',
#   '1771',
#   '606',
#   '1168',
#   '2461',
#   '1336',
#   '2514',
#   '1992',
#   '1988'],
#  222: ['1680',
#   '249',
#   '509',
#   '1498',
#   '534',
#   '2125',
#   '1059',
#   '1357',
#   '3426',
#   '1735'],
#  223: ['2355',
#   '2759',
#   '2599',
#   '2908',
#   '2997',
#   '2772',
#   '441',
#   '1060',
#   '2336',
#   '3543'],
#  224: ['351', '3261', '339', '838', '539', '597', '371', '357', '468', '2331'],
#  225: ['230',
#   '1841',
#   '1003',
#   '100',
#   '280',
#   '832',
#   '282',
#   '61',
#   '3249',
#   '2803'],
#  226: ['2556',
#   '3904',
#   '1915',
#   '601',
#   '790',
#   '3647',
#   '868',
#   '396',
#   '641',
#   '3376'],
#  227: ['459', '9', '548', '533', '1385', '786', '1792', '479', '3274', '1769'],
#  228: ['1133',
#   '660',
#   '3722',
#   '1558',
#   '234',
#   '1561',
#   '2317',
#   '505',
#   '2798',
#   '3031'],
#  229: ['230', '662', '280', '832', '1841', '16', '225', '1834', '1003', '454'],
#  230: ['832',
#   '280',
#   '225',
#   '1841',
#   '229',
#   '454',
#   '350',
#   '100',
#   '1003',
#   '1672'],
#  231: ['500',
#   '1614',
#   '333',
#   '2567',
#   '1425',
#   '248',
#   '2249',
#   '1485',
#   '3243',
#   '585'],
#  232: ['1885',
#   '1914',
#   '562',
#   '235',
#   '2289',
#   '1392',
#   '3108',
#   '348',
#   '1060',
#   '776'],
#  233: ['2712',
#   '2336',
#   '2434',
#   '2575',
#   '2333',
#   '3115',
#   '2688',
#   '2546',
#   '2607',
#   '2718'],
#  234: ['429',
#   '1133',
#   '1526',
#   '710',
#   '637',
#   '3243',
#   '542',
#   '818',
#   '1855',
#   '840'],
#  235: ['1885',
#   '2289',
#   '1914',
#   '562',
#   '1060',
#   '2324',
#   '1641',
#   '176',
#   '2359',
#   '441'],
#  236: ['1409', '7', '2558', '1457', '237', '1888', '289', '252', '378', '550'],
#  237: ['1409',
#   '1888',
#   '550',
#   '236',
#   '2558',
#   '252',
#   '1629',
#   '289',
#   '1593',
#   '378'],
#  238: ['986',
#   '1582',
#   '1015',
#   '1551',
#   '8',
#   '754',
#   '711',
#   '2103',
#   '484',
#   '2429'],
#  239: ['2354',
#   '48',
#   '2142',
#   '2559',
#   '888',
#   '673',
#   '244',
#   '1064',
#   '3400',
#   '3054'],
#  240: ['891',
#   '200',
#   '1430',
#   '3484',
#   '3562',
#   '1973',
#   '3322',
#   '103',
#   '2778',
#   '3596'],
#  241: ['1583',
#   '1764',
#   '2277',
#   '2059',
#   '531',
#   '1547',
#   '374',
#   '888',
#   '1538',
#   '1558'],
#  242: ['268',
#   '1035',
#   '2291',
#   '661',
#   '73',
#   '893',
#   '3538',
#   '199',
#   '138',
#   '1673'],
#  243: ['634',
#   '1558',
#   '1822',
#   '1707',
#   '2798',
#   '2799',
#   '2296',
#   '325',
#   '102',
#   '505'],
#  244: ['3400',
#   '2800',
#   '2559',
#   '888',
#   '975',
#   '2354',
#   '2092',
#   '3054',
#   '3945',
#   '2566'],
#  245: ['878',
#   '3295',
#   '758',
#   '2544',
#   '1504',
#   '1709',
#   '3382',
#   '1519',
#   '744',
#   '730'],
#  246: ['162',
#   '2677',
#   '1147',
#   '2909',
#   '1649',
#   '1361',
#   '556',
#   '2330',
#   '549',
#   '1470'],
#  247: ['265', '308', '1358', '25', '17', '36', '307', '994', '1280', '2357'],
#  248: ['2249',
#   '1614',
#   '333',
#   '231',
#   '203',
#   '719',
#   '1020',
#   '3258',
#   '252',
#   '2335'],
#  249: ['222',
#   '1680',
#   '1059',
#   '509',
#   '1735',
#   '3426',
#   '2125',
#   '802',
#   '1535',
#   '302'],
#  250: ['575',
#   '374',
#   '2953',
#   '881',
#   '1707',
#   '2036',
#   '1474',
#   '1005',
#   '267',
#   '2042'],
#  251: ['1825',
#   '3274',
#   '552',
#   '533',
#   '479',
#   '292',
#   '876',
#   '980',
#   '2334',
#   '1432'],
#  252: ['7',
#   '1457',
#   '2424',
#   '1569',
#   '1409',
#   '339',
#   '597',
#   '1888',
#   '539',
#   '708'],
#  253: ['382',
#   '724',
#   '2120',
#   '188',
#   '328',
#   '1339',
#   '1342',
#   '565',
#   '1717',
#   '1347'],
#  254: ['385', '167', '3374', '375', '1044', '359', '730', '726', '452', '197'],
#  255: ['2798',
#   '65',
#   '1133',
#   '2799',
#   '545',
#   '267',
#   '325',
#   '1855',
#   '1558',
#   '102'],
#  256: ['435',
#   '2053',
#   '2498',
#   '338',
#   '2408',
#   '185',
#   '2808',
#   '1603',
#   '196',
#   '788'],
#  257: ['1422',
#   '2267',
#   '1892',
#   '695',
#   '731',
#   '2803',
#   '350',
#   '1092',
#   '3151',
#   '427'],
#  258: ['1750',
#   '2053',
#   '546',
#   '2450',
#   '1882',
#   '2549',
#   '56',
#   '2498',
#   '173',
#   '880'],
#  259: ['1620',
#   '1647',
#   '2561',
#   '1598',
#   '521',
#   '463',
#   '22',
#   '2308',
#   '874',
#   '1791'],
#  260: ['1221',
#   '858',
#   '1196',
#   '1198',
#   '1210',
#   '1193',
#   '1214',
#   '1240',
#   '1206',
#   '1419'],
#  261: ['1271',
#   '805',
#   '3252',
#   '2218',
#   '1672',
#   '62',
#   '381',
#   '454',
#   '1177',
#   '848'],
#  262: ['531',
#   '1547',
#   '837',
#   '1012',
#   '917',
#   '2059',
#   '2083',
#   '515',
#   '2277',
#   '1919'],
#  263: ['878',
#   '398',
#   '1719',
#   '2674',
#   '1413',
#   '757',
#   '214',
#   '326',
#   '535',
#   '1187'],
#  264: ['730',
#   '3057',
#   '729',
#   '1369',
#   '1543',
#   '878',
#   '617',
#   '385',
#   '887',
#   '1908'],
#  265: ['17', '25', '58', '446', '1393', '1357', '3260', '1094', '36', '778'],
#  266: ['524',
#   '1600',
#   '1286',
#   '893',
#   '2106',
#   '1619',
#   '613',
#   '991',
#   '383',
#   '1735'],
#  267: ['3248',
#   '1133',
#   '818',
#   '833',
#   '747',
#   '545',
#   '1602',
#   '1474',
#   '1167',
#   '374'],
#  268: ['893',
#   '524',
#   '538',
#   '1673',
#   '242',
#   '144',
#   '481',
#   '1596',
#   '3173',
#   '3150'],
#  269: ['730',
#   '1051',
#   '477',
#   '261',
#   '1611',
#   '887',
#   '805',
#   '3252',
#   '1399',
#   '729'],
#  270: ['207',
#   '3436',
#   '202',
#   '2316',
#   '630',
#   '1735',
#   '2556',
#   '2154',
#   '2497',
#   '3103'],
#  271: ['491', '730', '197', '729', '1810', '282', '805', '175', '1672', '385'],
#  272: ['515',
#   '300',
#   '1633',
#   '3100',
#   '3271',
#   '337',
#   '1095',
#   '3260',
#   '1678',
#   '535'],
#  273: ['382',
#   '2120',
#   '177',
#   '724',
#   '2328',
#   '879',
#   '2279',
#   '1655',
#   '328',
#   '2327'],
#  274: ['374',
#   '545',
#   '174',
#   '310',
#   '1474',
#   '2953',
#   '234',
#   '2552',
#   '460',
#   '2317'],
#  275: ['719',
#   '2335',
#   '518',
#   '2249',
#   '203',
#   '135',
#   '3243',
#   '1550',
#   '312',
#   '1390'],
#  276: ['1593',
#   '1353',
#   '499',
#   '550',
#   '237',
#   '1409',
#   '2385',
#   '1629',
#   '1888',
#   '93'],
#  277: ['524',
#   '201',
#   '3173',
#   '3457',
#   '893',
#   '3513',
#   '1600',
#   '3594',
#   '3382',
#   '120'],
#  278: ['2350',
#   '2567',
#   '518',
#   '305',
#   '719',
#   '411',
#   '248',
#   '830',
#   '333',
#   '1915'],
#  279: ['730',
#   '2611',
#   '729',
#   '428',
#   '1038',
#   '1117',
#   '385',
#   '281',
#   '1531',
#   '2994'],
#  280: ['832', '230', '225', '1841', '454', '100', '481', '22', '229', '805'],
#  281: ['3100',
#   '300',
#   '475',
#   '1271',
#   '1682',
#   '3271',
#   '3246',
#   '272',
#   '1678',
#   '508'],
#  282: ['14', '1727', '369', '225', '57', '3502', '1399', '491', '887', '2432'],
#  283: ['874',
#   '732',
#   '2308',
#   '1501',
#   '1804',
#   '2280',
#   '391',
#   '3272',
#   '716',
#   '1799'],
#  284: [],
#  285: [],
#  286: ['398',
#   '1470',
#   '3237',
#   '985',
#   '134',
#   '1664',
#   '1039',
#   '2930',
#   '2909',
#   '2538'],
#  287: ['821',
#   '7',
#   '378',
#   '708',
#   '1441',
#   '1569',
#   '2597',
#   '2331',
#   '1593',
#   '1629'],
#  288: ['1518',
#   '1792',
#   '1769',
#   '2334',
#   '494',
#   '1047',
#   '89',
#   '2273',
#   '292',
#   '3274'],
#  289: ['7', '1409', '236', '378', '468', '550', '1457', '252', '237', '2424'],
#  290: ['1213',
#   '1041',
#   '50',
#   '306',
#   '2357',
#   '1034',
#   '1859',
#   '213',
#   '2360',
#   '1533'],
#  291: ['1430',
#   '2778',
#   '200',
#   '540',
#   '3063',
#   '1718',
#   '1427',
#   '782',
#   '3056',
#   '132'],
#  292: ['1792',
#   '494',
#   '1833',
#   '288',
#   '3274',
#   '165',
#   '2334',
#   '376',
#   '3020',
#   '1385'],
#  293: ['47',
#   '866',
#   '2391',
#   '1089',
#   '1358',
#   '2542',
#   '2268',
#   '1466',
#   '1729',
#   '608'],
#  294: ['1353',
#   '2385',
#   '1593',
#   '1888',
#   '378',
#   '276',
#   '691',
#   '1409',
#   '236',
#   '237'],
#  295: ['378',
#   '195',
#   '1457',
#   '1773',
#   '2558',
#   '550',
#   '1915',
#   '1821',
#   '597',
#   '294'],
#  296: ['1213',
#   '608',
#   '50',
#   '318',
#   '593',
#   '1089',
#   '1358',
#   '36',
#   '1719',
#   '2501'],
#  297: ['2760',
#   '2360',
#   '576',
#   '758',
#   '306',
#   '358',
#   '456',
#   '3295',
#   '923',
#   '3894'],
#  298: ['776',
#   '1966',
#   '1914',
#   '1537',
#   '863',
#   '68',
#   '1449',
#   '96',
#   '1180',
#   '583'],
#  299: ['43',
#   '2686',
#   '314',
#   '2443',
#   '2692',
#   '2585',
#   '2702',
#   '2395',
#   '2310',
#   '3100'],
#  300: ['3100',
#   '272',
#   '3271',
#   '1682',
#   '1678',
#   '337',
#   '1357',
#   '3246',
#   '3260',
#   '475'],
#  301: ['729',
#   '1650',
#   '1357',
#   '302',
#   '2943',
#   '85',
#   '2127',
#   '1643',
#   '509',
#   '1633'],
#  302: ['1643',
#   '1680',
#   '249',
#   '3426',
#   '1357',
#   '1059',
#   '1897',
#   '2943',
#   '509',
#   '2570'],
#  303: ['996',
#   '1379',
#   '368',
#   '1049',
#   '3236',
#   '1378',
#   '383',
#   '3277',
#   '552',
#   '210'],
#  304: ['2007',
#   '2811',
#   '1915',
#   '573',
#   '753',
#   '1773',
#   '2849',
#   '666',
#   '3106',
#   '445'],
#  305: ['203', '830', '1390', '719', '186', '818', '984', '743', '518', '312'],
#  306: ['1041',
#   '2360',
#   '213',
#   '1280',
#   '1719',
#   '1176',
#   '2357',
#   '1859',
#   '36',
#   '308'],
#  307: ['1176',
#   '308',
#   '994',
#   '36',
#   '1041',
#   '1095',
#   '1719',
#   '1280',
#   '1245',
#   '1635'],
#  308: ['1245',
#   '307',
#   '994',
#   '1095',
#   '36',
#   '1635',
#   '3260',
#   '1730',
#   '334',
#   '1719'],
#  309: ['2609',
#   '2833',
#   '49',
#   '2218',
#   '621',
#   '523',
#   '2442',
#   '698',
#   '3817',
#   '2619'],
#  310: ['274',
#   '87',
#   '1558',
#   '2039',
#   '1707',
#   '2953',
#   '2036',
#   '243',
#   '1474',
#   '38'],
#  311: ['763',
#   '3321',
#   '1820',
#   '815',
#   '3280',
#   '1165',
#   '1720',
#   '644',
#   '133',
#   '591'],
#  312: ['818',
#   '2335',
#   '833',
#   '719',
#   '784',
#   '429',
#   '1133',
#   '518',
#   '1461',
#   '275'],
#  313: ['2089',
#   '2800',
#   '1907',
#   '3400',
#   '13',
#   '2090',
#   '1064',
#   '2092',
#   '888',
#   '2876'],
#  314: ['299',
#   '43',
#   '529',
#   '2686',
#   '2395',
#   '2700',
#   '2070',
#   '308',
#   '3117',
#   '475'],
#  315: ['20', '544', '9', '1752', '485', '204', '694', '1004', '1382', '548'],
#  316: ['329',
#   '2094',
#   '1372',
#   '2393',
#   '1676',
#   '442',
#   '1876',
#   '1527',
#   '2641',
#   '1573'],
#  317: ['367',
#   '3466',
#   '1654',
#   '1848',
#   '2015',
#   '1702',
#   '586',
#   '1588',
#   '2',
#   '60'],
#  318: ['296', '527', '593', '1213', '1280', '306', '1041', '50', '213', '608'],
#  319: ['373',
#   '1358',
#   '1889',
#   '561',
#   '3634',
#   '16',
#   '1834',
#   '1343',
#   '3551',
#   '628'],
#  320: ['746',
#   '1783',
#   '2066',
#   '1344',
#   '1153',
#   '2727',
#   '164',
#   '707',
#   '1154',
#   '3292'],
#  321: ['2610',
#   '1730',
#   '515',
#   '2839',
#   '30',
#   '90',
#   '523',
#   '3295',
#   '1759',
#   '1719'],
#  322: ['52',
#   '45',
#   '2282',
#   '1060',
#   '562',
#   '3060',
#   '3255',
#   '1883',
#   '1747',
#   '348'],
#  324: ['1817',
#   '1677',
#   '84',
#   '2007',
#   '1038',
#   '1746',
#   '305',
#   '1915',
#   '1773',
#   '863'],
#  325: ['2798',
#   '2799',
#   '867',
#   '243',
#   '2953',
#   '374',
#   '470',
#   '65',
#   '1133',
#   '267'],
#  326: ['1176',
#   '334',
#   '1719',
#   '2610',
#   '1058',
#   '2673',
#   '1533',
#   '307',
#   '744',
#   '263'],
#  327: ['2986',
#   '1591',
#   '173',
#   '2808',
#   '504',
#   '172',
#   '1831',
#   '1882',
#   '379',
#   '405'],
#  328: ['188',
#   '842',
#   '177',
#   '2120',
#   '1342',
#   '1999',
#   '2004',
#   '879',
#   '382',
#   '2328'],
#  329: ['2094',
#   '316',
#   '1372',
#   '2393',
#   '442',
#   '1527',
#   '1676',
#   '1375',
#   '1876',
#   '2641'],
#  330: ['2004',
#   '3264',
#   '177',
#   '3013',
#   '879',
#   '1771',
#   '3693',
#   '1168',
#   '2328',
#   '842'],
#  331: ['679',
#   '1651',
#   '847',
#   '3382',
#   '630',
#   '526',
#   '2234',
#   '138',
#   '385',
#   '730'],
#  332: ['512',
#   '196',
#   '426',
#   '2377',
#   '1924',
#   '1762',
#   '3662',
#   '1334',
#   '3024',
#   '1692'],
#  333: ['2335',
#   '231',
#   '450',
#   '1614',
#   '2249',
#   '248',
#   '500',
#   '2567',
#   '3258',
#   '719'],
#  334: ['1594',
#   '1245',
#   '1719',
#   '308',
#   '1635',
#   '1095',
#   '535',
#   '1041',
#   '3260',
#   '326'],
#  335: ['2267',
#   '695',
#   '1892',
#   '696',
#   '1422',
#   '731',
#   '1675',
#   '229',
#   '1841',
#   '1472'],
#  336: ['760',
#   '2106',
#   '1898',
#   '3339',
#   '1619',
#   '991',
#   '3066',
#   '155',
#   '2818',
#   '647'],
#  337: ['1682',
#   '300',
#   '3100',
#   '3246',
#   '3260',
#   '272',
#   '1635',
#   '1095',
#   '778',
#   '1245'],
#  338: ['185',
#   '1603',
#   '2232',
#   '880',
#   '1779',
#   '1037',
#   '76',
#   '1831',
#   '172',
#   '849'],
#  339: ['597', '1569', '2424', '539', '2671', '708', '852', '7', '1777', '252'],
#  340: ['2429',
#   '1615',
#   '2822',
#   '1015',
#   '158',
#   '2103',
#   '590',
#   '1899',
#   '1605',
#   '2277'],
#  341: ['2839',
#   '3260',
#   '263',
#   '326',
#   '3271',
#   '456',
#   '535',
#   '36',
#   '307',
#   '2964'],
#  342: ['357',
#   '440',
#   '2108',
#   '497',
#   '471',
#   '838',
#   '3358',
#   '2671',
#   '3108',
#   '39'],
#  343: ['575',
#   '2277',
#   '310',
#   '2042',
#   '584',
#   '13',
#   '241',
#   '837',
#   '2032',
#   '3458'],
#  344: ['410',
#   '2124',
#   '333',
#   '413',
#   '585',
#   '3254',
#   '414',
#   '1541',
#   '2567',
#   '1503'],
#  345: ['2439',
#   '412',
#   '2124',
#   '45',
#   '3255',
#   '2321',
#   '1733',
#   '1060',
#   '2171',
#   '3060'],
#  346: ['199',
#   '3105',
#   '1416',
#   '73',
#   '1487',
#   '595',
#   '1087',
#   '2565',
#   '2725',
#   '3549'],
#  347: ['757',
#   '729',
#   '730',
#   '1486',
#   '1519',
#   '2557',
#   '2619',
#   '1121',
#   '398',
#   '568'],
#  348: ['125',
#   '2359',
#   '1641',
#   '1883',
#   '3108',
#   '2321',
#   '1060',
#   '52',
#   '3060',
#   '1449'],
#  349: ['733',
#   '10',
#   '1370',
#   '1552',
#   '2353',
#   '2058',
#   '1049',
#   '3256',
#   '2006',
#   '1722'],
#  350: ['1892',
#   '230',
#   '1422',
#   '832',
#   '1841',
#   '100',
#   '695',
#   '1003',
#   '1805',
#   '22'],
#  351: ['468',
#   '224',
#   '1888',
#   '2506',
#   '7',
#   '1569',
#   '339',
#   '1409',
#   '3261',
#   '2331'],
#  352: ['514',
#   '1875',
#   '104',
#   '562',
#   '2155',
#   '187',
#   '441',
#   '3253',
#   '1923',
#   '1641'],
#  353: ['1722',
#   '163',
#   '494',
#   '2273',
#   '1597',
#   '1518',
#   '288',
#   '1370',
#   '165',
#   '292'],
#  354: ['1836',
#   '3502',
#   '175',
#   '1051',
#   '31',
#   '1727',
#   '1611',
#   '282',
#   '724',
#   '1027'],
#  355: ['2953',
#   '374',
#   '1526',
#   '3248',
#   '1133',
#   '1588',
#   '2042',
#   '1005',
#   '881',
#   '1474'],
#  356: ['1184',
#   '151',
#   '471',
#   '539',
#   '3108',
#   '3253',
#   '1183',
#   '3448',
#   '2671',
#   '440'],
#  357: ['2108',
#   '440',
#   '342',
#   '497',
#   '39',
#   '471',
#   '838',
#   '3358',
#   '3108',
#   '1777'],
#  358: ['805',
#   '3270',
#   '175',
#   '1401',
#   '726',
#   '2309',
#   '2271',
#   '381',
#   '2165',
#   '97'],
#  359: ['35',
#   '3106',
#   '1735',
#   '1139',
#   '730',
#   '613',
#   '375',
#   '254',
#   '1600',
#   '1888'],
#  360: ['438', '485', '420', '204', '694', '20', '1431', '1604', '502', '315'],
#  361: ['3259',
#   '802',
#   '1735',
#   '605',
#   '46',
#   '3528',
#   '1835',
#   '105',
#   '2297',
#   '222'],
#  362: ['1015',
#   '986',
#   '2822',
#   '158',
#   '2045',
#   '1894',
#   '2103',
#   '1582',
#   '609',
#   '8'],
#  363: ['134',
#   '985',
#   '1470',
#   '2930',
#   '2909',
#   '791',
#   '602',
#   '1315',
#   '1039',
#   '769'],
#  364: ['595',
#   '1907',
#   '783',
#   '2687',
#   '2096',
#   '1022',
#   '1029',
#   '2078',
#   '588',
#   '1566'],
#  365: ['1027',
#   '536',
#   '781',
#   '3502',
#   '452',
#   '887',
#   '2432',
#   '3425',
#   '1727',
#   '31'],
#  366: ['3918',
#   '3917',
#   '188',
#   '1327',
#   '328',
#   '1973',
#   '70',
#   '3930',
#   '1970',
#   '1168'],
#  367: ['317',
#   '3466',
#   '2100',
#   '1654',
#   '2622',
#   '104',
#   '2797',
#   '1500',
#   '2174',
#   '852'],
#  368: ['1378',
#   '1379',
#   '303',
#   '996',
#   '552',
#   '380',
#   '3236',
#   '3277',
#   '383',
#   '2879'],
#  369: ['887',
#   '282',
#   '371',
#   '2271',
#   '730',
#   '1543',
#   '14',
#   '2283',
#   '2619',
#   '537'],
#  370: ['3869',
#   '2431',
#   '542',
#   '2335',
#   '5',
#   '1526',
#   '518',
#   '719',
#   '2249',
#   '203'],
#  371: ['1701',
#   '537',
#   '2252',
#   '372',
#   '224',
#   '1614',
#   '3500',
#   '1476',
#   '369',
#   '450'],
#  372: ['1884',
#   '1476',
#   '1485',
#   '1020',
#   '1614',
#   '371',
#   '500',
#   '2252',
#   '3261',
#   '708'],
#  373: ['1834',
#   '319',
#   '1343',
#   '2391',
#   '3728',
#   '2819',
#   '47',
#   '1358',
#   '628',
#   '1249'],
#  374: ['1474',
#   '2953',
#   '355',
#   '2036',
#   '1005',
#   '1707',
#   '274',
#   '3248',
#   '87',
#   '575'],
#  375: ['672',
#   '1651',
#   '2234',
#   '2742',
#   '167',
#   '1880',
#   '3218',
#   '2960',
#   '3382',
#   '895'],
#  376: ['494',
#   '1792',
#   '1769',
#   '786',
#   '2334',
#   '292',
#   '1687',
#   '1754',
#   '1616',
#   '288'],
#  377: ['1722',
#   '163',
#   '1408',
#   '3256',
#   '1370',
#   '2058',
#   '2353',
#   '474',
#   '555',
#   '2006'],
#  378: ['1457',
#   '2558',
#   '236',
#   '289',
#   '1409',
#   '1888',
#   '252',
#   '7',
#   '1821',
#   '1593'],
#  379: ['1037',
#   '504',
#   '849',
#   '2808',
#   '1831',
#   '173',
#   '2094',
#   '442',
#   '172',
#   '2322'],
#  380: ['2006',
#   '1049',
#   '2406',
#   '2879',
#   '552',
#   '1722',
#   '112',
#   '10',
#   '733',
#   '1101'],
#  381: ['805',
#   '3252',
#   '1672',
#   '62',
#   '3270',
#   '1727',
#   '1678',
#   '261',
#   '887',
#   '2218'],
#  382: ['724',
#   '2120',
#   '273',
#   '177',
#   '253',
#   '328',
#   '1342',
#   '879',
#   '2328',
#   '188'],
#  383: ['553',
#   '210',
#   '3236',
#   '416',
#   '3277',
#   '3487',
#   '3508',
#   '2401',
#   '303',
#   '1843'],
#  384: ['996',
#   '533',
#   '548',
#   '3165',
#   '459',
#   '204',
#   '479',
#   '227',
#   '1599',
#   '2756'],
#  385: ['730', '167', '729', '878', '2911', '398', '1139', '844', '264', '617'],
#  386: ['1880',
#   '27',
#   '1040',
#   '567',
#   '191',
#   '2960',
#   '2486',
#   '526',
#   '1811',
#   '375'],
#  387: ['3208',
#   '1858',
#   '2879',
#   '459',
#   '2582',
#   '1866',
#   '2170',
#   '544',
#   '485',
#   '876'],
#  388: ['3246',
#   '1095',
#   '281',
#   '515',
#   '2442',
#   '475',
#   '1633',
#   '300',
#   '1245',
#   '398'],
#  389: ['398',
#   '1094',
#   '1183',
#   '2610',
#   '475',
#   '2839',
#   '1357',
#   '787',
#   '3260',
#   '757'],
#  390: ['2993',
#   '3633',
#   '1572',
#   '1164',
#   '1858',
#   '2136',
#   '1429',
#   '3507',
#   '21',
#   '2946'],
#  391: ['2112',
#   '2231',
#   '1061',
#   '1799',
#   '1620',
#   '1671',
#   '259',
#   '81',
#   '2281',
#   '730'],
#  392: ['1812',
#   '2673',
#   '2101',
#   '238',
#   '2226',
#   '2632',
#   '262',
#   '2063',
#   '1547',
#   '3575'],
#  393: ['1681',
#   '1497',
#   '591',
#   '2196',
#   '502',
#   '667',
#   '1626',
#   '839',
#   '3268',
#   '546'],
#  394: ['1181',
#   '1102',
#   '876',
#   '1429',
#   '2258',
#   '1134',
#   '1112',
#   '2307',
#   '507',
#   '1796'],
#  395: [],
#  396: ['2619',
#   '2218',
#   '1773',
#   '1510',
#   '878',
#   '1915',
#   '138',
#   '1908',
#   '3748',
#   '865'],
#  397: ['1990',
#   '2462',
#   '2452',
#   '3085',
#   '1989',
#   '606',
#   '2464',
#   '1433',
#   '1324',
#   '1328'],
#  398: ['2127',
#   '878',
#   '286',
#   '1486',
#   '787',
#   '730',
#   '2824',
#   '757',
#   '134',
#   '2930'],
#  399: [],
#  400: [],
#  401: ['3772',
#   '3472',
#   '3337',
#   '3460',
#   '3321',
#   '3575',
#   '3025',
#   '1724',
#   '2783',
#   '3762'],
#  402: ['3377',
#   '1709',
#   '1908',
#   '868',
#   '3530',
#   '730',
#   '2557',
#   '1714',
#   '3413',
#   '2619'],
#  403: [],
#  404: ['1470',
#   '3237',
#   '2198',
#   '2909',
#   '134',
#   '985',
#   '791',
#   '2677',
#   '1138',
#   '1039'],
#  405: ['1882',
#   '546',
#   '692',
#   '2808',
#   '2986',
#   '172',
#   '2549',
#   '737',
#   '1591',
#   '173'],
#  406: ['526', '375', '567', '1149', '386', '682', '2619', '347', '895', '730'],
#  407: ['2713',
#   '2719',
#   '2606',
#   '2995',
#   '2676',
#   '879',
#   '1999',
#   '177',
#   '2328',
#   '1717'],
#  408: ['1609',
#   '409',
#   '375',
#   '2486',
#   '491',
#   '2960',
#   '386',
#   '726',
#   '175',
#   '3218'],
#  409: ['408',
#   '1459',
#   '2486',
#   '2124',
#   '344',
#   '410',
#   '412',
#   '2439',
#   '999',
#   '1268'],
#  410: ['344',
#   '2124',
#   '1541',
#   '414',
#   '413',
#   '445',
#   '333',
#   '1614',
#   '1503',
#   '2133'],
#  411: ['1133',
#   '518',
#   '2350',
#   '3722',
#   '1561',
#   '278',
#   '542',
#   '2335',
#   '865',
#   '545'],
#  412: ['2439',
#   '345',
#   '3250',
#   '1733',
#   '2611',
#   '2442',
#   '698',
#   '1635',
#   '515',
#   '523'],
#  413: ['414',
#   '344',
#   '410',
#   '833',
#   '3258',
#   '1541',
#   '333',
#   '88',
#   '1592',
#   '2249'],
#  414: ['413',
#   '410',
#   '344',
#   '1541',
#   '333',
#   '1614',
#   '2765',
#   '2124',
#   '865',
#   '1592'],
#  415: ['1021', '540', '1461', '637', '374', '23', '3063', '132', '355', '743'],
#  416: ['3236',
#   '210',
#   '458',
#   '432',
#   '383',
#   '967',
#   '2055',
#   '487',
#   '3277',
#   '2401'],
#  417: ['471',
#   '342',
#   '2108',
#   '1441',
#   '1777',
#   '357',
#   '3261',
#   '2331',
#   '708',
#   '852'],
#  418: ['209', '1726', '2269', '331', '847', '1811', '193', '701', '61', '536'],
#  419: ['65', '1679', '710', '54', '2798', '87', '93', '2953', '1167', '88'],
#  420: ['1431', '360', '438', '485', '153', '20', '204', '315', '1866', '88'],
#  421: ['1582',
#   '808',
#   '158',
#   '3672',
#   '2057',
#   '986',
#   '1015',
#   '238',
#   '8',
#   '1031'],
#  422: ['2803', '3249', '18', '662', '100', '436', '1841', '992', '23', '3063'],
#  423: ['1438',
#   '1687',
#   '95',
#   '1769',
#   '533',
#   '1752',
#   '1792',
#   '836',
#   '479',
#   '1432'],
#  424: ['510',
#   '282',
#   '1726',
#   '3141',
#   '3257',
#   '1027',
#   '209',
#   '418',
#   '679',
#   '78'],
#  425: ['509',
#   '1535',
#   '215',
#   '3426',
#   '302',
#   '1733',
#   '1357',
#   '987',
#   '1059',
#   '1643'],
#  426: ['512',
#   '332',
#   '196',
#   '1334',
#   '3660',
#   '76',
#   '2377',
#   '1924',
#   '3024',
#   '1762'],
#  427: ['3151',
#   '257',
#   '2338',
#   '1644',
#   '3220',
#   '3257',
#   '2945',
#   '1556',
#   '815',
#   '138'],
#  428: ['3100',
#   '281',
#   '194',
#   '3246',
#   '477',
#   '1635',
#   '300',
#   '1271',
#   '3271',
#   '1682'],
#  429: ['784', '542', '710', '234', '818', '2335', '1526', '719', '603', '518'],
#  430: ['193',
#   '1726',
#   '31',
#   '2269',
#   '212',
#   '3141',
#   '3502',
#   '1852',
#   '1363',
#   '1027'],
#  431: ['1061',
#   '2268',
#   '1729',
#   '1466',
#   '1799',
#   '1404',
#   '2112',
#   '2425',
#   '2231',
#   '1589'],
#  432: ['2055',
#   '416',
#   '487',
#   '2478',
#   '1133',
#   '234',
#   '429',
#   '2335',
#   '3313',
#   '3236'],
#  433: ['505',
#   '2335',
#   '1167',
#   '174',
#   '542',
#   '2296',
#   '1665',
#   '234',
#   '818',
#   '1839'],
#  434: ['464',
#   '44',
#   '809',
#   '2616',
#   '2002',
#   '736',
#   '1552',
#   '1587',
#   '208',
#   '170'],
#  435: ['256',
#   '2408',
#   '2053',
#   '185',
#   '338',
#   '379',
#   '1603',
#   '788',
#   '196',
#   '1391'],
#  436: ['61', '100', '1515', '79', '1841', '422', '2803', '3063', '225', '882'],
#  437: ['102',
#   '2798',
#   '1839',
#   '2799',
#   '867',
#   '1558',
#   '65',
#   '267',
#   '419',
#   '2552'],
#  438: ['360', '1431', '420', '1604', '886', '485', '20', '694', '9', '315'],
#  439: ['868',
#   '2213',
#   '133',
#   '975',
#   '3172',
#   '2217',
#   '3776',
#   '1142',
#   '2800',
#   '2876'],
#  440: ['357',
#   '2108',
#   '342',
#   '471',
#   '3358',
#   '1777',
#   '838',
#   '2671',
#   '497',
#   '39'],
#  441: ['1641',
#   '2321',
#   '2359',
#   '1060',
#   '1923',
#   '125',
#   '1885',
#   '3253',
#   '562',
#   '235'],
#  442: ['1876',
#   '2094',
#   '379',
#   '316',
#   '329',
#   '3697',
#   '2393',
#   '1037',
#   '504',
#   '1391'],
#  443: ['985',
#   '134',
#   '1470',
#   '791',
#   '1039',
#   '3237',
#   '2909',
#   '1138',
#   '2198',
#   '2824'],
#  444: ['64',
#   '1855',
#   '276',
#   '1773',
#   '2385',
#   '499',
#   '1353',
#   '679',
#   '545',
#   '505'],
#  445: ['542', '1461', '5', '410', '1614', '312', '719', '1167', '174', '1020'],
#  446: ['17', '265', '58', '25', '1094', '1357', '3260', '534', '1277', '28'],
#  447: ['2510',
#   '1666',
#   '1593',
#   '638',
#   '118',
#   '499',
#   '276',
#   '378',
#   '195',
#   '1632'],
#  448: ['3246',
#   '1095',
#   '1594',
#   '3260',
#   '1245',
#   '778',
#   '515',
#   '1704',
#   '36',
#   '535'],
#  449: ['663',
#   '1454',
#   '1904',
#   '69',
#   '700',
#   '2282',
#   '2155',
#   '180',
#   '441',
#   '1753'],
#  450: ['2447',
#   '2252',
#   '333',
#   '2249',
#   '371',
#   '3500',
#   '537',
#   '2567',
#   '4',
#   '372'],
#  451: ['2024',
#   '3386',
#   '113',
#   '138',
#   '350',
#   '2875',
#   '2583',
#   '1464',
#   '695',
#   '1459'],
#  452: ['580', '729', '887', '2341', '730', '1177', '35', '781', '55', '365'],
#  453: ['2567',
#   '333',
#   '585',
#   '231',
#   '278',
#   '542',
#   '708',
#   '550',
#   '1133',
#   '2195'],
#  454: ['230', '832', '280', '481', '16', '261', '628', '1672', '225', '229'],
#  455: ['169',
#   '2429',
#   '1595',
#   '158',
#   '577',
#   '609',
#   '1359',
#   '484',
#   '2162',
#   '168'],
#  456: ['1245',
#   '1594',
#   '1095',
#   '448',
#   '398',
#   '3246',
#   '1759',
#   '308',
#   '2760',
#   '1635'],
#  457: ['1610',
#   '3267',
#   '474',
#   '6',
#   '1912',
#   '3418',
#   '2571',
#   '589',
#   '1036',
#   '2058'],
#  458: ['3236',
#   '416',
#   '210',
#   '3122',
#   '967',
#   '1843',
#   '167',
#   '572',
#   '3644',
#   '383'],
#  459: ['227', '544', '9', '533', '315', '1438', '3208', '208', '2625', '548'],
#  460: ['274',
#   '1839',
#   '2296',
#   '2953',
#   '3248',
#   '4',
#   '1133',
#   '3031',
#   '87',
#   '833'],
#  461: ['1680', '509', '249', '85', '222', '1897', '1735', '270', '302', '802'],
#  462: ['44', '704', '798', '1606', '591', '15', '1681', '836', '1591', '208'],
#  463: ['1598',
#   '1686',
#   '1620',
#   '259',
#   '22',
#   '79',
#   '1647',
#   '2561',
#   '1791',
#   '1675'],
#  464: ['434', '44', '1552', '809', '798', '1687', '170', '547', '836', '95'],
#  465: ['2427',
#   '1586',
#   '991',
#   '1408',
#   '2106',
#   '3441',
#   '292',
#   '2476',
#   '3020',
#   '1619'],
#  466: ['1586',
#   '1616',
#   '1391',
#   '485',
#   '516',
#   '2815',
#   '552',
#   '3441',
#   '1488',
#   '688'],
#  467: ['69',
#   '1753',
#   '633',
#   '2999',
#   '2282',
#   '449',
#   '235',
#   '187',
#   '1904',
#   '1923'],
#  468: ['2424', '539', '7', '339', '1569', '597', '852', '289', '1409', '351'],
#  469: ['3528',
#   '1735',
#   '509',
#   '46',
#   '2801',
#   '730',
#   '1782',
#   '613',
#   '781',
#   '2062'],
#  470: ['1863',
#   '843',
#   '325',
#   '1731',
#   '3774',
#   '3043',
#   '2798',
#   '243',
#   '3031',
#   '545'],
#  471: ['357',
#   '342',
#   '440',
#   '2108',
#   '3358',
#   '497',
#   '3108',
#   '1777',
#   '2671',
#   '52'],
#  472: ['765', '4', '537', '3248', '2447', '679', '195', '2252', '518', '218'],
#  473: ['1445',
#   '157',
#   '688',
#   '516',
#   '545',
#   '466',
#   '2953',
#   '2817',
#   '1855',
#   '174'],
#  474: ['1610',
#   '2058',
#   '3267',
#   '2353',
#   '6',
#   '3256',
#   '457',
#   '3418',
#   '163',
#   '1480'],
#  475: ['3100',
#   '1682',
#   '300',
#   '281',
#   '1678',
#   '3271',
#   '3246',
#   '1095',
#   '1633',
#   '535'],
#  476: ['398',
#   '1486',
#   '45',
#   '1454',
#   '1875',
#   '1279',
#   '729',
#   '1437',
#   '1051',
#   '730'],
#  477: ['1271',
#   '1810',
#   '3100',
#   '428',
#   '1672',
#   '1120',
#   '1678',
#   '3252',
#   '1633',
#   '805'],
#  478: ['2296',
#   '3463',
#   '1133',
#   '505',
#   '305',
#   '1390',
#   '747',
#   '545',
#   '2169',
#   '237'],
#  479: ['533', '548', '3274', '227', '9', '485', '423', '1687', '315', '1432'],
#  480: ['1580',
#   '1356',
#   '1129',
#   '1527',
#   '1372',
#   '2916',
#   '2529',
#   '589',
#   '1376',
#   '1573'],
#  481: ['454', '280', '230', '832', '100', '225', '893', '229', '482', '1003'],
#  482: ['1889',
#   '481',
#   '1343',
#   '18',
#   '1249',
#   '1661',
#   '662',
#   '16',
#   '373',
#   '3947'],
#  483: ['2357',
#   '3260',
#   '515',
#   '3246',
#   '2966',
#   '2994',
#   '1719',
#   '1594',
#   '448',
#   '80'],
#  484: ['169',
#   '455',
#   '238',
#   '1538',
#   '56',
#   '1551',
#   '575',
#   '609',
#   '1005',
#   '1826'],
#  485: ['360', '420', '315', '204', '1431', '1604', '544', '20', '438', '479'],
#  486: ['312',
#   '1133',
#   '186',
#   '2335',
#   '1461',
#   '267',
#   '1167',
#   '3248',
#   '765',
#   '747'],
#  487: ['432',
#   '3236',
#   '416',
#   '3025',
#   '2055',
#   '967',
#   '383',
#   '210',
#   '2799',
#   '12'],
#  488: ['729',
#   '887',
#   '506',
#   '730',
#   '452',
#   '1051',
#   '369',
#   '1543',
#   '1369',
#   '1611'],
#  489: ['818', '429', '267', '1133', '542', '833', '1526', '545', '135', '234'],
#  490: ['3249',
#   '2803',
#   '662',
#   '230',
#   '1841',
#   '422',
#   '3686',
#   '18',
#   '225',
#   '229'],
#  491: ['805',
#   '2271',
#   '1027',
#   '31',
#   '282',
#   '2250',
#   '2236',
#   '14',
#   '3502',
#   '175'],
#  492: ['2583',
#   '1689',
#   '1464',
#   '513',
#   '1711',
#   '52',
#   '2024',
#   '1732',
#   '1892',
#   '1414'],
#  493: ['2278',
#   '6',
#   '3418',
#   '1785',
#   '555',
#   '507',
#   '112',
#   '2912',
#   '2058',
#   '474'],
#  494: ['1792',
#   '165',
#   '2273',
#   '288',
#   '2334',
#   '376',
#   '292',
#   '1518',
#   '89',
#   '1769'],
#  495: ['3803',
#   '3194',
#   '2131',
#   '2074',
#   '3655',
#   '3813',
#   '2866',
#   '2730',
#   '3167',
#   '1161'],
#  496: ['1773',
#   '583',
#   '2999',
#   '1734',
#   '1903',
#   '396',
#   '129',
#   '824',
#   '1749',
#   '3530'],
#  497: ['357',
#   '342',
#   '2108',
#   '39',
#   '3358',
#   '440',
#   '3108',
#   '471',
#   '1188',
#   '838'],
#  498: ['802',
#   '1735',
#   '182',
#   '605',
#   '351',
#   '613',
#   '1498',
#   '140',
#   '219',
#   '3259'],
#  499: ['276',
#   '1593',
#   '195',
#   '447',
#   '2510',
#   '1353',
#   '1550',
#   '237',
#   '2385',
#   '1463'],
#  500: ['1485',
#   '1020',
#   '1614',
#   '2567',
#   '231',
#   '141',
#   '333',
#   '1042',
#   '597',
#   '1425'],
#  501: ['2357',
#   '1719',
#   '1245',
#   '1859',
#   '1635',
#   '334',
#   '308',
#   '515',
#   '862',
#   '1594'],
#  502: ['1497',
#   '2835',
# ...
#   '2887',
#   '3026'],
#  844: ['385',
#   '878',
#   '167',
#   '398',
#   '1504',
#   '264',
#   '2127',
#   '1908',
#   '2544',
#   '729'],
#  845: [],
#  846: ['398', '1486', '90', '308', '381', '286', '385', '1437', '730', '456'],
#  847: ['672',
#   '895',
#   '2850',
#   '331',
#   '148',
#   '193',
#   '2911',
#   '3607',
#   '526',
#   '3382'],
#  848: ['887',
#   '1758',
#   '3252',
#   '805',
#   '508',
#   '685',
#   '1709',
#   '730',
#   '2218',
#   '261'],
#  849: ['1831',
#   '1037',
#   '1591',
#   '379',
#   '2808',
#   '173',
#   '504',
#   '172',
#   '1779',
#   '2094'],
#  850: ['2332',
#   '1501',
#   '1809',
#   '2129',
#   '1859',
#   '59',
#   '3123',
#   '2503',
#   '1533',
#   '1905'],
#  851: ['147', '94', '781', '1399', '1611', '730', '766', '264', '729', '1613'],
#  852: ['539', '1777', '708', '339', '2424', '1569', '2671', '597', '7', '543'],
#  853: ['3277',
#   '286',
#   '1724',
#   '3607',
#   '142',
#   '2845',
#   '2551',
#   '3220',
#   '1741',
#   '3376'],
#  854: ['3533',
#   '793',
#   '1423',
#   '872',
#   '820',
#   '670',
#   '3315',
#   '2351',
#   '3245',
#   '824'],
#  855: [],
#  856: [],
#  857: [],
#  858: ['1221',
#   '2019',
#   '1193',
#   '260',
#   '111',
#   '1198',
#   '3265',
#   '1062',
#   '2028',
#   '1252'],
#  859: ['3413',
#   '749',
#   '1142',
#   '3377',
#   '2213',
#   '3530',
#   '2217',
#   '868',
#   '1908',
#   '975'],
#  860: ['679',
#   '1773',
#   '33',
#   '1510',
#   '1622',
#   '530',
#   '566',
#   '703',
#   '651',
#   '2742'],
#  861: ['1047',
#   '2353',
#   '2273',
#   '163',
#   '2058',
#   '1370',
#   '3256',
#   '474',
#   '2278',
#   '3267'],
#  862: ['1117',
#   '501',
#   '2994',
#   '730',
#   '617',
#   '388',
#   '515',
#   '1486',
#   '3260',
#   '766'],
#  863: ['776',
#   '864',
#   '396',
#   '1360',
#   '1749',
#   '826',
#   '3295',
#   '623',
#   '2930',
#   '298'],
#  864: ['744',
#   '776',
#   '2673',
#   '2705',
#   '1360',
#   '863',
#   '570',
#   '2129',
#   '2964',
#   '826'],
#  865: ['3722',
#   '545',
#   '701',
#   '679',
#   '396',
#   '1561',
#   '660',
#   '2556',
#   '192',
#   '2317'],
#  866: ['2391',
#   '293',
#   '47',
#   '1089',
#   '1729',
#   '1466',
#   '1834',
#   '2268',
#   '25',
#   '1358'],
#  867: ['2798',
#   '1679',
#   '325',
#   '2799',
#   '634',
#   '243',
#   '87',
#   '1839',
#   '374',
#   '545'],
#  868: ['3530',
#   '402',
#   '641',
#   '1714',
#   '226',
#   '3647',
#   '3779',
#   '139',
#   '3164',
#   '582'],
#  869: ['3272',
#   '1000',
#   '2308',
#   '1447',
#   '2561',
#   '874',
#   '2281',
#   '1662',
#   '81',
#   '259'],
#  870: ['3248', '267', '234', '65', '88', '710', '1526', '374', '1461', '1133'],
#  871: [],
#  872: ['557',
#   '1534',
#   '3533',
#   '3575',
#   '820',
#   '1164',
#   '793',
#   '3315',
#   '702',
#   '3530'],
#  873: [],
#  874: ['2308',
#   '1804',
#   '2281',
#   '1501',
#   '2561',
#   '1647',
#   '732',
#   '1598',
#   '1000',
#   '3272'],
#  875: ['147',
#   '94',
#   '2025',
#   '1399',
#   '767',
#   '730',
#   '805',
#   '1268',
#   '3502',
#   '851'],
#  876: ['1181', '1429', '980', '394', '227', '2258', '251', '1102', '9', '548'],
#  877: ['2544',
#   '245',
#   '1139',
#   '2192',
#   '2911',
#   '1529',
#   '730',
#   '758',
#   '286',
#   '331'],
#  878: ['730',
#   '758',
#   '398',
#   '1519',
#   '1543',
#   '1369',
#   '2544',
#   '729',
#   '3295',
#   '2127'],
#  879: ['177',
#   '2328',
#   '2279',
#   '1771',
#   '1342',
#   '842',
#   '1717',
#   '328',
#   '2327',
#   '1999'],
#  880: ['519',
#   '66',
#   '185',
#   '338',
#   '172',
#   '1882',
#   '1831',
#   '1590',
#   '1591',
#   '3464'],
#  881: ['1588',
#   '2052',
#   '586',
#   '569',
#   '575',
#   '355',
#   '2082',
#   '250',
#   '1367',
#   '830'],
#  882: ['1798',
#   '132',
#   '782',
#   '92',
#   '3063',
#   '1841',
#   '1427',
#   '2446',
#   '540',
#   '61'],
#  884: ['578',
#   '827',
#   '712',
#   '576',
#   '1852',
#   '1558',
#   '732',
#   '679',
#   '3407',
#   '1532'],
#  885: ['1654',
#   '1583',
#   '2234',
#   '2277',
#   '3003',
#   '56',
#   '2086',
#   '1707',
#   '1702',
#   '981'],
#  886: ['438',
#   '204',
#   '1004',
#   '20',
#   '315',
#   '1606',
#   '479',
#   '544',
#   '2487',
#   '1432'],
#  887: ['730',
#   '1543',
#   '2619',
#   '878',
#   '369',
#   '1369',
#   '729',
#   '1384',
#   '506',
#   '2309'],
#  888: ['2559',
#   '3400',
#   '2092',
#   '2566',
#   '1881',
#   '2354',
#   '2800',
#   '244',
#   '1489',
#   '631'],
#  889: ['2623',
#   '690',
#   '623',
#   '3866',
#   '744',
#   '3336',
#   '2998',
#   '2895',
#   '1714',
#   '1830'],
#  890: [],
#  891: ['1973',
#   '2107',
#   '1977',
#   '1976',
#   '1168',
#   '240',
#   '1972',
#   '1986',
#   '2327',
#   '1971'],
#  892: ['3108',
#   '2108',
#   '357',
#   '497',
#   '1357',
#   '342',
#   '1782',
#   '509',
#   '838',
#   '39'],
#  893: ['524',
#   '268',
#   '481',
#   '538',
#   '1600',
#   '242',
#   '266',
#   '277',
#   '3173',
#   '1650'],
#  894: [],
#  895: ['651',
#   '672',
#   '847',
#   '1811',
#   '2576',
#   '660',
#   '2960',
#   '3382',
#   '3056',
#   '2742'],
#  896: ['214',
#   '1428',
#   '1504',
#   '2705',
#   '878',
#   '1413',
#   '3260',
#   '1719',
#   '1187',
#   '2360'],
#  897: ['1936',
#   '2430',
#   '3628',
#   '972',
#   '3366',
#   '941',
#   '3406',
#   '946',
#   '1262',
#   '3172'],
#  898: ['3097',
#   '2935',
#   '951',
#   '946',
#   '916',
#   '2936',
#   '2937',
#   '1281',
#   '1188',
#   '945'],
#  899: ['914',
#   '1947',
#   '2565',
#   '900',
#   '3475',
#   '945',
#   '1104',
#   '1946',
#   '1247',
#   '1944'],
#  900: ['914',
#   '899',
#   '1947',
#   '2565',
#   '2971',
#   '3549',
#   '938',
#   '3475',
#   '2941',
#   '915'],
#  901: ['3199',
#   '3549',
#   '935',
#   '1081',
#   '938',
#   '2941',
#   '1083',
#   '907',
#   '1057',
#   '970'],
#  902: ['3668',
#   '1247',
#   '2969',
#   '2067',
#   '914',
#   '3011',
#   '58',
#   '1947',
#   '1949',
#   '509'],
#  903: ['904',
#   '1086',
#   '1212',
#   '2186',
#   '1104',
#   '950',
#   '908',
#   '1950',
#   '1237',
#   '111'],
#  904: ['903',
#   '1212',
#   '1086',
#   '2186',
#   '950',
#   '1267',
#   '1237',
#   '908',
#   '1252',
#   '668'],
#  905: ['955',
#   '3462',
#   '947',
#   '1256',
#   '936',
#   '945',
#   '951',
#   '2300',
#   '3307',
#   '910'],
#  906: ['2206',
#   '931',
#   '2202',
#   '2176',
#   '2204',
#   '1086',
#   '929',
#   '3207',
#   '1940',
#   '942'],
#  907: ['1067',
#   '1066',
#   '945',
#   '1932',
#   '936',
#   '901',
#   '3517',
#   '2213',
#   '3599',
#   '1160'],
#  908: ['1104',
#   '1250',
#   '903',
#   '1248',
#   '1237',
#   '111',
#   '904',
#   '1193',
#   '2186',
#   '922'],
#  909: ['1948',
#   '1963',
#   '1276',
#   '3451',
#   '2300',
#   '2863',
#   '3504',
#   '3363',
#   '2788',
#   '2132'],
#  910: ['3462',
#   '951',
#   '2300',
#   '905',
#   '2935',
#   '1276',
#   '3504',
#   '3022',
#   '3307',
#   '1256'],
#  911: ['931',
#   '3044',
#   '1948',
#   '3075',
#   '933',
#   '3546',
#   '1963',
#   '1086',
#   '1226',
#   '1950'],
#  912: ['923',
#   '3095',
#   '2920',
#   '1193',
#   '3089',
#   '1204',
#   '1212',
#   '1939',
#   '527',
#   '2927'],
#  913: ['942',
#   '3435',
#   '2066',
#   '922',
#   '930',
#   '2203',
#   '1267',
#   '3606',
#   '1212',
#   '2392'],
#  914: ['1947',
#   '900',
#   '899',
#   '3668',
#   '1951',
#   '902',
#   '945',
#   '2969',
#   '1247',
#   '918'],
#  915: ['933',
#   '1226',
#   '916',
#   '2080',
#   '497',
#   '3088',
#   '934',
#   '357',
#   '342',
#   '937'],
#  916: ['1226',
#   '915',
#   '898',
#   '933',
#   '3097',
#   '3475',
#   '3088',
#   '945',
#   '2935',
#   '910'],
#  917: ['961',
#   '262',
#   '531',
#   '3217',
#   '2059',
#   '1099',
#   '1877',
#   '959',
#   '1547',
#   '1928'],
#  918: ['963',
#   '1932',
#   '2565',
#   '1029',
#   '3061',
#   '938',
#   '1282',
#   '3599',
#   '3549',
#   '2096'],
#  919: ['1931',
#   '1254',
#   '1262',
#   '1204',
#   '3134',
#   '978',
#   '1303',
#   '2899',
#   '2077',
#   '899'],
#  920: ['954',
#   '1247',
#   '2067',
#   '2919',
#   '1944',
#   '976',
#   '1927',
#   '17',
#   '1929',
#   '1099'],
#  921: ['1079',
#   '1273',
#   '1238',
#   '2918',
#   '1285',
#   '2973',
#   '3424',
#   '1394',
#   '1288',
#   '3210'],
#  922: ['2186',
#   '1248',
#   '1267',
#   '3435',
#   '2066',
#   '1252',
#   '2726',
#   '1260',
#   '2203',
#   '3364'],
#  923: ['3095',
#   '912',
#   '3089',
#   '1207',
#   '2920',
#   '1193',
#   '1237',
#   '3730',
#   '1212',
#   '2927'],
#  924: ['1253',
#   '1203',
#   '750',
#   '2728',
#   '3471',
#   '1206',
#   '1251',
#   '965',
#   '3468',
#   '1950'],
#  925: ['958',
#   '2822',
#   '133',
#   '3122',
#   '956',
#   '2056',
#   '761',
#   '3644',
#   '966',
#   '941'],
#  926: ['1104',
#   '1225',
#   '1203',
#   '2731',
#   '3475',
#   '1942',
#   '949',
#   '1927',
#   '2351',
#   '3038'],
#  927: ['1934',
#   '1160',
#   '624',
#   '905',
#   '2251',
#   '955',
#   '936',
#   '1067',
#   '947',
#   '1871'],
#  928: ['930',
#   '929',
#   '28',
#   '898',
#   '2204',
#   '2203',
#   '2927',
#   '3097',
#   '3530',
#   '906'],
#  929: ['2204',
#   '2202',
#   '3849',
#   '928',
#   '2176',
#   '3551',
#   '965',
#   '2203',
#   '2983',
#   '2612'],
#  930: ['1069',
#   '2066',
#   '3334',
#   '928',
#   '2203',
#   '2186',
#   '942',
#   '746',
#   '1154',
#   '1344'],
#  931: ['906',
#   '2206',
#   '911',
#   '2184',
#   '1086',
#   '2202',
#   '2204',
#   '3044',
#   '2176',
#   '943'],
#  932: ['3414',
#   '915',
#   '792',
#   '969',
#   '937',
#   '821',
#   '2262',
#   '1684',
#   '3206',
#   '2235'],
#  933: ['915',
#   '3088',
#   '1226',
#   '916',
#   '937',
#   '3475',
#   '3341',
#   '2183',
#   '1307',
#   '3035'],
#  934: ['3088',
#   '2874',
#   '1226',
#   '915',
#   '3096',
#   '3548',
#   '933',
#   '2080',
#   '901',
#   '1016'],
#  935: ['901',
#   '938',
#   '3549',
#   '1067',
#   '1087',
#   '2565',
#   '3199',
#   '2217',
#   '1932',
#   '3061'],
#  936: ['945',
#   '905',
#   '955',
#   '3462',
#   '947',
#   '624',
#   '1066',
#   '1256',
#   '1934',
#   '2937'],
#  937: ['939',
#   '1226',
#   '915',
#   '916',
#   '3414',
#   '933',
#   '1070',
#   '2299',
#   '3199',
#   '2675'],
#  938: ['2565',
#   '3549',
#   '963',
#   '1951',
#   '918',
#   '1022',
#   '3199',
#   '1932',
#   '901',
#   '935'],
#  939: ['1070',
#   '2299',
#   '937',
#   '3229',
#   '933',
#   '3640',
#   '624',
#   '2235',
#   '2874',
#   '1226'],
#  940: ['969',
#   '2366',
#   '1931',
#   '1287',
#   '1291',
#   '965',
#   '1242',
#   '1927',
#   '828',
#   '944'],
#  941: ['1254',
#   '1931',
#   '3461',
#   '2430',
#   '1017',
#   '1262',
#   '897',
#   '1303',
#   '2899',
#   '3168'],
#  942: ['3334',
#   '2066',
#   '3435',
#   '2940',
#   '2203',
#   '2726',
#   '164',
#   '930',
#   '1179',
#   '1069'],
#  943: ['973',
#   '1940',
#   '1935',
#   '2398',
#   '2200',
#   '966',
#   '953',
#   '1938',
#   '2202',
#   '1941'],
#  944: ['954',
#   '1933',
#   '2904',
#   '959',
#   '2847',
#   '1929',
#   '1099',
#   '3217',
#   '1931',
#   '3447'],
#  945: ['1066',
#   '936',
#   '905',
#   '907',
#   '955',
#   '2300',
#   '3462',
#   '947',
#   '2935',
#   '898'],
#  946: ['898',
#   '2935',
#   '2936',
#   '1281',
#   '3035',
#   '1936',
#   '1939',
#   '1256',
#   '3097',
#   '2202'],
#  947: ['905',
#   '3462',
#   '955',
#   '1256',
#   '936',
#   '3307',
#   '2208',
#   '945',
#   '951',
#   '3629'],
#  948: ['3379',
#   '3171',
#   '982',
#   '3559',
#   '2362',
#   '2939',
#   '1103',
#   '971',
#   '669',
#   '3548'],
#  949: ['1103',
#   '1104',
#   '3038',
#   '2731',
#   '1945',
#   '1178',
#   '3559',
#   '3475',
#   '3196',
#   '2351'],
#  950: ['903',
#   '978',
#   '904',
#   '2208',
#   '1212',
#   '1260',
#   '905',
#   '3134',
#   '3307',
#   '942'],
#  951: ['898',
#   '2937',
#   '2936',
#   '905',
#   '910',
#   '2935',
#   '955',
#   '1256',
#   '2300',
#   '3462'],
#  952: ['1085',
#   '3548',
#   '3417',
#   '1017',
#   '3088',
#   '1316',
#   '1226',
#   '1287',
#   '1806',
#   '1259'],
#  953: ['2398',
#   '1938',
#   '1935',
#   '3095',
#   '2612',
#   '973',
#   '1940',
#   '1941',
#   '3089',
#   '943'],
#  954: ['920',
#   '1929',
#   '944',
#   '2728',
#   '978',
#   '959',
#   '953',
#   '2847',
#   '1949',
#   '2904'],
#  955: ['905',
#   '1256',
#   '3462',
#   '947',
#   '936',
#   '945',
#   '951',
#   '3307',
#   '2208',
#   '1162'],
#  956: ['3599',
#   '966',
#   '3778',
#   '3818',
#   '3870',
#   '943',
#   '973',
#   '925',
#   '1937',
#   '3229'],
#  957: ['3232',
#   '3492',
#   '3447',
#   '3641',
#   '2823',
#   '872',
#   '2201',
#   '3517',
#   '3306',
#   '793'],
#  958: ['966',
#   '925',
#   '1154',
#   '967',
#   '3122',
#   '2205',
#   '3642',
#   '3640',
#   '931',
#   '2650'],
#  959: ['2904',
#   '1929',
#   '3217',
#   '978',
#   '1099',
#   '2847',
#   '2612',
#   '944',
#   '954',
#   '624'],
#  960: ['1940',
#   '966',
#   '2200',
#   '973',
#   '1423',
#   '1941',
#   '1068',
#   '962',
#   '3334',
#   '3315'],
#  961: ['917',
#   '2847',
#   '2207',
#   '962',
#   '1929',
#   '1930',
#   '2904',
#   '3123',
#   '2209',
#   '974'],
#  962: ['3123',
#   '2209',
#   '2847',
#   '1930',
#   '624',
#   '2904',
#   '2214',
#   '3315',
#   '960',
#   '2207'],
#  963: ['918',
#   '938',
#   '2217',
#   '1932',
#   '3549',
#   '2565',
#   '2213',
#   '3061',
#   '3599',
#   '2099'],
#  964: ['3644',
#   '967',
#   '3122',
#   '3311',
#   '3642',
#   '3236',
#   '3792',
#   '3487',
#   '2896',
#   '3682'],
#  965: ['2212',
#   '2210',
#   '929',
#   '1251',
#   '978',
#   '2208',
#   '954',
#   '1203',
#   '3075',
#   '2219'],
#  966: ['2200',
#   '3229',
#   '2201',
#   '3642',
#   '1940',
#   '2205',
#   '973',
#   '3632',
#   '1026',
#   '943'],
#  967: ['3642',
#   '3122',
#   '3644',
#   '3236',
#   '964',
#   '210',
#   '3373',
#   '3025',
#   '416',
#   '2200'],
#  968: ['2901',
#   '2554',
#   '2553',
#   '2664',
#   '2900',
#   '1334',
#   '24',
#   '2782',
#   '3576',
#   '2288'],
#  969: ['940',
#   '1944',
#   '1287',
#   '926',
#   '1927',
#   '2019',
#   '1200',
#   '932',
#   '3475',
#   '3405'],
#  970: ['2874',
#   '1016',
#   '901',
#   '624',
#   '1070',
#   '1943',
#   '3229',
#   '2299',
#   '3315',
#   '3199'],
#  971: ['1103',
#   '3222',
#   '3379',
#   '3475',
#   '949',
#   '1104',
#   '1957',
#   '982',
#   '3152',
#   '1946'],
#  972: ['3154',
#   '3229',
#   '1070',
#   '2299',
#   '3172',
#   '2235',
#   '624',
#   '3406',
#   '3585',
#   '897'],
#  973: ['2398',
#   '943',
#   '1940',
#   '1938',
#   '953',
#   '966',
#   '1941',
#   '2200',
#   '1935',
#   '960'],
#  974: ['1933',
#   '1930',
#   '2214',
#   '2210',
#   '3447',
#   '2847',
#   '2904',
#   '1929',
#   '2219',
#   '3739'],
#  975: ['2213',
#   '3611',
#   '2217',
#   '3759',
#   '244',
#   '3776',
#   '3400',
#   '859',
#   '1024',
#   '1489'],
#  976: ['1071',
#   '920',
#   '1183',
#   '1933',
#   '944',
#   '928',
#   '2067',
#   '151',
#   '1932',
#   '2847'],
#  977: ['133',
#   '3172',
#   '2214',
#   '3321',
#   '3151',
#   '1145',
#   '2219',
#   '311',
#   '1830',
#   '3651'],
#  978: ['3134',
#   '1929',
#   '2847',
#   '2904',
#   '959',
#   '2732',
#   '872',
#   '905',
#   '950',
#   '954'],
#  979: [],
#  980: ['591',
#   '1170',
#   '20',
#   '3443',
#   '2196',
#   '459',
#   '1004',
#   '9',
#   '2487',
#   '1636'],
#  981: ['2955',
#   '572',
#   '1522',
#   '672',
#   '2960',
#   '2562',
#   '3382',
#   '3184',
#   '3001',
#   '2234'],
#  982: ['3379',
#   '948',
#   '3171',
#   '3559',
#   '1935',
#   '971',
#   '1103',
#   '1012',
#   '1946',
#   '1070'],
#  983: [],
#  984: ['305',
#   '3045',
#   '2252',
#   '1915',
#   '4',
#   '537',
#   '1817',
#   '679',
#   '1410',
#   '518'],
#  985: ['1470',
#   '134',
#   '791',
#   '3237',
#   '2909',
#   '1039',
#   '3609',
#   '2198',
#   '1138',
#   '1743'],
#  986: ['1015',
#   '238',
#   '1582',
#   '362',
#   '8',
#   '2077',
#   '2057',
#   '2045',
#   '2899',
#   '1017'],
#  987: ['35',
#   '425',
#   '729',
#   '2192',
#   '630',
#   '1384',
#   '138',
#   '2218',
#   '730',
#   '1850'],
#  988: ['1528',
#   '1317',
#   '269',
#   '2999',
#   '2619',
#   '1794',
#   '396',
#   '730',
#   '821',
#   '1643'],
#  989: ['3460',
#   '2878',
#   '684',
#   '3321',
#   '2226',
#   '1165',
#   '3164',
#   '3904',
#   '2464',
#   '3280'],
#  990: ['798',
#   '1744',
#   '20',
#   '1606',
#   '704',
#   '1591',
#   '1004',
#   '1432',
#   '44',
#   '547'],
#  991: ['1619',
#   '647',
#   '151',
#   '2106',
#   '155',
#   '516',
#   '1184',
#   '1183',
#   '1898',
#   '161'],
#  992: ['1430',
#   '422',
#   '3249',
#   '2803',
#   '662',
#   '2343',
#   '200',
#   '3686',
#   '291',
#   '18'],
#  993: ['679',
#   '1811',
#   '167',
#   '1510',
#   '1817',
#   '1651',
#   '3382',
#   '396',
#   '331',
#   '1726'],
#  994: ['3260',
#   '308',
#   '307',
#   '1719',
#   '1635',
#   '1095',
#   '36',
#   '1245',
#   '515',
#   '1358'],
#  996: ['1379',
#   '303',
#   '210',
#   '1382',
#   '3165',
#   '548',
#   '368',
#   '511',
#   '384',
#   '204'],
#  997: ['878',
#   '1369',
#   '1543',
#   '1437',
#   '2994',
#   '1889',
#   '758',
#   '1648',
#   '280',
#   '3295'],
#  998: ['2616',
#   '42',
#   '2308',
#   '170',
#   '1918',
#   '2540',
#   '1000',
#   '1523',
#   '3274',
#   '3020'],
#  999: ['2280',
#   '1447',
#   '1061',
#   '2231',
#   '2112',
#   '874',
#   '1799',
#   '2281',
#   '1352',
#   '1662'],
#  1000: ['2308',
#   '874',
#   '1662',
#   '869',
#   '2281',
#   '3272',
#   '1675',
#   '2561',
#   '259',
#   '658'],
#  1001: [],
#  1002: ['1903',
#   '1585',
#   '633',
#   '1875',
#   '1871',
#   '3282',
#   '52',
#   '1528',
#   '649',
#   '811'],
#  1003: ['225',
#   '1841',
#   '61',
#   '100',
#   '230',
#   '3063',
#   '832',
#   '2803',
#   '350',
#   '3249'],
#  1004: ['1752',
#   '20',
#   '1626',
#   '204',
#   '1438',
#   '798',
#   '839',
#   '836',
#   '1744',
#   '547'],
#  1005: ['2042',
#   '374',
#   '2953',
#   '1474',
#   '575',
#   '2036',
#   '355',
#   '87',
#   '274',
#   '2052'],
#  1006: ['805',
#   '78',
#   '3502',
#   '477',
#   '62',
#   '2190',
#   '1810',
#   '491',
#   '3252',
#   '280'],
#  1007: ['2016',
#   '2014',
#   '2095',
#   '2055',
#   '2040',
#   '2032',
#   '2031',
#   '616',
#   '1011',
#   '1021'],
#  1008: ['3311',
#   '3368',
#   '2401',
#   '3236',
#   '3365',
#   '1283',
#   '3487',
#   '964',
#   '1843',
#   '967'],
#  1009: ['2',
#   '60',
#   '1030',
#   '2043',
#   '2161',
#   '126',
#   '3672',
#   '1031',
#   '2143',
#   '1967'],
#  1010: ['1014',
#   '2098',
#   '1013',
#   '2136',
#   '2079',
#   '1018',
#   '1083',
#   '1713',
#   '2047',
#   '1588'],
#  1011: ['2051',
#   '2095',
#   '3674',
#   '2014',
#   '2037',
#   '3672',
#   '1009',
#   '2016',
#   '1359',
#   '1538'],
#  1012: ['531',
#   '2096',
#   '262',
#   '1103',
#   '2059',
#   '982',
#   '1022',
#   '1013',
#   '948',
#   '3171'],
#  ...}

# %% [markdown]
# ## Step 2. 탐색적으로 다양한 추천 후보군 생성

# %% [markdown]
# ### 문제 8. EDA & 전처리 - 평균 평점 기반 Popular 후보군 생성

# %%
# 일정 count 이상이면서 평균 rating이 높은 순서대로 Popular 후보군 생성 (movie_id에 groupby 적용)

# %% [markdown]
# ### 문제 9. EDA & 전처리 - Popular 후보군 생성 결과 확인

# %%
# 생성 결과를 popular_movie_list 변수에 할당

# ex.
# [4.608695652173913,
#  4.560509554140127,
#  4.554557700942973,
#  4.524966261808367,
#  4.52054794520548,
#  4.517106001121705,
#  4.510416666666667,
#  4.507936507936508,
#  4.491489361702127,
#  4.477724741447892]

# %% [markdown]
# ### 문제 10. EDA & 전처리 - 장르 & 연도 기준 Meta2Item 후보군 생성

# %%
# 장르 & 연도를 meta로 하는, meta별 상위 10개씩 popular list 추출
genre_popular = []
year_popular = []

# %% [markdown]
# ### 문제 11. EDA & 전처리 - Meta 후보군 생성 결과 확인

# %%
# 위 결과 확인
# ex.
# 연도별 popular list - {'1910': [3132, 2821, 2823], '1920': [3517, 3022, 3629, 2010], ....}

# %% [markdown]
# ## Step 3. Point-wise 데이터셋 생성

# %% [markdown]
# #### Ranking Model
#
#     [랭킹 모델의 형태와 역할]
#     1. Binary Classification을 학습하는 Regressor가 가장 대표적인 예
#     2. y=1은 User가 Item을 시청(혹은 구매 등)한 경우 -> **Ground Truth**
#     3. f(x_ui) = X_u + X_i + b -> **X_u는 User의 여러가지 정보를 벡터로 나타낸 것, 그리고 X_i는 아이템의 여러가지 정보를 벡터로 나타낸 것**
#     4. NDCG, AUC, Top@Precision... 등을 기준으로 모델을 학습 (랭킹 학습 방식인 Point-wise, Pair-wise 등을 기준으로 각각 다름)
#
# ![point-wise](https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/images/point-wise.png)

# %% [markdown]
# ### 문제 12. EDA & 전처리 - 특정 시간 기준 데이터셋 분리

# %%
# 데이터셋을 8:2로 나눌 수 있는 시간을 기준으로 데이터셋을 train,test로 분리

# %% [markdown]
# ### 문제 13. User Profiling - 유저 속성 EDA (gender, age, occupation, zipcode)

# %% [markdown]
# ##### 1) Gender

# %%
# gender 피처 탐색

# %% [markdown]
# #### 2) Age

# %%
# age 피처 탐색

# %%
# age 피처 bucketize

# %% [markdown]
# #### 3) Occupation

# %%
# occupation 피처 탐색

# %% [markdown]
# #### 4) Zipcode

# %%
# zipcode 피처 탐색

# %% [markdown]
# ### 문제 14. User Profiling - 유저 속성별 피쳐맵 생성

# %% [markdown]
# #### 1) Gender

# %%
# gender 피처맵 생성

# ex.
# {'F': 1, 'M': 2}

# %% [markdown]
# #### 2) Age

# %%
# age 피처맵 생성

# ex.
# {'10': 6, '20': 3, '30': 5, '40': 4, '50': 2, 'outlier': 1}

# %% [markdown]
# #### 3) Occupation

# %%
# occupation 피처맵 생성

# ex.
# {0: 10,
#  1: 7,
#  2: 17,
#  3: 11,
#  4: 13,
#  ...}

# %% [markdown]
# ### 문제 15. Item Profiling - 영화 속성별 피쳐맵 생성 (장르, 년도)

# %% [markdown]
# #### 1) Genre

# %%
# genre 피처맵 생성

# ex.
# {'Action': 4,
#  'Adventure': 2,
#  'Animation': 1,
#  "Children's": 9,
#  'Comedy': 3,
#  'Crime': 7,
#  'Documentary': 10,
#  'Drama': 5,
#  'Fantasy': 17,
#  'Film-Noir': 15,
#  'Horror': 12,
#  'Musical': 18,
#  'Mystery': 14,
#  'Romance': 8,
#  'Sci-Fi': 11,
#  'Thriller': 6,
#  'War': 16,
#  'Western': 13}

# %% [markdown]
# #### 2) Year

# %%
# year 피처맵 생성

# %% [markdown]
# ### 문제 16. Context Profiling - 특정 시간 기준 유저 행동 EDA (시청한 영화 정보, 시청한 영화 점수 분포)

# %%
# 시간 기준으로 분리한 데이터셋 EDA

# %% [markdown]
# ### 문제 17. Feature Mapping - Profiling 피처맵 맵핑

# %%
# profile 완료된 경과로 피처맵 맵핑

# ex.
# 	user_id	movie_id	rating	released_year_area	main_genre	gender	occupation	age_bucket
# 0	635	1251	4	4	5	2	9	2
# 1	635	3948	4	10	3	2	9	2
# 2	635	1270	4	3	3	2	9	2
# 3	635	1279	5	1	3	2	9	2
# 4	635	1286	4	3	5	2	9	2
# Out:
#    user_id  movie_id  rating  ...  gender  occupation  age_bucket
# 0      635      1251       4  ...       2           9           2
# 1      635      3948       4  ...       2           9           2
# 2      635      1270       4  ...       2           9           2
# 3      635      1279       5  ...       2           9           2
# 4      635      1286       4  ...       2           9           2
#
# [5 rows x 8 columns]

# %% [markdown]
# ### 문제 18. Binary Transformation - 평가 점수 기준으로 (0,1) 변환

# %%
# rating이 4점 이상인 경우 1, 3점 이하인 경우 0으로 변환

# %% [markdown]
# ### 문제 19. Feature Vector 생성 - libsvm 포맷의 데이터셋 생성

# %% [markdown]
# #### Sparse Vector in Linear Model
#
#     [Sparse Vector]
#     1. 0, 1로 값을 표현하는 벡터가 매우 희소한 상황
#     2. 아래 그림에서 3002개의 벡터 중, 1이 등장하는 벡터는 단 두개
#     3. Linear Model에서 Sparse 하다는 것은 이러한 상황을 의미
#
# ![sparse](https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/images/sparse.png)
#
# ----
#
#     [Linear Model]
#     1. 입력 특성에 대한 선형 함수를 만들어 예측을 수행하는 모델
#     2. y = a1x1 + a2x2... 같은 방정식이라고 생각할 수 있음
#     3. 일반적인 랭킹 모델은 Linear Model로 마지막 추론을 하게 되어있음
#     4. x1, x2...가 바로 Sparse Vector를 의미함
#
# ----
#
#     [libsvm 포맷]
#     1. "index":"value" 형태로 sparse vector를 표현하는 형태
#     2. 위 그림을 표현하면, "1:1 3001:1" 이 됨.

# %%
# libsvm 포맷의 데이터셋 생성

# %%
# ex. 1 634:1 6650:1 9065:1 9076:1 9091:1 9100:1 9114:1

# %% [markdown]
# ## Step 4. 추천 랭킹 모델링 (Factorization Machine)

# %% [markdown]
# #### Factorization Machine
#
# ![equation](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FbRP7gn%2FbtqDw3LQxDB%2FXmWK8heUckUWpHx379UCM1%2Fimg.png)
#
#     [랭킹 모델의 형태와 역할]
#     1. Linear Regression, SVM처럼 동작하는 General predictor
#     2. 변수 간의 모든 pair-wise interaction을 계산하는 알고리즘
#     3. General predictor의 장점 + MF 알고리즘이 가지는 의미 단위 해석(latent factor)의 장점
#     4. sparse한 데이터셋을 가지고 있을 때 적합

# %% [markdown]
# ### 문제 20. 학습 데이터 생성 - 특정 시간 기준 Train/Test 데이터셋 생성

# %%
# !pip install xlearn
# Out:
# Collecting xlearn
#   Downloading https://files.pythonhosted.org/packages/ab/1b/9ad0093cac05d6f95d3d768bc855804b18723c72120ce45cd930bd303587/xlearn-0.40a1.tar.gz (4.9MB)
#      |████████████████████████████████| 4.9MB 9.1MB/s
# Building wheels for collected packages: xlearn
#   Building wheel for xlearn (setup.py) ... done
#   Created wheel for xlearn: filename=xlearn-0.40a1-cp36-none-any.whl size=230317 sha256=d05283d54ceadc2a2b0bea2a983df31bb090dd4bf922063dfff0b70c6286c714
#   Stored in directory: /root/.cache/pip/wheels/59/7d/71/699578f3cb69f16a2e5f648d978259dba959c92a5a6eca9451
# Successfully built xlearn
# Installing collected packages: xlearn
# Successfully installed xlearn-0.40a1

# %%
txt_file = open('train.txt', 'w')
for idx, row in train_df.iterrows():
  vec = []
  label = row['y']
  vec.append(str(label))
  row = row.drop(labels=['rating'])
  row = row.drop(labels=['y'])
  for key, value in row.items():
    col_idx = col_accum_index_dict[key] + value - 1
    vec.append(str(col_idx) + ":" + str(1))
  txt_file.write("%s\n" % " ".join(vec))
txt_file.close()

# %%
txt_file = open('test.txt', 'w')
for idx, row in test_df.iterrows():
  vec = []
  label = row['y']
  vec.append(str(label))
  row = row.drop(labels=['rating'])
  row = row.drop(labels=['y'])
  for key, value in row.items():
    col_idx = col_accum_index_dict[key] + value - 1
    vec.append(str(col_idx) + ":" + str(1))
  txt_file.write("%s\n" % " ".join(vec))
txt_file.close()

# %% [markdown]
# ### 문제 21. 모델링 - FM Binary Classification 모델 학습

# %%
import numpy as np
from sklearn.metrics import roc_auc_score


class FactorizationMachine():
    """
    This Class is implementation of this paper : https://www.csie.ntu.edu.tw/~b97053/paper/Rendle2010FM.pdf
    Just a example of FM Algorithm, not for production.
    -----
    Only simple methods are available.
    e.g 1 : batch training, adagrad optimizer, parallel training are not supported.
    e.g 2 : simple optimizer Stochastic Gradient Descent with L2 Regularization.
    e.g 3 : using titanic dataset on local memory.
    """
    def __init__(self, k, lr, l2_reg, l2_lambda, epoch, early_stop_window, train_data, valid_data):
        """
        :param k: number of latent vector
        :param lr: learning rate
        :param l2_reg: bool parameter for L2 regularization
        :param l2_lambda: lambda of L2 regularization
        :param epoch: training epoch
        :param train_data: path of train data
        :param valid_data: path of valid data
        """
        self._k = k
        self._lr = lr
        self._l2_reg = l2_reg
        self._l2_lambda = l2_lambda
        self._epoch = epoch
        self._early_stop_window = early_stop_window
        self._train_file_path = train_data
        self._valid_file_path = valid_data
        self._valid_loss_list = []

    def _load_dataset(self):
        """
        1. load dataset to memory from train/valid path
        2. find max index in dataset for w's vector size
        """
        # load data
        train_file = open(self._train_file_path, 'r')
        valid_file = open(self._valid_file_path, 'r')
        self._train_data = train_file.read().split('\n')
        self._valid_data = valid_file.read().split('\n')
        train_file.close()
        valid_file.close()

        # find max index
        self.feature_max_index = 0
        print("Start to init FM vectors.")
        for row in self._train_data:
            for element in row.split(" ")[1:]:
                index = int(element.split(":")[0])
                if self.feature_max_index < index:
                    self.feature_max_index = index

        for row in self._valid_data:
            for element in row.split(" ")[1:]:
                index = int(element.split(":")[0])
                if self.feature_max_index < index:
                    self.feature_max_index = index

        # init FM vectors
        self._init_vectors()
        print("Finish init FM vectors.")

    def _init_vectors(self):
        """
        1. initialize FM vectors
        2. Conduct naive transformation libsvm format txt data to numpy training sample.
        """
        self.w = np.random.randn(self.feature_max_index+1)
        self.v = np.random.randn(self.feature_max_index+1, self._k)
        self.train_x_data = []
        self.train_y_data = np.zeros((len(self._train_data)-1))
        self.valid_x_data = []
        self.valid_y_data = np.zeros((len(self._valid_data)-1))

        # make numpy dataset
        for n, row in enumerate(self._train_data):
            element = row.split(" ")
            if len(element) > 1:
              self.train_y_data[n] = int(element[0])
              self.train_x_data.append([np.array([int(pair.split(":")[0]) for pair in element[1:]]),
                                        np.array([int(pair.split(":")[1]) for pair in element[1:]])])

        for n, row in enumerate(self._valid_data):
            element = row.split(" ")
            if len(element) > 1:
              self.valid_y_data[n] = int(element[0])
              self.valid_x_data.append([np.array([int(pair.split(":")[0]) for pair in element[1:]]),
                                        np.array([int(pair.split(":")[1]) for pair in element[1:]])])

    def train(self):
        """
        Train FM model by Gradient Descent with L2 regularization
        """
        self._load_dataset()
        for epoch_num in range(1, self._epoch):
            train_y_hat = self.predict(data=self.train_x_data)
            valid_y_hat = self.predict(data=self.valid_x_data)
            train_loss = self._get_loss(y_data=self.train_y_data, y_hat=train_y_hat)
            valid_loss = self._get_loss(y_data=self.valid_y_data, y_hat=valid_y_hat)
            train_auc = roc_auc_score(self.train_y_data, train_y_hat)
            valid_auc = roc_auc_score(self.valid_y_data, valid_y_hat)
            self._print_learning_info(epoch=epoch_num, train_loss=train_loss, valid_loss=valid_loss,
                                      train_auc=train_auc, valid_auc=valid_auc)
            if self._check_early_stop(valid_loss=valid_loss):
                print("Early stop at epoch:", epoch_num)
                return 0

            self._stochastic_gradient_descent(self.train_x_data, self.train_y_data)

    def predict(self, data):
        """
        Implementation of FM model's equation on O(kmd)
        -----
        Numpy array shape : (n, [index of md], [value of md])
        md : none-zero feature
        """
        num_data = len(data)
        scores = np.zeros(num_data)
        for n in range(num_data):
            feat_idx = data[n][0]
            val = data[n][1]

            # linear feature score
            linear_feature_score = np.sum(self.w[feat_idx] * val)

            # factorized feature score
            vx = self.v[feat_idx] * (val.reshape(-1, 1))
            cross_sum = np.sum(vx, axis=0)
            square_sum = np.sum(vx * vx, axis=0)
            cross_feature_score = 0.5 * np.sum(np.square(cross_sum) - square_sum)

            # Model's equation
            scores[n] = linear_feature_score + cross_feature_score

        # Sigmoid transformation for binary classification
        scores = 1.0 / (1.0 + np.exp(-scores))
        return scores

    def _get_loss(self, y_data, y_hat):
        """
        Calculate loss with L2 regularization (two type of coeficient - w,v)
        """
        l2_norm = 0
        if self._l2_reg:
            w_norm = np.sqrt(np.sum(np.square(self.w)))
            v_norm = np.sqrt(np.sum(np.square(self.v)))
            l2_norm = self._l2_lambda * (w_norm + v_norm)
        return -1 * np.sum( (y_data * np.log(y_hat)) + ((1 - y_data) * np.log(1 - y_hat)) ) + l2_norm

    def _check_early_stop(self, valid_loss):
        self._valid_loss_list.append(valid_loss)
        if len(self._valid_loss_list) > 5:
            prev_loss = self._valid_loss_list[len(self._valid_loss_list) - self._early_stop_window]
            curr_loss = valid_loss
            if prev_loss < curr_loss:
                return True
        return False

    def _print_learning_info(self, epoch, train_loss, valid_loss, train_auc, valid_auc):
        print("epoch:", epoch, "||", "train_loss:", train_loss, "||", "valid_loss:", valid_loss,
              "||", "Train AUC:", train_auc, "||", "Test AUC:", valid_auc)


    def _stochastic_gradient_descent(self, x_data, y_data):
        """
        Update each coefs (w, v) by Gradient Descent
        """
        for data, y in zip(x_data, y_data):
            feat_idx = data[0]
            val = data[1]
            vx = self.v[feat_idx] * (val.reshape(-1, 1))

            # linear feature score
            linear_feature_score = np.sum(self.w[feat_idx] * val)

            # factorized feature score
            vx = self.v[feat_idx] * (val.reshape(-1, 1))
            cross_sum = np.sum(vx, axis=0)
            square_sum = np.sum(vx * vx, axis=0)
            cross_feature_score = 0.5 * np.sum(np.square(cross_sum) - square_sum)

            # Model's equation
            score = linear_feature_score + cross_feature_score
            y_hat = 1.0 / (1.0 + np.exp(-score))
            cost = y_hat - y

            if self._l2_reg:
                self.w[feat_idx] = self.w[feat_idx] - cost * self._lr * (val + self._l2_lambda * self.w[feat_idx])
                self.v[feat_idx] = self.v[feat_idx] - cost * self._lr * ((sum(vx) * (val.reshape(-1, 1)) - (vx * (val.reshape(-1, 1)))) + self._l2_lambda * self.v[feat_idx])
            else:
                self.w[feat_idx] = self.w[feat_idx] - cost * self._lr * val
                self.v[feat_idx] = self.v[feat_idx] - cost * self._lr * (sum(vx) * (val.reshape(-1, 1)) - (vx * (val.reshape(-1, 1))))

# %% [markdown]
# ### 문제 22. 모델링 - AUC 평가

# %%
fm = FactorizationMachine(k=4,
                          lr=0.005,
                          l2_reg=True,
                          l2_lambda=0.0002,
                          epoch=30,
                          early_stop_window=3,
                          train_data='./train.txt',
                          valid_data='./test.txt')
fm.train()
# Out:
# Start to init FM vectors.
# Finish init FM vectors.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:152: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:152: RuntimeWarning: invalid value encountered in multiply
# epoch: 1 || train_loss: nan || valid_loss: nan || Train AUC: 0.4921103729117869 || Test AUC: 0.49304915298621127
# epoch: 2 || train_loss: 736900.2836016961 || valid_loss: 198644.74687446197 || Train AUC: 0.5800798753509125 || Test AUC: 0.5619787034050658
# epoch: 3 || train_loss: 651009.9312976537 || valid_loss: 180090.75890737606 || Train AUC: 0.6170377247586235 || Test AUC: 0.5872701632247662
# epoch: 4 || train_loss: 605023.7906217531 || valid_loss: 169998.84888488898 || Train AUC: 0.6425698141531598 || Test AUC: 0.6041856323230529
# epoch: 5 || train_loss: 576017.5491097918 || valid_loss: 163575.5639834436 || Train AUC: 0.6614054044251164 || Test AUC: 0.6166846867487699
# epoch: 6 || train_loss: 555887.8108497746 || valid_loss: 159121.3592374289 || Train AUC: 0.6759621226758684 || Test AUC: 0.6264261366402801
# epoch: 7 || train_loss: 541028.4093140943 || valid_loss: 155872.33083542256 || Train AUC: 0.6875697318401519 || Test AUC: 0.634224237309259
# epoch: 8 || train_loss: 529556.0962632183 || valid_loss: 153410.5791362925 || Train AUC: 0.6970478273957991 || Test AUC: 0.640583545581711
# epoch: 9 || train_loss: 520392.7994923586 || valid_loss: 151484.37900942547 || Train AUC: 0.7049339823068209 || Test AUC: 0.6458456482520428
# epoch: 10 || train_loss: 512882.2335284191 || valid_loss: 149934.75143550636 || Train AUC: 0.7115981180091674 || Test AUC: 0.6502620196962721
# epoch: 11 || train_loss: 506602.6437924827 || valid_loss: 148658.16287764962 || Train AUC: 0.7173020233713663 || Test AUC: 0.6540199024561956
# epoch: 12 || train_loss: 501268.8965244307 || valid_loss: 147585.3942050374 || Train AUC: 0.7222376701997938 || Test AUC: 0.6572556094927172
# epoch: 13 || train_loss: 496679.42976295965 || valid_loss: 146668.91468987166 || Train AUC: 0.7265503627329477 || Test AUC: 0.660072267998942
# epoch: 14 || train_loss: 492686.43030737306 || valid_loss: 145875.17003499676 || Train AUC: 0.7303528001885679 || Test AUC: 0.662548345226313
# epoch: 15 || train_loss: 489178.30362302455 || valid_loss: 145179.80201035453 || Train AUC: 0.7337321513382349 || Test AUC: 0.6647453220224107
# epoch: 16 || train_loss: 486068.9098659161 || valid_loss: 144564.65736258053 || Train AUC: 0.7367596622777405 || Test AUC: 0.6667063528538753
# epoch: 17 || train_loss: 483290.6547013685 || valid_loss: 144015.9049259066 || Train AUC: 0.73949100582059 || Test AUC: 0.6684695438072158
# epoch: 18 || train_loss: 480789.8377139825 || valid_loss: 143522.83537113035 || Train AUC: 0.7419723247205365 || Test AUC: 0.6700651167690872
# epoch: 19 || train_loss: 478523.37531079294 || valid_loss: 143077.07299033145 || Train AUC: 0.7442415573131379 || Test AUC: 0.6715149723735633
# epoch: 20 || train_loss: 476456.4049609758 || valid_loss: 142672.03132923538 || Train AUC: 0.7463289338426067 || Test AUC: 0.672837193157213
# epoch: 21 || train_loss: 474560.4861116522 || valid_loss: 142302.5139314887 || Train AUC: 0.7482595989885975 || Test AUC: 0.6740498502914085
# epoch: 22 || train_loss: 472812.22584629 || valid_loss: 141964.40662111205 || Train AUC: 0.7500547265917545 || Test AUC: 0.6751638885628002
# epoch: 23 || train_loss: 471192.21992970037 || valid_loss: 141654.43423156763 || Train AUC: 0.7517313401332746 || Test AUC: 0.6761886356527969
# epoch: 24 || train_loss: 469684.23490307183 || valid_loss: 141369.9678675115 || Train AUC: 0.753303738373396 || Test AUC: 0.677134818887172
# epoch: 25 || train_loss: 468274.5762768101 || valid_loss: 141108.8737867128 || Train AUC: 0.7547843152045111 || Test AUC: 0.6780070337632327
# epoch: 26 || train_loss: 466951.59906238917 || valid_loss: 140869.39607028564 || Train AUC: 0.7561834795639356 || Test AUC: 0.6788128214954086
# epoch: 27 || train_loss: 465705.32497594226 || valid_loss: 140650.06534563776 || Train AUC: 0.7575098887387297 || Test AUC: 0.6795571266549288
# epoch: 28 || train_loss: 464527.13849524106 || valid_loss: 140449.62637381622 || Train AUC: 0.7587714398599181 || Test AUC: 0.6802441917076544
# epoch: 29 || train_loss: 463409.542218049 || valid_loss: 140266.9785891072 || Train AUC: 0.7599752054906321 || Test AUC: 0.6808788156082214

# %% [markdown]
# ## Step 5. 모의 추천 시스템 구축

# %% [markdown]
# ### 문제 23. 추천 결과 평가 - 특정 시간 기준 유저별 시청 목록 추출 (Train/Test과 동일 기준)

# %%
# train 데이터셋에서 유저 시청 목록 추출

# %% [markdown]
# ### 문제 24. 추천 결과 평가 - Train 데이터 기반 유저별 추천 후보군 생성

# %% [markdown]
# #### 1) 최근 시청한 3개 영화의 연관 영화 목록 추출

# %%
# train 데이터셋으로만 m2v 모델 학습

# %%
model = Word2Vec(movie2vec_dataset,
                 size=100,
                 window=6,  # 주변 word의 윈도우
                 sg=1,  # skip-gram OR cbow
                 hs=0,  # hierarchical softmax OR negative sampling
                 negative=20,  # negative sampling 파라미터
                 min_count=1,  # word의 등장 최소 횟수
                 iter=20)

# %%
# 유저별 최근 시청한 3개 영화 추출
recent_user_watch_list = rating_df[rating_df['time'] < 975768738].groupby('user_id')[['movie_id', 'time']].apply(lambda x : get_recent_movie_list_sort_by_time(x, 3))

# %%
# 영화별 연관 영화 (item2item) k개씩 추출

# %% [markdown]
# #### 2) 평점 기반 인기 영화

# %%
# 평점 높은 상위 10개의 영화 추출

# %% [markdown]
# #### 3) 장르, 연도별 인기 영화

# %%
# 장르&연도를 meta로 하여, meta별 상위 10개의 평점 높은 영화 리스트 추출

# %% [markdown]
# #### 4) 4개 추천 후보군 병합

# %%
# 위에서 추출한 후보군들을 하나로 병합

# %% [markdown]
# ##### 유저별 선호 장르/연도 파악

# %%
# 1. 유저별 시청 히스토리를 기준으로 선호하는 장르/연도 지정
# 2. 선호하는 장르/연도의 인기 리스트 추출

# %% [markdown]
# ##### 최종 병합

# %% [markdown]
# ### 문제 25. 추천 결과 평가 - 랭킹 모델로 추천 후보군 K개 정렬

# %% [markdown]
# #### predict 가능한 포맷으로 변경
# - ex) [[array([31, 55, 66, 77]), array([1, 1, 1, 1])]]

# %% [markdown]
# #### 후보군 정렬

# %%
# 유저별 추천 후보군 재정렬
# ex. 
# {635: {1664: 0.49089334810703084, 3498: 0.7017178066091346, 2444: 0.3960630484760756...}, ...}
# -> {userid: {movieid: score...}...}

# %%
str(user_recommendation_dict)[:2000]
# Out:
# '{635: {1664: 0.49089334810703084, 3498: 0.7017178066091346, 2444: 0.3960630484760756, 3152: 0.9267421332219103, 527: 0.906818420614163, 787: 0.8598210292115226, 2964: 0.49588669638145944, 922: 0.982938255727678, 1178: 0.9484776307851908, 1041: 0.8669462244704258, 537: 0.549539598898913, 1701: 0.8241026949792277, 1830: 0.16538777379886402, 372: 0.40789551375524885, 50: 0.9608472119143907, 2908: 0.8413125456347317, 53: 0.40820096414145074, 3382: 0.9968718349209549, 318: 0.912371092519536, 1471: 0.8704239191580381, 3006: 0.8130977243189997, 3522: 0.781827773625932, 2503: 0.6881686870074593, 2610: 0.9471364810657155, 1955: 0.7705156756575101, 2905: 0.8373731467801648, 858: 0.9526282013504191, 989: 0.1534201482163519, 371: 0.5308118956903058, 2019: 0.9851106898334485, 3201: 0.7831165743484206, 745: 0.9605919071180541, 2930: 0.9943506643249671, 1476: 0.6154292429949801, 1148: 0.9551935409057166, 3163: 0.7549520403458307}, 636: {1664: 0.9969645379579196, 2977: 0.39311269548383027, 466: 0.3561161179138224, 2444: 0.9497407962119908, 1762: 0.13427362867081133, 3146: 0.30124938578183846, 527: 0.9552889370389953, 787: 0.9583230736383349, 2964: 0.8383208743761764, 922: 0.9763335941818866, 1178: 0.8661635222007678, 379: 0.6058716894681772, 442: 0.6043344648202376, 1830: 0.9881795448276919, 50: 0.9766793142892624, 53: 0.9719690680849682, 3382: 0.9998692011464098, 196: 0.39610568439341287, 318: 0.9380225412547604, 1471: 0.8666744038177431, 3326: 0.6248576362373083, 3522: 0.10390601948906227, 2503: 0.9462347853198093, 435: 0.6896573108522145, 332: 0.4354207370496189, 2905: 0.9211134786173443, 3180: 0.020027753344978756, 858: 0.9619828740618135, 989: 0.08412842399652949, 2525: 0.5138511236112588, 780: 0.6769360452351423, 2019: 0.976205616680101, 745: 0.9420676708374995, 1676: 0.5699376392017544, 2930: 0.9944958536932457, 1320: 0.5288169857527165, 1148: 0.9451463876173282}, 637: {1664: 0.9601895646931214, 368: 0.6424317784137946, 2476: 0.4335441401750167, 2444: 0.95065552610112, 527: '

# %% [markdown]
# ## Step 6. 추천 결과 평가

# %% [markdown]
# ### 문제 26. 추천 결과 평가 - 추천 후보군과 Test 데이터간의 MAP@K 계산

# %%
# 4점 이상을 준 test 시청 리스트 추출하여 MAP 계산

# %%
# 아래 그래프처럼 map@k 시각화
